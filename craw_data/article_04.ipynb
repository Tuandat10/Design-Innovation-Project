# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
import spacy
from spacy import displacy

# %%
url = "https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific#:~:text=Indo-Pacific"
response = requests.get(url)

# %%
soup=BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3115931-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "UA-3115931-1", {"groups":"default","anonymize_ip":true,"page_placeholder":"PLACEHOLDER_page_path"});gtag("config", "G-2Q1HP4FKQV", {"groups":"default","page_placeholder":"PLACEHOLDER_page_location"});
#   </script>
#   <script src="/sites/default/files/hotjar/hotjar.script.js?sj6rpe">
#   </script>
#   <meta content="Energy security is shifting to new interdependencies based on alternate fuels and rare earths." name="description"/>
#   <link href="https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" rel="canonical"/>
#   <meta content="https://www.lowyinstitute.org/sites/default/files/2022-09/50503416718_b25c206dd3_k_0.jpg" property="og:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Energy security is shifting to new interdependencies based on alternate fuels and rare earths." name="twitter:description"/>
#   <meta content="@lowyinstitute" name="twitter:site"/>
#   <meta content="Powerhouse: clean energy transitions in the Indo-Pacific" name="twitter:title"/>
#   <meta content="@lowyinstitute" name="twitter:creator"/>
#   <meta content="https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" name="twitter:url"/>
#   <meta content="https://www.lowyinstitute.org/sites/default/files/2022-09/50503416718_b25c206dd3_k_0.jpg" name="twitter:image"/>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Powerhouse: clean energy transitions in the Indo-Pacific | Lowy Institute
#   </title>
#   <link href="/sites/default/files/css/css_ysRUr3vy5gjRl2yhj2QZQND5fXEthazaJ3z-hovdoHY.css?delta=0&amp;language=en&amp;theme=lowy&amp;include=eJw9itEKgDAIAH_I8pPCwg3LdGxC7e9bBL0cx3Gtt-ATV2oM6lfHrL6SQnIP8-CGv0ESDa64UQlx-3axkUrlwalQZkhKGV_MKnYstNP9AMB9JwU" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_24fxxV5B4jnNEAyzIYMhouXBB8LMMiF0AATxIW6U3XU.css?delta=1&amp;language=en&amp;theme=lowy&amp;include=eJw9itEKgDAIAH_I8pPCwg3LdGxC7e9bBL0cx3Gtt-ATV2oM6lfHrL6SQnIP8-CGv0ESDa64UQlx-3axkUrlwalQZkhKGV_MKnYstNP9AMB9JwU" media="all" rel="stylesheet"/>
#   <link href="/themes/custom/lowy/favicons/interpreter-apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/themes/custom/lowy/favicons/interpreter-favicon32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/themes/custom/lowy/favicons/interpreter-favicon16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://fonts.googleapis.com/css?family=Dosis:400,200,300,500,600,700,800" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Raleway:700italic,700" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Merriweather:400,700,900,700italic,900italic,400italic,300italic,300" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:400,400italic,600,600italic,700,700italic,900,900italic,300italic,300,200italic,200" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Quicksand:300,400,700" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,500" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Noto+Serif:400i,700i" media="all" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="page-the-interpreter page-the-interpreter-archive domain-lowyinstitute path-node page-node-type-interpreter-debate">
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Skip to main content
#   </a>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <div id="wrapper">
#     <header id="header">
#      <div class="container txt-center clearfix">
#       <div class="region region-interpreter-header">
#        <div id="block-interpretersitebranding">
#         <div id="header-brand">
#          <a href="/the-interpreter">
#           The Interpreter
#          </a>
#         </div>
#        </div>
#        <div id="block-interpretersearchbox">
#         <div id="header-search">
#          <a class="icon icon-search" id="header-search-btn-toggle">
#          </a>
#          <form accept-charset="UTF-8" action="/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" class="interpreter-search-box" data-drupal-selector="lowy-interpreter-search-box" id="lowy-interpreter-search-box" method="post">
#           <div class="js-form-item form-item js-form-type-textfield form-item-search js-form-item-search form-no-label">
#            <input aria-required="true" class="ctools-auto-submit form-text required form-item__textfield" data-drupal-selector="edit-search" id="interpreter-input-s" maxlength="128" name="search" placeholder="Search" required="required" size="15" type="text" value=""/>
#           </div>
#           <input class="form-item__textfield" data-drupal-selector="form-vruhkuqhr6wkt6vooydldi4glqopamze-tdimwzvw1m" name="form_build_id" type="hidden" value="form-VRUHkUQhR6wkT6vooYdldi4glQOpAMZe-TDImWzvW1M"/>
#           <input class="form-item__textfield" data-drupal-selector="edit-lowy-interpreter-search-box" name="form_id" type="hidden" value="lowy_interpreter_search_box"/>
#           <input class="ctools-auto-submit-click js-hide button js-form-submit form-submit form-item__textfield" data-drupal-selector="edit-submit" id="lowy-int-btn-searchbox" name="op" type="submit" value="Search"/>
#          </form>
#         </div>
#        </div>
#        <nav id="header-nav">
#         <a class="icon icon-menu" id="header-nav-btn-toggle">
#         </a>
#         <div id="header-nav-wrap">
#          <h2 class="visually-hidden" id="block-interpretermenulinks-menu">
#           Interpreter - Menu Links
#          </h2>
#          <ul class="menu clearfix">
#           <li>
#            <a data-drupal-link-system-path="the-interpreter/archive" href="/the-interpreter/archive">
#             Articles
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="the-interpreter/debate" href="/the-interpreter/debate">
#             Debates
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="the-interpreter/contributors" href="/the-interpreter/contributors">
#             Contributors
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/8" href="/the-interpreter/about-interpreter">
#             About
#            </a>
#           </li>
#          </ul>
#          <div id="subhead-mobile">
#          </div>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </header>
#     <div id="subhead">
#      <div class="container">
#       <div class="region region-interpreter-subheader">
#        <div id="block-interpretersocialblock">
#         <div class="row">
#          <div class="col-sm-6">
#           <p class="txt-muted txt-tu">
#            Published daily by the
#            <a class="txt-dn" href="https://www.lowyinstitute.org">
#             <strong>
#              Lowy Institute
#             </strong>
#            </a>
#           </p>
#          </div>
#          <div class="col-sm-6 txt-right">
#           <ul class="clearfix list-unstyled pull-right">
#            <li class="pull-left">
#             <a class="txt-dn d-b txt-muted" href="http://www.facebook.com/LowyInstitute" target="_blank">
#              <i class="icon icon-social-facebook">
#              </i>
#             </a>
#            </li>
#            <li class="pull-left">
#             <a class="txt-dn d-b txt-muted" href="http://www.twitter.com/LowyInstitute" target="_blank">
#              <i class="icon icon-social-twitter">
#              </i>
#             </a>
#            </li>
#            <li class="pull-left">
#             <a class="txt-dn d-b txt-muted" href="http://www.linkedin.com/company/457230" target="_blank">
#              <i class="icon icon-social-linkedin">
#              </i>
#             </a>
#            </li>
#            <li class="pull-left">
#             <a class="txt-dn d-b txt-muted" href="/the-interpreter/rss.xml" target="_blank">
#              <i class="icon icon-social-rss">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <main role="main">
#      <div class="main-content__wrapper container">
#       <a id="main-content" tabindex="-1">
#       </a>
#       <div class="layout-content">
#        <div class="region region-content">
#         <div class="hidden" data-drupal-messages-fallback="">
#         </div>
#         <div id="block-lowy-content">
#          <article about="/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" class="node-type-interpreter-debate" data-history-node-id="34326">
#           <div class="interpreter-article-detail archive-detail-page node-type-interpreter-debate">
#            <div class="container pv-lg">
#             <div class="article-masthead row txt-center">
#              <div class="article-title col-sm-offset-2 col-sm-8 pv-sm">
#               <h1 class="txt-f4 txt-s7 balance-text">
#                Powerhouse: clean energy transitions in the Indo-Pacific
#               </h1>
#              </div>
#              <div class="article-author pv-md col-sm-offset-3 col-sm-6">
#               <a class="txt-dn txt-f1 txt-s3 txt-tu" href="/the-interpreter/contributors/articles/parul-bakshi">
#                Parul Bakshi
#               </a>
#              </div>
#              <div class="article-summary col-sm-offset-1 col-sm-10">
#               <p class="txt-s5 txt-f1 balance-text txt-lmd">
#                Energy security is shifting to new interdependencies based on alternate fuels and rare earths.
#               </p>
#              </div>
#             </div>
#             <div class="article-main-image">
#              <img alt="The critical minerals essential to manufacturing solar and wind energy technologies will become increasingly important (Jonathan Cutrer/Flickr)" class="article-main-image-img" src="https://www.lowyinstitute.org/sites/default/files/styles/interpreter_article_image/public/2022-09/50503416718_b25c206dd3_k_0.jpg?itok=yaYkj2S2"/>
#              <div class="article-save-btn">
#              </div>
#              <div class="article-main-image-caption">
#               The critical minerals essential to manufacturing solar and wind energy technologies will become increasingly important (Jonathan Cutrer/Flickr)
#              </div>
#             </div>
#             <div class="clearfix">
#              <div class="txt-center pv-md">
#               <span class="txt-muted">
#                Published 13 Sep 2022
#               </span>
#               <ul class="article-tags d-ib list-unstyled">
#                <li class="article-tag d-ib">
#                 <a class="txt-muted txt-dn" href="/the-interpreter/archive?issue=195">
#                  Asia
#                 </a>
#                </li>
#                <li class="article-tag d-ib">
#                 <a class="txt-muted txt-dn" href="/the-interpreter/archive?issue=355">
#                  Energy
#                 </a>
#                </li>
#               </ul>
#               <span class="rm-twiter-acc https://twitter.com/@ParulBakshi_">
#                <a class="txt-dn" href="https://twitter.com/@ParulBakshi_" target="_blank">
#                 <span class="icon icon-social-twitter" style="vertical-align:middle">
#                 </span>
#                 Follow @ParulBakshi_
#                </a>
#               </span>
#              </div>
#              <div class="row">
#               <div class="col-sm-10 col-sm-offset-1">
#                <hr/>
#               </div>
#              </div>
#              <div class="row article-body">
#               <div class="col-md-offset-1 col-md-1">
#                <div class="pv-md article-share pin" data-bounds=".article-body" data-pin="">
#                 <ul class="list-unstyled clearfix">
#                  <li>
#                   <a class="txt-dn" href="https://www.facebook.com/sharer/sharer.php?u=https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" onclick="window.open(this.href, '', 'width=600, height=300');return false;" rel="noopener noreferrer" target="_blank">
#                    <i class="icon icon-social-facebook">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="txt-dn" href="javascript:void(0)" onclick="window.open('http://www.twitter.com/share?text=“Powerhouse%3A+clean+energy+transitions+in+the+Indo-Pacific”&amp;url=https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific','','width=600, height=400')">
#                    <i class="icon icon-social-twitter">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="txt-dn" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific&amp;title=Powerhouse%3A+clean+energy+transitions+in+the+Indo-Pacific&amp;summary=Powerhouse%3A+clean+energy+transitions+in+the+Indo-Pacific&amp;source=" onclick="javascript:window.open(this.href,
#     '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" rel="noopener noreferrer" target="_blank">
#                    <i class="icon icon-social-linkedin">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="txt-dn" href="mailto:?subject=Powerhouse%3A+clean+energy+transitions+in+the+Indo-Pacific&amp;body=https://www.lowyinstitute.org/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific">
#                    <i class="icon icon-mail">
#                    </i>
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="col-md-8 col-sm-10 col-sm-offset-1 col-md-offset-0 txt-s3 txt-f2 pv-lg">
#                <div class="article-content clearfix">
#                 <div>
#                  <p>
#                   With a global energy crisis underway due to rising
#                   <a href="https://blogs.worldbank.org/developmenttalk/energy-shock-could-sap-global-growth-years">
#                    prices
#                   </a>
#                   , coupled with a
#                   <a href="https://www.severe-weather.eu/long-range-2/winter-forecast-2022-2023-season-first-look-united-states-europe-fa/">
#                    forecast
#                   </a>
#                   of a harsh northern hemisphere winter and supply volatility brought on by the Russia–Ukraine war, all eyes are on the
#                   <a href="https://www.iea.org/news/support-for-fossil-fuels-almost-doubled-in-2021-slowing-progress-toward-international-climate-goals-according-to-new-analysis-from-oecd-and-iea">
#                    future of energy transition
#                   </a>
#                   . The Indo-Pacific will be at the centre of this transition, with rapidly expanding Southeast Asian economies and burgeoning populations forming a large share of the exponentially rising global energy demand.
#                  </p>
#                  <p>
#                   An energy transition is broadly defined as the pathway to transforming the energy mix towards low carbon, sustainable and renewable forms of energy. One of its key components is maintaining energy security. Traditionally, energy security has encapsulated the 4 As – availability, accessibility, affordability and acceptability – but scholars today also focus on defined aspects such as minimal vulnerability, enhanced resilience and equitable access to energy.
#                  </p>
#                  <p>
#                   Over the past decades, the classical distinction between importers and exporters of energy has blurred. A traditional importer such as the United States is today a crucial energy exporter after its shale gas
#                   <a href="https://www.strausscenter.org/energy-and-security-project/the-u-s-shale-revolution/">
#                    revolution
#                   </a>
#                   . Further transformations in the energy landscape due to the global clean energy transition are expected to augment the energy self-sufficiency ratio of nations as their dependency on domestic renewable sources increases, leading to improved energy security. While this might be the case, the belief that such transitions could lead to reduced volatility of energy security is far-fetched.
#                  </p>
#                  <div class="article-quote-right">
#                   The increasing risk of geopolitical turbulence makes it imperative to promote shared interests and principles of energy security in the region.
#                  </div>
#                  <p>
#                   The ongoing transition away from fossil fuels will usher in a growing reliance on procuring supplies of hydrogen, ammonia, biofuels and other alternatives. Renewables will therefore alter the arenas of energy interaction, transform traditional energy markets and mark a shift in trading partners while reshaping patterns of conflict and cooperation between countries. Since the Indo-Pacific will be a major energy hub that houses critical and strategic energy trade routes, this reshaping will be most pronounced in the region.
#                  </p>
#                  <p>
#                   Instances of such shifts are already evident in the urgency to decarbonise and diversify energy sources. In 2020, traditional oil giant Saudi Arabia demonstrated the world’s first successful
#                   <a href="https://www.aramco.com/en/news-media/news/2020/first-blue-ammonia-shipment">
#                    blue ammonia
#                   </a>
#                   supply network by producing and shipping 40 tonnes of high-grade low-carbon fuel to Japan. Similarly, Japanese oil company
#                   <a href="https://www.al-monitor.com/originals/2022/06/abu-dhabi-national-oil-company-sends-ammonia-japan#:~:text=Clean%20ammonia%20from%20Abu%20Dhabi,the%20Dutch%20chemical%20company%20OCI.">
#                    Inpex
#                   </a>
#                   successfully brought clean ammonia produced by the Abu Dhabi National Oil Company to Japan. Furthermore, Singapore was the major export destination of
#                   <a href="https://connect2india.com/global/export-Biodiesel-from-india#:~:text=Summary%20for%20the%20Indian%20Biodiesel,2020%20was%20914.35%20USD%20million%20.">
#                    biodiesel
#                   </a>
#                   from India in the 2020–21 financial year.
#                  </p>
#                  <figure class="align-center" role="group">
#                   <img alt="The blue ammonia injection point compressor at the Hawiyah Natural Gas Liquids Recovery Plant, operated by Saudi Aramco, in Hawiyah, Saudi Arabia (Maya Siddiqui/Bloomberg via Getty Images)" data-entity-type="file" data-entity-uuid="f149ba77-3687-4210-893c-fb3ea440bec1" height="683" loading="lazy" src="/sites/default/files/inline-images/GettyImages-1233713386.jpg" width="1024"/>
#                   <figcaption>
#                    The blue ammonia injection point compressor at the Hawiyah Natural Gas Liquids Recovery Plant, operated by Saudi Aramco, in Hawiyah, Saudi Arabia (Maya Siddiqui/Bloomberg via Getty Images)
#                   </figcaption>
#                  </figure>
#                  <p>
#                   Meanwhile, key Indo-Pacific players such as Japan and Australia are fuelling their bilateral relationship through hydrogen, with the world’s first
#                   <a href="https://www.pinsentmasons.com/out-law/news/worlds-first-liquefied-hydrogen-ship-completes-voyage-in-japan">
#                    liquefied hydrogen
#                   </a>
#                   carrier ship completing its
#                   <a href="https://www.lowyinstitute.org/the-interpreter/japan-australia-building-hydrogen-supply-chain">
#                    maritime transport
#                   </a>
#                   of the fuel from Victoria to Kobe in February this year.
#                   <a href="https://swarajyamag.com/infrastructure/india-targets-low-production-cost-for-green-hydrogen-aims-to-become-export-hub">
#                    India
#                   </a>
#                   is also preparing to jump on the hydrogen exporter bandwagon. Among the Association of Southeast Asian Nations (ASEAN), Singapore imported hydropower-generated clean electricity from
#                   <a href="https://www.bloomberg.com/news/articles/2022-06-23/singapore-imports-clean-power-for-first-time-buying-from-laos">
#                    Laos
#                   </a>
#                   via Thailand and Malaysia through grid interconnections for the first time in June. Countries such as
#                   <a href="https://www.iea.org/reports/southeast-asia-energy-outlook-2022/key-findings">
#                    Brunei
#                   </a>
#                   have also started exporting small quantities of hydrogen to Japan. Although new and emerging interdependent energy relations are forming within the Indo-Pacific, fault lines have also emerged, with
#                   <a href="https://www.scmp.com/week-asia/opinion/article/3183786/indonesias-green-energy-export-ban-puts-aseans-power-grid-plans">
#                    Indonesia
#                   </a>
#                   recently announcing a ban on green energy export, putting a halt to the vision of an integrated ASEAN power grid.
#                  </p>
#                  <div class="article-quote-right">
#                   Diversifying the sources of rare earths and enabling stable supply becomes imperative to expanding renewable energies and ensuring energy security.
#                  </div>
#                  <p>
#                   In countries such as
#                   <a href="https://www.sbs.com.au/news/article/peter-dutton-put-nuclear-power-back-on-the-table-will-it-work-in-australia/jwockpjb1">
#                    Australia
#                   </a>
#                   , in an attempt to secure energy supplies while meeting sustainability goals, nuclear energy is again being debated as a potential addition to the energy mix. However,  a rise in the use of nuclear power would result in an increased reliance on uranium
#                   <a href="https://economictimes.indiatimes.com/news/india/india-to-import-100-tonne-of-uranium-to-power-nuclear-power-plants-in-fy23/articleshow/90561182.cms">
#                    imports
#                   </a>
#                   for many countries. It is interesting to note here that Russia is a key exporter of uranium to the
#                   <a href="https://www.washingtonpost.com/politics/2022/04/20/does-russia-sell-nearly-1-billion-uranium-us-year/">
#                    United States
#                   </a>
#                   and
#                   <a href="https://www.spglobal.com/marketintelligence/en/news-insights/latest-news-headlines/eu-eyes-more-nuclear-energy-but-still-reliant-on-russia-as-uranium-market-surges-69307111">
#                    European Union
#                   </a>
#                   , and with the fuel not being subject to the ongoing Russian sanctions, it adds to the debate on reliance on Russia and energy security.
#                  </p>
#                  <p>
#                   With the continuous growth in solar and wind energy across the region, the critical minerals essential to manufacturing these technologies will become increasingly important. Since these
#                   <a href="https://thediplomat.com/2022/01/rare-earths-fighting-for-the-fuel-of-the-future/">
#                    rare earths
#                   </a>
#                   are concentrated in specific nations, particularly China, diversifying the sources and enabling stable supply becomes imperative to expanding renewable energies and ensuring energy security.
#                  </p>
#                  <p>
#                   In 2010, China imposed an
#                   <a href="https://www.nytimes.com/2010/09/23/business/global/23rare.html">
#                    export ban
#                   </a>
#                   on rare earths to Japan due to a territorial dispute. It is anticipated that the energy-intensive undertones of China’s flagship
#                   <a href="https://www.eurobiz.com.cn/the-role-of-energy-within-bri/">
#                    Belt and Road Initiative
#                   </a>
#                   will impact the geopolitics around energy trade routes, especially in the Indo-Pacific. Such a scenario increases the need for regional countries to embark on a strategy to secure energy supply routes and affordable energy supplies. Recently,
#                   <a href="https://m.koreatimes.co.kr/pages/article.asp?newsIdx=335214">
#                    South Korea and Mongolia
#                   </a>
#                   and
#                   <a href="https://www.hindustantimes.com/world-news/india-australia-discuss-cooperation-in-rare-earth-minerals-101656936473519.html">
#                    India and Australia
#                   </a>
#                   agreed to boost cooperation on global supply chains, especially concerning rare earths.
#                  </p>
#                  <p>
#                   As China and Russia continue to weaponise these supply capacities to exert geopolitical leverage to coerce other countries for their political purposes, it highlights the prominence of geopolitics of energy. The increasing risk of geopolitical turbulence, as seen recently with growing tensions in
#                   <a href="https://thediplomat.com/2022/08/crossing-the-line-the-makings-of-the-4th-taiwan-strait-crisis/">
#                    Taiwan
#                   </a>
#                   , makes it imperative to promote shared interests and principles of energy security in the region.
#                  </p>
#                  <p>
#                   The future of smooth energy transitions and the development of a peaceful and stable Indo-Pacific rely on a deeper understanding of evolving energy security and fostering a rules-based order safeguarding the same. As the Indo-Pacific comes under the spotlight with major players attempting to expand their influence, energy can act as a means to further relations and interests. Dialogues such as the
#                   <a href="https://www.pmc.gov.au/international-policy/sydney-energy-forum">
#                    Sydney Energy Forum
#                   </a>
#                   are setting the stage. But is the Indo-Pacific prepared for the new contours of energy security?
#                  </p>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="row pv-md">
#              <div class="col-sm-4 col-sm-offset-4">
#               <hr/>
#              </div>
#             </div>
#             <div class="pv-lg">
#              <div class="article-card article-card-related">
#               <h4>
#                Related Content
#               </h4>
#               <div class="views-field views-field-field-blog-main-image">
#                <div class="field-content">
#                 <a href="/the-interpreter/national-champion-departs-scene-china-food-fight-looms">
#                  <img alt="Treasurer Josh Frydenberg (Sam Mooy/Getty Images)" class="img-responsive" src="https://www.lowyinstitute.org/sites/default/files/styles/large/public/GettyImages-1288483841-min.jpg?itok=vFILP4zX"/>
#                 </a>
#                </div>
#               </div>
#               <div class="views-field views-field-title">
#                <h2 class="field-content">
#                 <a href="/the-interpreter/national-champion-departs-scene-china-food-fight-looms">
#                  As a national champion departs the scene, a China food fight looms
#                 </a>
#                </h2>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="container">
#             <hr/>
#             <div class="row pv-md">
#              <div class="col-sm-6 pv-sm txt-sm-center prev">
#               <span class="txt-dn txt-tu txt-w700">
#                Previous Article
#               </span>
#               <br/>
#               <a class="txt-s3 txt-dn" href="/the-interpreter/aukus-one-year">
#                AUKUS, one year on
#               </a>
#              </div>
#              <div class="col-sm-6 pv-sm txt-right txt-sm-center next">
#               <span class="txt-dn txt-tu txt-w700">
#                Next Article
#               </span>
#               <br/>
#               <a class="txt-s3 txt-dn" href="/the-interpreter/quad-needs-stronger-economic-message">
#                The Quad needs a stronger economic message
#               </a>
#              </div>
#             </div>
#             <hr/>
#             <div class="row pv-sm">
#              <div class="col-md-2 pv-md">
#               <h4 class="txt-w700 txt-tu txt-lmd">
#                You may also be interested in
#               </h4>
#              </div>
#              <div class="col-md-10">
#               <div class="row row-first">
#                <div class="col-sm-4">
#                 <article about="/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" class="node-type-interpreter-debate" data-history-node-id="34326" id="node-">
#                  <div class="article-meta pv-xs txt-s1">
#                   <span class="article-author">
#                    <a class="txt-dn txt-tu" href="/people/contributor/bio/grant-wyeth">
#                     Grant Wyeth
#                    </a>
#                   </span>
#                   <span class="article-date txt-pnum txt-muted rm-tab-date">
#                    6 Oct 2021 06:00
#                   </span>
#                  </div>
#                  <a class="article-thumb-wrap" href="/the-interpreter/aukus-what-happens-if-republicans-play-trump-card">
#                   <div class="article-thumb" style="background-image: url('https://www.lowyinstitute.org/sites/default/files/styles/large/public/Cards.jpg?itok=t54ALzcq'">
#                   </div>
#                  </a>
#                  <div class="article-title">
#                   <h3>
#                    <a href="/the-interpreter/aukus-what-happens-if-republicans-play-trump-card">
#                     AUKUS: What happens if the Republicans play the Trump card?
#                    </a>
#                   </h3>
#                  </div>
#                  <div class="pv-sm">
#                   <div class="article-precede">
#                    A White House change of guard could mean Australia needs to reassess its values under a more nihilistic regime.
#                   </div>
#                  </div>
#                 </article>
#                </div>
#                <div class="col-sm-4">
#                 <article about="/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" class="node-type-interpreter-debate" data-history-node-id="34326" id="node-">
#                  <div class="article-meta pv-xs txt-s1">
#                   <span class="article-author">
#                    <a class="txt-dn txt-tu" href="/people/contributor/bio/erin-hurley">
#                     Erin Hurley
#                    </a>
#                   </span>
#                   <span class="article-date txt-pnum txt-muted rm-tab-date">
#                    19 Apr 2021 10:00
#                   </span>
#                  </div>
#                  <a class="article-thumb-wrap" href="/the-interpreter/america-china-imagining-worst">
#                   <div class="article-thumb" style="background-image: url('https://www.lowyinstitute.org/sites/default/files/styles/large/public/28506541931_b520b69f73_k.jpg?itok=gVk1j60t'">
#                   </div>
#                  </a>
#                  <div class="article-title">
#                   <h3>
#                    <a href="/the-interpreter/america-china-imagining-worst">
#                     America and China: Imagining the worst
#                    </a>
#                   </h3>
#                  </div>
#                  <div class="pv-sm">
#                   <div class="article-precede">
#                    A little well-crafted speculation can shake off complacency and allow people to focus on the true challenge.
#                   </div>
#                  </div>
#                 </article>
#                </div>
#                <div class="col-sm-4">
#                 <article about="/the-interpreter/powerhouse-clean-energy-transitions-indo-pacific" class="node-type-interpreter-debate" data-history-node-id="34326" id="node-">
#                  <div class="article-meta pv-xs txt-s1">
#                   <span class="article-author">
#                    <a class="txt-dn txt-tu" href="/people/contributor/bio/casper-wuite">
#                     Casper Wuite
#                    </a>
#                   </span>
#                   <span class="article-date txt-pnum txt-muted rm-tab-date">
#                    17 Mar 2017 09:01
#                   </span>
#                  </div>
#                  <a class="article-thumb-wrap" href="/the-interpreter/eu-shouldn-t-strike-turkey-style-deal-libya">
#                   <div class="article-thumb" style="background-image: url('https://www.lowyinstitute.org/sites/default/files/styles/large/public/cropped%20refugee.jpg?itok=uHYGTzVu'">
#                   </div>
#                  </a>
#                  <div class="article-title">
#                   <h3>
#                    <a href="/the-interpreter/eu-shouldn-t-strike-turkey-style-deal-libya">
#                     The EU shouldn’t strike a Turkey-style deal with Libya
#                    </a>
#                   </h3>
#                  </div>
#                  <div class="pv-sm">
#                   <div class="article-precede">
#                    The EU should use the tools at its disposal to find short-term fixes to the crisis; a Turkey-style deal is clearly not that.
#                   </div>
#                  </div>
#                 </article>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </article>
#         </div>
#        </div>
#       </div>
#      </div>
#     </main>
#     <footer id="footer">
#      <div class="container">
#       <div class="region region-interpreter-footer">
#        <div id="block-interpreterctablock">
#         <div class="footer-cta row pv-lg txt-s3">
#          <div class="col-sm-offset-2 col-sm-8 pv-sm">
#           <p class="txt-center balance-text txt-lmd">
#            Stay informed with the latest commentary and analysis on international events from experts at the Lowy Institute and around the world.
#           </p>
#          </div>
#          <div class="col-sm-6 col-sm-offset-3 col-md-offset-5 col-md-2 pv-sm">
#           <a class="btn btn-block btn-solid" href="https://portal.lowyinstitute.org/Account/Login/Register">
#            Register
#           </a>
#          </div>
#         </div>
#        </div>
#        <div id="block-interpreterfootermenublock">
#         <hr/>
#         <div class="footer-menu row pv-lg">
#          <div class="col-sm-4 col-sm-offset-1 hidden-sm">
#           <p>
#            The Interpreter features in-depth analysis &amp; expert commentary on the latest international events, published daily by the
#            <a href="https://www.lowyinstitute.org">
#             <strong>
#              Lowy Institute
#             </strong>
#            </a>
#            .
#           </p>
#           <p class="txt-muted txt-tu">
#            © Copyright 2024
#            <a class="txt-dn" href="https://www.lowyinstitute.org">
#             <strong>
#              Lowy Institute
#             </strong>
#            </a>
#           </p>
#          </div>
#          <div class="col-sm-6 col-sm-offset-1">
#           <ul class="list-unstyled footer-links">
#            <li>
#             <a href="/the-interpreter/debate">
#              Debates
#             </a>
#            </li>
#            <li>
#             <a href="/the-interpreter/contributors">
#              Contributors
#             </a>
#            </li>
#            <li>
#             <a href="/the-interpreter/archive">
#              Articles
#             </a>
#            </li>
#            <li>
#             <a href="/the-interpreter/about-interpreter">
#              About
#             </a>
#            </li>
#            <li>
#             <a href="/the-interpreter/terms-use-content-supply-terms">
#              Terms of Use
#             </a>
#            </li>
#            <li>
#             <a href="https://portal.lowyinstitute.org/Account/Login/" target="_self">
#              Log In
#             </a>
#            </li>
#            <li>
#             <a href="https://www.lowyinstitute.org/the-interpreter/saved-items">
#              My bookmarks
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script src="https://digitalgarden.atlassian.net/s/d41d8cd98f00b204e9800998ecf8427e-T/-onpk8x/b/7/c95134bc67d3a521bb3f4331beb9b804/_/download/batch/com.atlassian.jira.collector.plugin.jira-issue-collector-plugin:issuecollector/com.atlassian.jira.collector.plugin.jira-issue-collector-plugin:issuecollector.js?locale=en-US&amp;collectorId=8667749d" type="text/javascript">
#   </script>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","pathPrefix":"","currentPath":"node\/34326","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"eJxdjkEOwkAIRS9E5UgNbRiCUpgMJDq3t9rEhZuXl7f5v6kVD9ypl4ZDMxL84Gbqj5Xu9IIWUR7FiT8DiRDjlZxslu6J_wEsnhPFYiO7XP0c6oNPLp2Er3rE4KV9TyTkzOIDN0p-A8_XO6c","theme":"lowy","theme_token":null},"ajaxTrustedUrl":{"form_action_p_pvdeGsVG5zNF_XLGPTvYSKCf43t8qZYSwcfZl2uzM":true},"google_analytics":{"account":"UA-3115931-1","trackOutbound":1,"trackMailto":1,"trackTel":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"user":{"uid":0,"permissionsHash":"5976d1e1e924d920375d5335dc5a6131a18176c919ce71da23f9fbccae174380"}}
#   </script>
#   <script src="/sites/default/files/js/js_nrN4i5nC_etT6L06LOw-0L90rdcqzazW1lknw-TlZq4.js?scope=footer&amp;delta=0&amp;language=en&amp;theme=lowy&amp;include=eJxdiVEOgCAMxS4EciQyzVimT0aQRLm9GP3yp2laMRNwpEzoTZcjyC842NmDwGbC67tV9knRuH5X8_BSedAXEnYJJOHBBM1bpJWuG55oKSA">
#   </script>
#  </body>
# </html>

# %%
paragraphs = soup.find_all('p')

# %%
main_content = soup.find('div', {'class': 'article-content clearfix'})
for element in main_content(['a']):
    element.decompose()
    
text_list = []
for paragraph in main_content.find_all('p'):
    paragraph_text = paragraph.get_text(separator=' ', strip=True)
    text_list.append(paragraph_text)

# %%
df = pd.DataFrame(text_list, columns=["Paragraph Text"])
df.to_csv('04_paragraphs.csv', index=False)

# %%
df
# Out:
#                                        Paragraph Text
# 0   With a global energy crisis underway due to ri...
# 1   An energy transition is broadly defined as the...
# 2   Over the past decades, the classical distincti...
# 3   The ongoing transition away from fossil fuels ...
# 4   Instances of such shifts are already evident i...
# 5   Meanwhile, key Indo-Pacific players such as Ja...
# 6   In countries such as , in an attempt to secure...
# 7   With the continuous growth in solar and wind e...
# 8   In 2010, China imposed an on rare earths to Ja...
# 9   As China and Russia continue to weaponise thes...
# 10  The future of smooth energy transitions and th...

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/loogyee/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/loogyee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/loogyee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('04_paragraphs.csv')

# %%
# Preprocessing 
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # Lowercase the entire text
    text = text.lower()
    
    # Tokenize and lemmatize
    lemmatized_words = []
    for word in text.split():  # Split the text into words
        lemmatized_words.append(lemmatizer.lemmatize(word))  # Lemmatize each word
    
    # Join lemmatized words back into a single string
    cleaned_text = ' '.join(lemmatized_words)
    
    return cleaned_text

# %%
df['Processed Text'] = df['Paragraph Text'].apply(preprocess_text)

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/loogyee/anaconda3/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz (12.8 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
relationship_keywords = {'collaboration', 'cooperation', 'partner', 'engage', 
                         'support', 'fund', 'finance', 'invest', 'develop', 
                         'supply', 'promote', 'transition', 'export', 'agreement', 
                         'interest', 'share', 'enhance', 'effort', 'import'}

# %%
def extract_entities_and_relationships(text):
    doc = nlp(text)  # Process text with spaCy
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['ORG', 'GPE']]

    # Find relationships based on keywords
    relationships = []
    for token in doc:
        if token.text in relationship_keywords:  # Check if the token matches any relationship keyword
            subject = [w for w in token.children if w.dep_ == "nsubj"]  # Find the subject
            object_ = [w for w in token.children if w.dep_ == "dobj"]  # Find the direct object
            if subject and object_:
                relationships.append((subject[0].text, token.text, object_[0].text))  # (subject, relationship keyword, object)

    return entities, relationships

# %%
df['Entities'], df['Relationships'] = zip(*df['Processed Text'].apply(extract_entities_and_relationships))

# %%
df[['Processed Text', 'Entities', 'Relationships']]
# Out:
#                                        Processed Text  \
# 0   with a global energy crisis underway due to ri...
# 1   an energy transition is broadly defined a the ...
# 2   over the past decades, the classical distincti...
# 3   the ongoing transition away from fossil fuel w...
# 4   instance of such shift are already evident in ...
# 5   meanwhile, key indo-pacific player such a japa...
# 6   in country such a , in an attempt to secure en...
# 7   with the continuous growth in solar and wind e...
# 8   in 2010, china imposed an on rare earth to jap...
# 9   a china and russia continue to weaponise these...
# 10  the future of smooth energy transition and the...
#
#                                              Entities Relationships
# 0                                     [(russia, GPE)]            []
# 1                                                  []            []
# 2                           [(the united state, GPE)]            []
# 3                                   [(hydrogen, GPE)]            []
# 4   [(saudi arabia, GPE), (japan, GPE), (the abu d...            []
# 5   [(japan, GPE), (australia, GPE), (asean), ORG)...            []
# 6                      [(russia, GPE), (russia, GPE)]            []
# 7                                      [(china, GPE)]            []
# 8          [(china, GPE), (japan, GPE), (china, GPE)]            []
# 9                       [(china, GPE), (russia, GPE)]            []
# 10                                                 []            []

# %%
for index, row in df.iterrows():
    print(f"\nParagraph {index + 1}:")
    print(row['Paragraph Text'])

    # Display dependency parsing
    doc = nlp(row['Processed Text'])
    sentence_spans = list(doc.sents)
    displacy.render(sentence_spans, style='dep', jupyter=True, options={'compact': True})
    
    # Display named entities
    displacy.render(sentence_spans, style="ent", jupyter=True)

    # Print extracted entities and relationships
    print("Entities:", row['Entities'])
# Out:
# Paragraph 1:
# With a global energy crisis underway due to rising , coupled with a of a harsh northern hemisphere winter and supply volatility brought on by the Russia–Ukraine war, all eyes are on the . The Indo-Pacific will be at the centre of this transition, with rapidly expanding Southeast Asian economies and burgeoning populations forming a large share of the exponentially rising global energy demand.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bc1864d7b3864c75856098fea387f9c4-0" class="displacy" width="5000" height="887.0" direction="ltr" style="max-width: none; height: 887.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">crisis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">underway</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">due</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">rising ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">coupled</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">harsh</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">northern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">hemisphere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">winter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">supply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">volatility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">brought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">russia–</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">ukraine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">war,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">eye</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="455
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">with a global energy crisis underway due to rising , coupled with a of a harsh northern hemisphere
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and supply volatility brought on by the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# –ukraine war, all eye are on the . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">the indo-pacific will be at the centre of this transition, with rapidly expanding
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     southeast asian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  economy and burgeoning population forming a large share of the exponentially rising global energy demand.</div></span>
# Entities: [('russia', 'GPE')]
#
# Paragraph 2:
# An energy transition is broadly defined as the pathway to transforming the energy mix towards low carbon, sustainable and renewable forms of energy. One of its key components is maintaining energy security. Traditionally, energy security has encapsulated the 4 As – availability, accessibility, affordability and acceptability – but scholars today also focus on defined aspects such as minimal vulnerability, enhanced resilience and equitable access to energy.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="36da04a2bf954c2da9b93103802c9193-0" class="displacy" width="3500" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">transition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">broadly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">defined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">pathway</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">transforming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">mix</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">towards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">low</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">carbon,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">sustainable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">renewable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">form</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">energy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-36da04a2bf954c2da9b93103802c9193-0-0" stroke-width="2px" d="M62,377.0 62,327.0 341.0,327.0 341.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-36da04a2bf954c2da9b93103802c9193-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-36da04a2bf954c2da9b93103802c9193-0-1" stroke-width="2px" d="M212,377.0 212,352.0 338.0,352.0 338.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-36da04a2bf954c2da9b93103802c9193-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-36da04a2bf954c2da9b93103802c9193-0-2" stroke-width="2px" d="M362,377.0 362,302.0 794.0,302.0 794.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-36da04a2bf954c2da9b93103802c9193-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-36da04a2bf954c2da9b93103802c9193-0-3" stroke-width="2px" d="M512,377.0 512,327.0 791.0,327.0 791.0,377.0" fill="none" stroke="currentColor"/>
#     <
# /Users/loogyee/anaconda3/lib/python3.11/site-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">an energy transition is broadly defined a the pathway to transforming the energy mix towards low carbon, sustainable and renewable form of energy. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of it key component is maintaining energy security. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">traditionally, energy security ha encapsulated the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  a – availability, accessibility, affordability and acceptability – but scholar
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  also focus on defined aspect such a minimal vulnerability, enhanced resilience and equitable access to energy.</div></span>
# Entities: []
#
# Paragraph 3:
# Over the past decades, the classical distinction between importers and exporters of energy has blurred. A traditional importer such as the United States is today a crucial energy exporter after its shale gas . Further transformations in the energy landscape due to the global clean energy transition are expected to augment the energy self-sufficiency ratio of nations as their dependency on domestic renewable sources increases, leading to improved energy security. While this might be the case, the belief that such transitions could lead to reduced volatility of energy security is far-fetched.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="be4fb246b41242119cffa25f70d4f496-0" class="displacy" width="2300" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">past</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">decades,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">classical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">distinction</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">importer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">exporter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">ha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">blurred.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-0" stroke-width="2px" d="M62,377.0 62,252.0 2150.0,252.0 2150.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-1" stroke-width="2px" d="M212,377.0 212,327.0 491.0,327.0 491.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-2" stroke-width="2px" d="M362,377.0 362,352.0 488.0,352.0 488.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-3" stroke-width="2px" d="M62,377.0 62,302.0 494.0,302.0 494.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M494.0,379.0 L498.0,371.0 490.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-4" stroke-width="2px" d="M662,377.0 662,327.0 941.0,327.0 941.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,379.0 L658,371.0 666,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-5" stroke-width="2px" d="M812,377.0 812,352.0 938.0,352.0 938.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,379.0 L808,371.0 816,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be4fb246b41242119cffa25f70d4f496-0-6" stroke-width="2px" d="M962,377.0 962,277.0 2147.0,277.0 2147.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be4fb246b41242119cffa25f70d4f496-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the classical distinction between importer and exporter of energy ha blurred. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">a traditional importer such a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the united state
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  a crucial energy exporter after it shale gas . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">further transformation in the energy landscape due to the global clean energy transition are expected to augment the energy self-sufficiency ratio of nation a their dependency on domestic renewable source increases, leading to improved energy security. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">while this might be the case, the belief that such transition could lead to reduced volatility of energy security is far-fetched.</div></span>
# Entities: [('the united state', 'GPE')]
#
# Paragraph 4:
# The ongoing transition away from fossil fuels will usher in a growing reliance on procuring supplies of hydrogen, ammonia, biofuels and other alternatives. Renewables will therefore alter the arenas of energy interaction, transform traditional energy markets and mark a shift in trading partners while reshaping patterns of conflict and cooperation between countries. Since the Indo-Pacific will be a major energy hub that houses critical and strategic energy trade routes, this reshaping will be most pronounced in the region.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8335acabd2da4d158fe4029056754670-0" class="displacy" width="3500" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">ongoing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">transition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">away</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">fossil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">fuel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">usher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">growing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">reliance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">procuring</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">supply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">hydrogen,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">ammonia,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">biofuels</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">alternatives.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8335acabd2da4d158fe4029056754670-0-0" stroke-width="2px" d="M62,227.0 62,177.0 347.0,177.0 347.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8335acabd2da4d158fe4029056754670-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8335acabd2da4d158fe4029056754670-0-1" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8335acabd2da4d158fe4029056754670-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8335acabd2da4d158fe4029056754670-0-2" stroke-width="2px" d="M362,227.0 362,152.0 1250.0,152.0 1250.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8335acabd2da4d158fe4029056754670-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8335acabd2da4d158fe4029056754670-0-3" stroke-width="2px" d="M362,227.0 362,202.0 494.0,202.0 494.0,227.0" fill="none" stroke="currentColor"/>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the ongoing transition away from fossil fuel will usher in a growing reliance on procuring supply of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hydrogen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , ammonia, biofuels and other alternatives. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">renewables will therefore alter the arena of energy interaction, transform traditional energy market and mark a shift in trading partner while reshaping pattern of conflict and cooperation between countries. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">since the indo-pacific will be a major energy hub that house critical and strategic energy trade routes, this reshaping will be most pronounced in the region.</div></span>
# Entities: [('hydrogen', 'GPE')]
#
# Paragraph 5:
# Instances of such shifts are already evident in the urgency to decarbonise and diversify energy sources. In 2020, traditional oil giant Saudi Arabia demonstrated the world’s first successful supply network by producing and shipping 40 tonnes of high-grade low-carbon fuel to Japan. Similarly, Japanese oil company successfully brought clean ammonia produced by the Abu Dhabi National Oil Company to Japan. Furthermore, Singapore was the major export destination of from India in the 2020–21 financial year.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="deb9bd4c778d4c0ab355e62b436a4ebd-0" class="displacy" width="2450" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">instance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">such</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">shift</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">already</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">evident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">urgency</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">decarbonise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">diversify</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">sources.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-0" stroke-width="2px" d="M62,302.0 62,227.0 647.0,227.0 647.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-1" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M191.0,304.0 L195.0,296.0 187.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-3" stroke-width="2px" d="M212,302.0 212,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M494.0,304.0 L498.0,296.0 490.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-deb9bd4c778d4c0ab355e62b436a4ebd-0-4" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# ...
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">capacity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">exert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">geopolitical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">leverage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">coerce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">political</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">purposes,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">highlight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">prominence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">geopolitics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">energy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-17685642b6e54d708bc9eda4b130e933-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stro
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  continue to weaponise these supply capacity to exert geopolitical leverage to coerce other country for their political purposes, it highlight the prominence of geopolitics of energy. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">the increasing risk of geopolitical turbulence, a seen recently with growing tension in , make it imperative to promote shared interest and principle of energy security in the region.</div></span>
# Entities: [('china', 'GPE'), ('russia', 'GPE')]
#
# Paragraph 11:
# The future of smooth energy transitions and the development of a peaceful and stable Indo-Pacific rely on a deeper understanding of evolving energy security and fostering a rules-based order safeguarding the same. As the Indo-Pacific comes under the spotlight with major players attempting to expand their influence, energy can act as a means to further relations and interests. Dialogues such as the are setting the stage. But is the Indo-Pacific prepared for the new contours of energy security?
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1fbfc4252f584e9e9e7e34ca6100cdc7-0" class="displacy" width="5150" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">future</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">smooth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">transition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">development</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">peaceful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">stable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">indo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">pacific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">rely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">deeper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">understanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">evolving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">security</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">fostering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">rules-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curre
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the future of smooth energy transition and the development of a peaceful and stable indo-pacific rely on a deeper understanding of evolving energy security and fostering a rules-based order safeguarding the same. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">a the indo-pacific come under the spotlight with major player attempting to expand their influence, energy can act a a mean to further relation and interests. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">dialogue such a the are setting the stage. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">but is the indo-pacific prepared for the new contour of energy security?</div></span>
# Entities: []

# %%
entity1_list = []
relationship_list = []
entity2_list = []
date_list = []
money_list = []

# %%
# Iterate through each paragraph
for index, row in df.iterrows():
    doc = nlp(row['Paragraph Text'])  # Process the paragraph with spaCy

    for sent in doc.sents:
        # Extract named entities (countries, organizations)
        entities = []
        money_in_sentence = []

        for ent in sent.ents:
            if ent.label_ == 'Initiative' in ent.text:
                entities.append(ent._replace(label_='POL'))  # Change label for specific case
            elif ent.label_ in ['GPE', 'ORG', 'POL', 'MONEY']:
                entities.append(ent)

            # Collect monetary amounts
            if ent.label_ == "MONEY":
                money_in_sentence.append(ent.text)
        
        # Look for verbs or specific relationship nouns in the sentence
        verbs = [token for token in sent if token.pos_ == "VERB"]
        keywords_in_sentence = [token.text for token in sent if token.lemma_ in relationship_keywords]
        
        # Extract dates
        dates = [ent.text for ent in sent.ents if ent.label_ == "DATE"]

        # If we find two entities and a relationship keyword, we assume a relationship
        if len(entities) >= 2 and keywords_in_sentence:
            entity1_list.append(entities[0].text)

            # Concatenate the relationship noun and verb (if available) into one string
            relationship_info = keywords_in_sentence[0]
            if verbs:
                relationship_info += " (verb: " + verbs[0].lemma_ + ")"

            relationship_list.append(relationship_info)  # Store concatenated info
            entity2_list.append(entities[1].text)
            date_list.append(dates[0] if dates else "n/a")
            money_list.append(money_in_sentence[0] if money_in_sentence else "n/a")

# %%
# DataFrame
extracted_data = pd.DataFrame({
    "Entity1": entity1_list,
    "Relationship": relationship_list,
    "Entity2": entity2_list,
    "Date": date_list,
    "Money": money_list
})

# %%
extracted_data
# Out:
#                                       Entity1                Relationship  \
# 0                                Saudi Arabia  supply (verb: demonstrate)
# 1                                   Singapore                      export
# 2  the Association of Southeast Asian Nations     imported (verb: import)
# 3                            the Indo-Pacific       export (verb: emerge)
# 4                                       China     supply (verb: continue)
#
#   Entity2                        Date Money
# 0   Japan                        2020   n/a
# 1   India  the 2020–21 financial year   n/a
# 2   ASEAN                        June   n/a
# 3   ASEAN                         n/a   n/a
# 4  Russia                         n/a   n/a

# %%
# Export to csv
extracted_data.to_csv('04_relationships.csv', index=False)
