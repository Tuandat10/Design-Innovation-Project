# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = "https://www.csis.org/analysis/filling-indo-pacific-economic-framework"
response = requests.get(url)

# %%
soup=BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="bg-blue-800" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="CSIS experts Matthew P. Goodman and Bill Reinsch offer insight on how the Biden administration can fill in the gaps to craft a credible and durable Indo-Pacific economic framework (IPEF)." name="description"/>
#   <link href="https://www.csis.org/analysis/filling-indo-pacific-economic-framework" rel="canonical"/>
#   <link href="https://csis-website-prod.s3.amazonaws.com/s3fs-public/publication/GettyImages-1184775451.jpg?VersionId=pvxKRzigR8t1SRFt2z5FXB9EoUgd7cJ3" rel="image_src"/>
#   <meta content="Filling In the Indo-Pacific Economic Framework" name="citation_title"/>
#   <meta content="Matthew P. Goodman" name="citation_author"/>
#   <meta content="William Alan Reinsch" name="citation_author"/>
#   <meta content="Wed, 01/26/2022 - 12:00" name="citation_publication_date"/>
#   <meta content="Filling In the Indo-Pacific Economic Framework" property="og:title"/>
#   <meta content="https://csis-website-prod.s3.amazonaws.com/s3fs-public/publication/GettyImages-1184775451.jpg?VersionId=pvxKRzigR8t1SRFt2z5FXB9EoUgd7cJ3" property="og:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="CSIS experts Matthew P. Goodman and Bill Reinsch offer insight on how the Biden administration can fill in the gaps to craft a credible and durable Indo-Pacific economic framework (IPEF)." name="twitter:description"/>
#   <meta content="Filling In the Indo-Pacific Economic Framework" name="twitter:title"/>
#   <meta content="@CSIS" name="twitter:site"/>
#   <meta content="https://csis-website-prod.s3.amazonaws.com/s3fs-public/publication/GettyImages-1184775451.jpg?VersionId=pvxKRzigR8t1SRFt2z5FXB9EoUgd7cJ3" name="twitter:image"/>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <script type="application/ld+json">
#    {
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Report",
#             "headline": "Filling In the Indo-Pacific Economic Framework",
#             "description": "CSIS experts Matthew P. Goodman and Bill Reinsch offer insight on how the Biden administration can fill in the gaps to craft a credible and durable Indo-Pacific economic framework (IPEF).",
#             "about": [
#                 "Climate Change",
#                 "Technology",
#                 "Data Governance",
#                 "Technology and Innovation",
#                 "Economics",
#                 "Trade and International Business"
#             ],
#             "image": {
#                 "@type": "ImageObject",
#                 "representativeOfPage": "True",
#                 "url": "https://csis-website-prod.s3.amazonaws.com/s3fs-public/publication/GettyImages-1184775451.jpg?VersionId=pvxKRzigR8t1SRFt2z5FXB9EoUgd7cJ3",
#                 "width": "2500",
#                 "height": "1872"
#             },
#             "isAccessibleForFree": "True",
#             "dateModified": "2024-07-03T12:13:01-0400",
#             "author": [
#                 {
#                     "@type": "Person",
#                     "@id": "https://www.csis.org/people/matthew-p-goodman",
#                     "name": "Matthew P. Goodman",
#                     "url": "https://www.csis.org/people/matthew-p-goodman"
#                 },
#                 {
#                     "@type": "Person",
#                     "@id": "https://www.csis.org/people/william-alan-reinsch",
#                     "name": "William Alan Reinsch",
#                     "url": "https://www.csis.org/people/william-alan-reinsch"
#                 }
#             ],
#             "publisher": {
#                 "@type": "Organization",
#                 "@id": "https://csis.org",
#                 "name": "Center for Strategic and International Studies",
#                 "url": "https://csis.org",
#                 "sameAs": [
#                     "https://www.facebook.com/CSIS.org",
#                     "https://twitter.com/csis",
#                     "https://www.instagram.com/csis/",
#                     "https://www.linkedin.com/company/csis",
#                     "https://www.youtube.com/user/csisdc"
#                 ]
#             },
#             "mainEntityOfPage": "https://www.csis.org/analysis/filling-indo-pacific-economic-framework"
#         }
#     ]
# }
#   </script>
#   <link href="/themes/custom/ts_csis/assets/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    Filling In the Indo-Pacific Economic Framework
#   </title>
#   <link href="/themes/composer/stable/css/system/components/ajax-progress.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/align.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/autocomplete-loading.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/fieldgroup.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/container-inline.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/clearfix.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/details.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/hidden.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/item-list.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/js.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/nowrap.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/position-container.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/progress.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/reset-appearance.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/resize.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/sticky-header.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/system-status-counter.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/system-status-report-counters.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/system-status-report-general-info.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/tabledrag.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/tablesort.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/composer/stable/css/system/components/tree-child.module.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/modules/custom/c2pa/css/c2pa.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="/themes/custom/ts_csis/dist/print.css?ske1qr" media="print" rel="stylesheet"/>
#   <link href="/themes/custom/ts_csis/dist/ts-csis.css?ske1qr" media="all" rel="stylesheet"/>
#   <link href="//use.typekit.net/mkb5tpc.css" media="all" rel="stylesheet"/>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","pathPrefix":"","currentPath":"node\/63758","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"csis_seo":{"entity_details":{"content_type":"report","program_related":"Scholl Chair in International Business|Economics Program","person_related":"Matthew P. Goodman|William Alan Reinsch","topic_related":"Climate Change|Technology|Data Governance|Technology and Innovation|Economics|Trade and International Business","region_related":"Asia","parent_related":"","month_published":"January","year_published":"2022","date_published":"Jan 26, 2022","page_type":"Report"},"gtm_id":"GTM-MNGQTH"},"csis_events":{"events_live_now":"Live Now","events_on_demand":"Video On Demand","events_live_in":"Live in"},"user":{"uid":0,"permissionsHash":"925b65726c370a469c3416788c7951288089108a421527f97dd2c4153ec8f963"}}
#   </script>
#   <script src="/themes/custom/ts_csis/node_modules/jquery/dist/jquery.min.js?ske1qr">
#   </script>
#   <script src="/core/misc/drupalSettingsLoader.js?v=10.2.6">
#   </script>
#   <script src="/modules/custom/csis_seo/js/csis_seo.js?ske1qr">
#   </script>
#   <script src="/modules/custom/csis_seo/js/csis_gtm.js?ske1qr">
#   </script>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MNGQTH" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <a class="btn-utility-outline btn-utility-outline--sm btn-skip-link absolute visually-hidden focusable text-high-contrast top-0 left-0 z-8" href="#main-content">
#    Skip to main content
#   </a>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <header class="page-header ts-bg-blue-800" role="banner">
#     <div class="region--primary-navigation has-nav-full ts-bg-blue-800 nav-text py-base lg:py-xl relative text-high-contrast nav-links z-7">
#      <div class="p-site xl:container">
#       <div class="basic">
#        <div class="flex items-center justify-between">
#         <div class="flex items-center justify-between">
#          <button aria-label="Main menu" class="menu-toggle mr-lg lg:mr-xl w-4xl" for="hamburger-checkbox">
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#          </button>
#          <div class="hidden lg:inline-block mr-md">
#           <button class="btn-mega-menu--programs btn-mega-dropdown">
#            <span class="btn-mega-dropdown--label visually-hidden">
#             open
#            </span>
#            <h2>
#             Programs
#             <span class="visually-hidden">
#              submenu
#             </span>
#             <span class="inline-block ml-sm">
#              <svg fill="none" viewbox="0 0 11 7" xmlns="http://www.w3.org/2000/svg">
#               <path d="M0 1.80338L1.83333 0L5.5 3.5L9.16667 0L11 1.80338L5.5 7L0 1.80338Z" fill="#080808">
#               </path>
#              </svg>
#             </span>
#            </h2>
#           </button>
#          </div>
#          <div class="hidden lg:inline-block mr-md">
#           <a class="ml-md" href="/experts">
#            Experts
#           </a>
#          </div>
#          <div>
#           <a aria-label="CSIS home" class="h-md w-3xl invisible-home-link-simple" href="/">
#           </a>
#          </div>
#         </div>
#         <div class="hidden lg:block">
#          <a aria-label="CSIS home" class="invisible-home-link" href="/">
#          </a>
#         </div>
#         <div>
#          <div class="hidden lg:inline-block mr-md">
#           <button class="btn-mega-menu--regions btn-mega-dropdown">
#            <span class="btn-mega-dropdown--label visually-hidden">
#             open
#            </span>
#            <h2>
#             Regions
#             <span class="visually-hidden">
#              submenu
#             </span>
#             <span class="inline-block ml-sm">
#              <svg fill="none" viewbox="0 0 11 7" xmlns="http://www.w3.org/2000/svg">
#               <path d="M0 1.80338L1.83333 0L5.5 3.5L9.16667 0L11 1.80338L5.5 7L0 1.80338Z" fill="#080808">
#               </path>
#              </svg>
#             </span>
#            </h2>
#           </button>
#          </div>
#          <div class="hidden lg:inline-block mr-md">
#           <button class="btn-mega-menu--topics btn-mega-dropdown">
#            <span class="btn-mega-dropdown--label visually-hidden">
#             open
#            </span>
#            <h2>
#             Topics
#             <span class="visually-hidden">
#              submenu
#             </span>
#             <span class="inline-block ml-sm">
#              <svg fill="none" viewbox="0 0 11 7" xmlns="http://www.w3.org/2000/svg">
#               <path d="M0 1.80338L1.83333 0L5.5 3.5L9.16667 0L11 1.80338L5.5 7L0 1.80338Z" fill="#080808">
#               </path>
#              </svg>
#             </span>
#            </h2>
#           </button>
#          </div>
#          <div class="inline-block ml-lg">
#           <button aria-label="search" class="link-search" id="link-search">
#            <span class="search-icon-open">
#             <svg fill="none" viewbox="0 0 19 19" xmlns="http://www.w3.org/2000/svg">
#              <path clip-rule="evenodd" d="M2 7.59906C2 4.50679 4.50679 2 7.59906 2C10.6913 2 13.1981 4.50679 13.1981 7.59906C13.1981 10.6913 10.6913 13.1981 7.59906 13.1981C4.50679 13.1981 2 10.6913 2 7.59906ZM7.59906 0C3.40222 0 0 3.40222 0 7.59906C0 11.7959 3.40222 15.1981 7.59906 15.1981C9.30301 15.1981 10.876 14.6373 12.1434 13.6902C12.1602 13.7096 12.1779 13.7287 12.1963 13.7472L17.1126 18.6745C17.3191 18.8827 17.6002 18.9998 17.8935 18.9998C18.1867 18.9998 18.4679 18.8827 18.6744 18.6745C18.8826 18.468 18.9997 18.1869 18.9997 17.8936C18.9997 17.6003 18.8826 17.3192 18.6744 17.1127L13.7471 12.1964C13.7285 12.178 13.7095 12.1604 13.6901 12.1436C14.6373 10.8761 15.1981 9.30307 15.1981 7.59906C15.1981 3.40222 11.7959 0 7.59906 0Z" fill="#080808" fill-rule="evenodd">
#              </path>
#             </svg>
#            </span>
#            <span class="search--icon-close ts-hidden">
#             <svg version="1.1" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#              <title>
#               button-close
#              </title>
#              <g fill="none" fill-rule="evenodd" id="Page-1" stroke="none" stroke-width="1">
#               <g fill="#000000" fill-rule="nonzero" id="Group" stroke="#000" transform="translate(1.000000, 1.000000)">
#                <line id="Path" x1="0" x2="18" y1="0" y2="18">
#                </line>
#                <line id="Path" x1="18" x2="0" y1="0" y2="18">
#                </line>
#               </g>
#              </g>
#             </svg>
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="search-overlay relative z-7">
#      <div class="ts-bg-blue-800 absolute left-0 top-0 w-full pb-lg md:pb-2xl z-4 ts-hidden" id="csis-search-overlay">
#       <div class="p-site xl:container">
#        <form action="/search">
#         <div class="flex items-center relative">
#          <input autocomplete="off" class="search-overlay--input flex-grow h-[70px] p-md utility-lg w-full" name="keyword" placeholder="What are you looking for?" type="text"/>
#          <input class="btn-solid btn-solid--base absolute cursor-pointer top-sm right-sm" type="submit" value="Search"/>
#         </div>
#         <div class="csis-search-keyword-line utility-lg">
#         </div>
#        </form>
#       </div>
#       <div class="p-site xl:container pt-md hidden md:block" id="csis-search-overlay-results">
#       </div>
#      </div>
#     </div>
#     <div class="mega-menu relative z-7" tabindex="-1">
#      <div class="mega-menu--inner-wrapper nav-links text-high-contrast ts-bg-blue-800 absolute left-0 top-0 w-full pb-lg md:pb-2xl z-4">
#       <div>
#        <div class="mega-menu-default-block" data-block-plugin-id="mega-menu-default-block" data_block_region="mega-menu" id="block-megamenudefaultblock">
#         <div class="mega-menu-region-items default-nav">
#          <div class="mega-menu-default-wrapper divide-blue-250/50 live-today md:divide-x mt-xl ts-grid-3-4-5 p-site xl:container">
#           <div class="column-one region--mega-menu-column-one region--mega-menu-column utility-xl">
#            <nav aria-labelledby="-menu" data-block-plugin-id="system-menu-block-mega-menu-links" role="navigation">
#             <h2 class="block__title visually-hidden" id="-menu">
#              Primary Menu
#             </h2>
#             <ul>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101271" href="/analysis">
#                Analysis
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101194" href="/programs">
#                Programs
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101205" href="/about/people/experts">
#                Experts
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101234" href="/regions">
#                Regions
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101337" href="/topics">
#                Topics
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101235" href="/events">
#                Events
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a href="https://www.csis.org/analysis?f%5B0%5D=content_type%3Areport&amp;f%5B1%5D=report_type%3A3034">
#                Digital Reports
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101233" href="/podcasts">
#                Podcasts
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="webform/subscribe" href="/subscribe">
#                Newsletters
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/52383" href="/dracopoulos-ideas-lab/video-series">
#                Videos
#               </a>
#              </li>
#              <li class="menu-swipe-mobile">
#               <a data-drupal-link-system-path="node/101272" href="/microsites">
#                Microsites
#               </a>
#              </li>
#             </ul>
#            </nav>
#            <div class="md:hidden">
#             <nav aria-labelledby="-menu" data-block-plugin-id="system-menu-block-mega-menu-about-links" role="navigation">
#              <h2 class="block__title visually-hidden" id="-menu">
#               About CSIS
#              </h2>
#              <ul>
#               <div class="menu-swipe-mobile">
#                <button class="btn-swipe relative w-full md:hidden">
#                 <span class="btn-menu-swipe--label visually-hidden">
#                  open
#                 </span>
#                 <h2 class="text-left">
#                  About CSIS
#                  <span class="visually-hidden">
#                   submenu
#                  </span>
#                  <span class="absolute right-md bottom-xs ml-sm">
#                   <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M1.80338 11L0 9.16667L3.5 5.5L0 1.83333L1.80338 0L7 5.5L1.80338 11Z" fill="#080808">
#                    </path>
#                   </svg>
#                  </span>
#                 </h2>
#                </button>
#                <div class="menu-swipe-submenu divide-low-contrast-on-dk divide-y md:divide-y-0 pb-3xl">
#                 <button aria-label="return to
#                full menu" class="btn-swipe-back flex h-lg items-center md:hidden mb-base p-site relative w-full">
#                  <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M5.19662 0L7 1.83333L3.5 5.5L7 9.16667L5.19662 11L0 5.5L5.19662 0Z" fill="#FCFCFC">
#                   </path>
#                  </svg>
#                  <span class="text-center utility-lg w-full">
#                   Main menu
#                  </span>
#                 </button>
#                 <div class="ts-bg-blue-800 h-screen md:h-auto pt-base px-base md:px-0 md:pt-0">
#                  <li>
#                   <a data-drupal-link-system-path="&lt;front&gt;" href="/">
#                    Home
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/100650" href="/about">
#                    About CSIS
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101201" href="/about/people">
#                    Leadership &amp; Staff
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101199" href="/about/financial-information">
#                    Financial Information
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101856" href="/about/membership-groups-and-special-events">
#                    Membership Groups
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101210" href="/about/media">
#                    Media Requests
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/100413" href="/dracopoulos-ideas-lab">
#                    iDeas Lab/Multimedia
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/103275" href="/about/congressional-affairs-csis">
#                    Congressional Affairs
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/100403" href="/executive-education">
#                    Executive Education
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101208" href="/about/careers-culture">
#                    Careers &amp; Culture
#                   </a>
#                  </li>
#                  <li>
#                   <a data-drupal-link-system-path="node/101209" href="/about/location-contact">
#                    Location &amp; Contact
#                   </a>
#                  </li>
#                 </div>
#                </div>
#               </div>
#              </ul>
#             </nav>
#            </div>
#           </div>
#           <div class="column-two hidden md:block md:pl-xl region--mega-menu-column-two region--mega-menu-column utility-xl">
#            <nav aria-labelledby="-menu" data-block-plugin-id="system-menu-block-mega-menu-about-links" role="navigation">
#             <h2 class="block__title visually-hidden" id="-menu">
#              About Menu
#             </h2>
#             <ul>
#              <div class="menu-swipe-mobile">
#               <button class="btn-swipe relative w-full md:hidden">
#                <span class="btn-menu-swipe--label visually-hidden">
#                 open
#                </span>
#                <h2 class="text-left">
#                 About CSIS
#                 <span class="visually-hidden">
#                  submenu
#                 </span>
#                 <span class="absolute right-md bottom-xs ml-sm">
#                  <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M1.80338 11L0 9.16667L3.5 5.5L0 1.83333L1.80338 0L7 5.5L1.80338 11Z" fill="#080808">
#                   </path>
#                  </svg>
#                 </span>
#                </h2>
#               </button>
#               <div class="menu-swipe-submenu divide-low-contrast-on-dk divide-y md:divide-y-0 pb-3xl">
#                <button aria-label="return to
#                full menu" class="btn-swipe-back flex h-lg items-center md:hidden mb-base p-site relative w-full">
#                 <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M5.19662 0L7 1.83333L3.5 5.5L7 9.16667L5.19662 11L0 5.5L5.19662 0Z" fill="#FCFCFC">
#                  </path>
#                 </svg>
#                 <span class="text-center utility-lg w-full">
#                  Main menu
#                 </span>
#                </button>
#                <div class="ts-bg-blue-800 h-screen md:h-auto pt-base px-base md:px-0 md:pt-0">
#                 <li>
#                  <a data-drupal-link-system-path="&lt;front&gt;" href="/">
#                   Home
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100650" href="/about">
#                   About CSIS
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101201" href="/about/people">
#                   Leadership &amp; Staff
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101199" href="/about/financial-information">
#                   Financial Information
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101856" href="/about/membership-groups-and-special-events">
#                   Membership Groups
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101210" href="/about/media">
#                   Media Requests
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100413" href="/dracopoulos-ideas-lab">
#                   iDeas Lab/Multimedia
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/103275" href="/about/congressional-affairs-csis">
#                   Congressional Affairs
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100403" href="/executive-education">
#                   Executive Education
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101208" href="/about/careers-culture">
#                   Careers &amp; Culture
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101209" href="/about/location-contact">
#                   Location &amp; Contact
#                  </a>
#                 </li>
#                </div>
#               </div>
#              </div>
#             </ul>
#            </nav>
#           </div>
#           <div class="column-three hidden md:block md:pl-xl region--mega-menu-column-three region--mega-menu-column utility-xl">
#            <div class="mega-menu-events-list-block" data-block-plugin-id="mega-menu-events-list-block">
#             <div class="mega-menu-events-wrapper">
#              <div class="upcoming-events">
#               <article class="ts-card-event-sm mb-xl relative no-video event-past">
#                <a aria-hidden="true" aria-label="overlay link" class="card_overlay-link absolute left-0 top-0 w-full h-full" href="/events/doing-business-ukraine-2024-conference-building-ukraines-security-through-modernized-economy" tabindex="-1">
#                </a>
#                <h3 class="headline-sm mt-base mb-sm text-high-contrast">
#                 <a class="hocus-headline" href="/events/doing-business-ukraine-2024-conference-building-ukraines-security-through-modernized-economy">
#                  <span>
#                   Doing Business in Ukraine 2024 Conference: Building Ukraine’s Security through a Modernized Economy
#                  </span>
#                 </a>
#                </h3>
#                <div class="mt-0 utility-xs text-md-contrast">
#                 September 25, 2024 • 8:00 am – 5:00 pm EDT
#                </div>
#                <span class="text-md-contrast">
#                 <div class="mt-0 mb-2xs">
#                  <span class="event-status inline-block mr-sm event-status-wrapper" style="">
#                  </span>
#                  <div class="event-icon inline-block mr-sm mt-2xs">
#                  </div>
#                 </div>
#                </span>
#                <div class="mt-sm text-md-contrast utility-xs">
#                 Hosted by
#                 <span class="utility-xs-bold">
#                  <a href="/programs/project-prosperity-and-development" hreflang="en">
#                   Project on Prosperity and Development
#                  </a>
#                 </span>
#                </div>
#               </article>
#               <article class="ts-card-event-sm mb-xl relative has-video event-past">
#                <a aria-hidden="true" aria-label="overlay link" class="card_overlay-link absolute left-0 top-0 w-full h-full" href="/events/rebuilding-americas-maritime-strength-senator-kelly-and-congressman-waltz" tabindex="-1">
#                </a>
#                <h3 class="headline-sm mt-base mb-sm text-high-contrast">
#                 <a class="hocus-headline" href="/events/rebuilding-americas-maritime-strength-senator-kelly-and-congressman-waltz">
#                  <span>
#                   Rebuilding America’s Maritime Strength with Senator Kelly and Congressman Waltz
#                  </span>
#                 </a>
#                </h3>
#                <div class="mt-0 utility-xs text-md-contrast">
#                 September 25, 2024 • 9:00 – 9:45 am EDT
#                </div>
#                <span class="text-md-contrast">
#                 <div class="mt-0 mb-2xs">
#                  <span class="event-status inline-block mr-sm event-status-wrapper" style="">
#                   <div class="mt-sm">
#                    <div class="event-status tag tag-events inline-block text-white" data-alt-live-text="happening" data-end-date="2024-09-25T09:45:00-04:00" data-ended="1" data-start-date="2024-09-25T09:00:00-04:00">
#                     Video On Demand
#                    </div>
#                   </div>
#                  </span>
#                  <div class="event-icon inline-block mr-sm mt-2xs">
#                  </div>
#                 </div>
#                </span>
#                <div class="mt-sm text-md-contrast utility-xs">
#                 Hosted by
#                 <span class="utility-xs-bold">
#                  <a href="/programs/international-security-program" hreflang="en">
#                   International Security Program
#                  </a>
#                 </span>
#                </div>
#               </article>
#               <article class="ts-card-event-sm mb-xl relative has-video event-not-past">
#                <a aria-hidden="true" aria-label="overlay link" class="card_overlay-link absolute left-0 top-0 w-full h-full" href="/events/global-impact-2024-us-presidential-election" tabindex="-1">
#                </a>
#                <h3 class="headline-sm mt-base mb-sm text-high-contrast">
#                 <a class="hocus-headline" href="/events/global-impact-2024-us-presidential-election">
#                  <span>
#                   The Global Impact of the 2024 U.S. Presidential Election
#                  </span>
#                 </a>
#                </h3>
#                <div class="mt-0 utility-xs text-md-contrast">
#                 September 26, 2024 • 8:30 – 11:00 am EDT
#                </div>
#                <span class="text-md-contrast">
#                 <div class="mt-0 mb-2xs">
#                  <span class="event-status inline-block mr-sm event-status-wrapper" style="">
#                   <div class="event-status tag tag-events inline-block text-white" data-alt-live-text="live" data-end-date="2024-09-26T11:00:00-04:00" data-ended="" data-start-date="2024-09-26T08:30:00-04:00">
#                    Live in 10 hours
#                   </div>
#                  </span>
#                  <div class="event-icon inline-block mr-sm mt-2xs">
#                   <span class="ts-fill-high-contrast inline-block -mb-2xs">
#                    <svg fill="none" viewbox="0 0 21 21" xmlns="http://www.w3.org/2000/svg">
#                     <g>
#                      <path d="M10.4304 20.6557C10.5391 20.8187 10.7221 20.9167 10.918 20.9167C11.1139 20.9167 11.2968 20.8188 11.4055 20.6557C12.7922 18.5758 14.8346 16.007 16.2579 13.3944C17.396 11.3055 17.9492 9.52392 17.9492 7.94791C17.9492 4.07088 14.795 0.916656 10.918 0.916656C7.04094 0.916656 3.88672 4.07088 3.88672 7.94791C3.88672 9.52392 4.43996 11.3055 5.57801 13.3944C7.00023 16.005 9.0466 18.5801 10.4304 20.6557ZM10.918 2.08853C14.1488 2.08853 16.7773 4.71705 16.7773 7.94791C16.7773 9.32306 16.2708 10.9213 15.2289 12.8338C14.002 15.0857 12.2513 17.3701 10.918 19.2904C9.5848 17.3703 7.83398 15.0858 6.60707 12.8338C5.56512 10.9213 5.05859 9.32306 5.05859 7.94791C5.05859 4.71705 7.68711 2.08853 10.918 2.08853Z" fill="#EAEAEA">
#                      </path>
#                      <path d="M10.918 11.4635C12.8565 11.4635 14.4336 9.88642 14.4336 7.94791C14.4336 6.00939 12.8565 4.43228 10.918 4.43228C8.97945 4.43228 7.40234 6.00939 7.40234 7.94791C7.40234 9.88642 8.97945 11.4635 10.918 11.4635ZM10.918 5.60416C12.2103 5.60416 13.2617 6.65556 13.2617 7.94791C13.2617 9.24025 12.2103 10.2917 10.918 10.2917C9.62563 10.2917 8.57422 9.24025 8.57422 7.94791C8.57422 6.65556 9.62563 5.60416 10.918 5.60416Z" fill="#EAEAEA">
#                      </path>
#                     </g>
#                    </svg>
#                   </span>
#                   <span class="inline-block utility-sm ml-2xs">
#                    In Person
#                   </span>
#                  </div>
#                  <div class="event-icon inline-block mr-sm mt-2xs">
#                   <span class="ts-fill-high-contrast inline-block -mb-2xs">
#                    <svg fill="none" viewbox="0 0 20 21" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M13.96 11.7867C13.4439 9.0632 11.0451 7.02417 8.20312 7.02417C5.33676 7.02417 2.90909 9.09494 2.42889 11.883C0.998993 12.3466 0 13.691 0 15.2273C0 17.1658 1.57715 18.7429 3.51562 18.7429H14.6873C16.626 18.7429 18.203 17.1658 18.203 15.2273C18.203 13.0094 16.156 11.3241 13.96 11.7867ZM14.6873 17.571H3.51562C2.22321 17.571 1.17187 16.5196 1.17187 15.2273C1.17187 14.1062 1.96899 13.1385 3.06747 12.9264C3.32169 12.8773 3.51349 12.6672 3.53928 12.4094C3.77991 10.0074 5.78491 8.19604 8.20312 8.19604C10.679 8.19604 12.7344 10.1299 12.8822 12.5987C12.9069 13.0102 13.3385 13.2681 13.7123 13.0958C15.2487 12.3879 17.0311 13.5157 17.0311 15.2273C17.0311 16.5196 15.9798 17.571 14.6873 17.571Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M10.2594 12.9652L7.29065 11.2074C6.90079 10.9766 6.40625 11.2581 6.40625 11.7117V15.2272C6.40625 15.6802 6.90033 15.9625 7.29065 15.7315L10.2594 13.9737C10.6418 13.7472 10.6424 13.192 10.2594 12.9652ZM7.57812 14.1994V12.7396L8.81088 13.4695L7.57812 14.1994Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M14.4168 8.97417C14.5912 9.24685 14.9536 9.32635 15.2261 9.15209C15.4986 8.97768 15.5783 8.61529 15.404 8.34277C15.0409 7.77499 14.6077 7.25253 14.1166 6.78988C13.881 6.56786 13.5102 6.579 13.2884 6.8146C13.0665 7.05004 13.0775 7.42083 13.3129 7.64285C13.7341 8.03957 14.1055 8.48742 14.4168 8.97417Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M14.4073 5.48924C15.3248 6.23661 16.0834 7.13688 16.6619 8.16502C16.8207 8.44715 17.1781 8.54694 17.4599 8.38825C17.7419 8.22956 17.8419 7.87235 17.6832 7.59022C17.0324 6.43375 16.1793 5.42118 15.1475 4.58073C14.8966 4.37626 14.5275 4.41395 14.323 4.6648C14.1187 4.91581 14.1564 5.28477 14.4073 5.48924Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M19.9338 6.82396C19.0399 5.10063 17.7411 3.57521 16.1777 2.41264C15.9182 2.21961 15.551 2.27348 15.358 2.53318C15.1648 2.79274 15.2189 3.15986 15.4786 3.35289C16.9001 4.41017 18.0809 5.79689 18.8935 7.36351C19.0425 7.65083 19.3964 7.76268 19.6834 7.61375C19.9707 7.46482 20.0829 7.11113 19.9338 6.82396Z" fill="#EAEAEA">
#                     </path>
#                    </svg>
#                   </span>
#                   <span class="inline-block utility-sm ml-2xs">
#                    Webcast
#                   </span>
#                  </div>
#                 </div>
#                </span>
#                <div class="mt-sm text-md-contrast utility-xs">
#                 Hosted by
#                 <span class="utility-xs-bold">
#                  <a href="/special-initiatives/on-china/geopolitics" hreflang="en">
#                   Geopolitics
#                  </a>
#                 </span>
#                </div>
#               </article>
#               <article class="ts-card-event-sm mb-xl relative no-video event-not-past">
#                <a aria-hidden="true" aria-label="overlay link" class="card_overlay-link absolute left-0 top-0 w-full h-full" href="/events/powering-tomorrow-innovations-intersection-ai-and-energy" tabindex="-1">
#                </a>
#                <h3 class="headline-sm mt-base mb-sm text-high-contrast">
#                 <a class="hocus-headline" href="/events/powering-tomorrow-innovations-intersection-ai-and-energy">
#                  <span>
#                   Powering Tomorrow: Innovations at the Intersection of AI and Energy
#                  </span>
#                 </a>
#                </h3>
#                <div class="mt-0 utility-xs text-md-contrast">
#                 September 26, 2024 • 4:00 – 4:30 pm EDT
#                </div>
#                <span class="text-md-contrast">
#                 <div class="mt-0 mb-2xs">
#                  <span class="event-status inline-block mr-sm event-status-wrapper" style="">
#                   <div class="event-status tag tag-events inline-block text-white" data-alt-live-text="live" data-end-date="2024-09-26T16:30:00-04:00" data-ended="" data-start-date="2024-09-26T16:00:00-04:00">
#                    Live in 17 hours
#                   </div>
#                  </span>
#                  <div class="event-icon inline-block mr-sm mt-2xs">
#                   <span class="ts-fill-high-contrast inline-block -mb-2xs">
#                    <svg fill="none" viewbox="0 0 20 21" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M13.96 11.7867C13.4439 9.0632 11.0451 7.02417 8.20312 7.02417C5.33676 7.02417 2.90909 9.09494 2.42889 11.883C0.998993 12.3466 0 13.691 0 15.2273C0 17.1658 1.57715 18.7429 3.51562 18.7429H14.6873C16.626 18.7429 18.203 17.1658 18.203 15.2273C18.203 13.0094 16.156 11.3241 13.96 11.7867ZM14.6873 17.571H3.51562C2.22321 17.571 1.17187 16.5196 1.17187 15.2273C1.17187 14.1062 1.96899 13.1385 3.06747 12.9264C3.32169 12.8773 3.51349 12.6672 3.53928 12.4094C3.77991 10.0074 5.78491 8.19604 8.20312 8.19604C10.679 8.19604 12.7344 10.1299 12.8822 12.5987C12.9069 13.0102 13.3385 13.2681 13.7123 13.0958C15.2487 12.3879 17.0311 13.5157 17.0311 15.2273C17.0311 16.5196 15.9798 17.571 14.6873 17.571Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M10.2594 12.9652L7.29065 11.2074C6.90079 10.9766 6.40625 11.2581 6.40625 11.7117V15.2272C6.40625 15.6802 6.90033 15.9625 7.29065 15.7315L10.2594 13.9737C10.6418 13.7472 10.6424 13.192 10.2594 12.9652ZM7.57812 14.1994V12.7396L8.81088 13.4695L7.57812 14.1994Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M14.4168 8.97417C14.5912 9.24685 14.9536 9.32635 15.2261 9.15209C15.4986 8.97768 15.5783 8.61529 15.404 8.34277C15.0409 7.77499 14.6077 7.25253 14.1166 6.78988C13.881 6.56786 13.5102 6.579 13.2884 6.8146C13.0665 7.05004 13.0775 7.42083 13.3129 7.64285C13.7341 8.03957 14.1055 8.48742 14.4168 8.97417Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M14.4073 5.48924C15.3248 6.23661 16.0834 7.13688 16.6619 8.16502C16.8207 8.44715 17.1781 8.54694 17.4599 8.38825C17.7419 8.22956 17.8419 7.87235 17.6832 7.59022C17.0324 6.43375 16.1793 5.42118 15.1475 4.58073C14.8966 4.37626 14.5275 4.41395 14.323 4.6648C14.1187 4.91581 14.1564 5.28477 14.4073 5.48924Z" fill="#EAEAEA">
#                     </path>
#                     <path d="M19.9338 6.82396C19.0399 5.10063 17.7411 3.57521 16.1777 2.41264C15.9182 2.21961 15.551 2.27348 15.358 2.53318C15.1648 2.79274 15.2189 3.15986 15.4786 3.35289C16.9001 4.41017 18.0809 5.79689 18.8935 7.36351C19.0425 7.65083 19.3964 7.76268 19.6834 7.61375C19.9707 7.46482 20.0829 7.11113 19.9338 6.82396Z" fill="#EAEAEA">
#                     </path>
#                    </svg>
#                   </span>
#                   <span class="inline-block utility-sm ml-2xs">
#                    Webcast
#                   </span>
#                  </div>
#                 </div>
#                </span>
#                <div class="mt-sm text-md-contrast utility-xs">
#                 Hosted by
#                 <span class="utility-xs-bold">
#                  <a href="/programs/energy-security-and-climate-change-program" hreflang="en">
#                   Energy Security and Climate Change Program
#                  </a>
#                 </span>
#                </div>
#               </article>
#              </div>
#              <div class="all-events mt-2xl">
#               <a class="link-text text-white" href="/events">
#                All Events
#                <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M1.80338 11L0 9.16667L3.5 5.5L0 1.83333L1.80338 0L7 5.5L1.80338 11Z" fill="#080808">
#                 </path>
#                </svg>
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="hidden about-menu-mobile">
#            <nav aria-labelledby="-menu" data-block-plugin-id="system-menu-block-mega-menu-about-links" role="navigation">
#             <h2 class="block__title visually-hidden" id="-menu">
#              About Menu
#             </h2>
#             <ul>
#              <div class="menu-swipe-mobile">
#               <button class="btn-swipe relative w-full md:hidden">
#                <span class="btn-menu-swipe--label visually-hidden">
#                 open
#                </span>
#                <h2 class="text-left">
#                 About CSIS
#                 <span class="visually-hidden">
#                  submenu
#                 </span>
#                 <span class="absolute right-md bottom-xs ml-sm">
#                  <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M1.80338 11L0 9.16667L3.5 5.5L0 1.83333L1.80338 0L7 5.5L1.80338 11Z" fill="#080808">
#                   </path>
#                  </svg>
#                 </span>
#                </h2>
#               </button>
#               <div class="menu-swipe-submenu divide-low-contrast-on-dk divide-y md:divide-y-0 pb-3xl">
#                <button aria-label="return to
#                full menu" class="btn-swipe-back flex h-lg items-center md:hidden mb-base p-site relative w-full">
#                 <svg fill="none" viewbox="0 0 7 11" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M5.19662 0L7 1.83333L3.5 5.5L7 9.16667L5.19662 11L0 5.5L5.19662 0Z" fill="#FCFCFC">
#                  </path>
#                 </svg>
#                 <span class="text-center utility-lg w-full">
#                  Main menu
#                 </span>
#                </button>
#                <div class="ts-bg-blue-800 h-screen md:h-auto pt-base px-base md:px-0 md:pt-0">
#                 <li>
#                  <a data-drupal-link-system-path="&lt;front&gt;" href="/">
#                   Home
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100650" href="/about">
#                   About CSIS
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101201" href="/about/people">
#                   Leadership &amp; Staff
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101199" href="/about/financial-information">
#                   Financial Information
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101856" href="/about/membership-groups-and-special-events">
#                   Membership Groups
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101210" href="/about/media">
#                   Media Requests
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100413" href="/dracopoulos-ideas-lab">
#                   iDeas Lab/Multimedia
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/103275" href="/about/congressional-affairs-csis">
#                   Congressional Affairs
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/100403" href="/executive-education">
#                   Executive Education
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101208" href="/about/careers-culture">
#                   Careers &amp; Culture
#                  </a>
#                 </li>
#                 <li>
#                  <a data-drupal-link-system-path="node/101209" href="/about/location-contact">
#                   Location &amp; Contact
#                  </a>
#                 </li>
#                </div>
#               </div>
#              </div>
#             </ul>
#            </nav>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="mega-menu-program-links-block" data-block-plugin-id="mega-menu-program-links-block" data_block_region="mega-menu" id="block-megamenuprogramlinksblock">
#         <div class="mega-menu-region-items program p-site mt-xl xl:container">
#          <div class="ts-grid-col-3 divide-x divide-blue-250/50">
#           <div class="pl-md">
#            <h3 class="tag tag-events inline-block blue-400">
#             a-d
#            </h3>
#            <ul class="utility-sm mt-base">
#             <li class="mb-sm">
#              <a href="/programs/abshire-inamori-leadership-academy">
#               Abshire-Inamori Leadership Academy
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/international-security-program/aerospace-security-project">
#               Aerospace Security Project
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/africa-program">
#               Africa Program
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/americas-program">
#               Americas Program
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/international-security-program/arleigh-burke-chair-strategy">
#               Arleigh A. Burke Chair in Strategy
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/asia-maritime-transparency-initiative">
#               Asia Maritime Transparency Initiative
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/asia-program">
#               Asia Program
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/australia-chair">
#               Australia Chair
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/brzezinski-chair-global-security-and-geostrategy">
#               Brzezinski Chair in Global Security and Geostrategy
#              </a>
#             </li>
#             <li class="mb-sm">
#              <a href="/programs/brzezinski-institute-geostrategy">
#               Brzezinski Institute on Geostrategy
#              </a>
#             </li>
#             <li class="mb-sm">
# ...
#                 </svg>
#                 <span class="ml-sm">
#                  202.775.3242
#                 </span>
#                </a>
#               </li>
#               <li>
#                <a class="flex hocus-action hocus-underline mb-xs ts-fill-high-contrast" href="mailto:aschwartz@csis.org">
#                 <svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                  <path clip-rule="evenodd" d="M5.00854 7L11.9998 12.6659L18.9916 7H5.00854ZM5 8.49449L8.83542 11.6031L5 15.7867V8.49449ZM15.1646 11.6031L19 15.7867V8.49449L15.1646 11.6031ZM12 14.1674L14.2563 12.3387L18.9872 17.5H5.01282L9.74365 12.3387L12 14.1674Z" fill="#080808" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="ml-sm">
#                  aschwartz@csis.org
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="mb-md">
#              <ul>
#               <li class="mb-xs">
#                <a class="font-bold" href="/people/samuel-cestari">
#                 Samuel Cestari
#                </a>
#               </li>
#               <li class="mb-xs">
#                Media Relations Coordinator, External Relations
#               </li>
#               <li>
#                <a class="flex hocus-action hocus-underline mb-xs ts-fill-high-contrast" href="tel:2027757317">
#                 <svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                  <g clip-path="url(#clip0_2488_34246)">
#                   <path d="M18.5094 15.528C17.4221 14.598 16.3185 14.0346 15.2445 14.9633L14.6032 15.5245C14.1339 15.9319 13.2615 17.8355 9.8884 13.9553C6.51599 10.0799 8.52286 9.4765 8.99279 9.0726L9.63763 8.51065C10.706 7.57991 10.3028 6.40825 9.53226 5.20216L9.06725 4.47162C8.29316 3.26834 7.45023 2.4781 6.37901 3.40743L5.8002 3.91318C5.32676 4.25808 4.00336 5.37917 3.68235 7.50897C3.29601 10.0644 4.51474 12.9908 7.30693 16.2017C10.0956 19.4139 12.826 21.0274 15.4124 20.9993C17.5618 20.9761 18.8599 19.8227 19.266 19.4034L19.8469 18.8969C20.9153 17.9683 20.2515 17.0228 19.1634 16.0907L18.5094 15.528Z" fill="#080808">
#                   </path>
#                  </g>
#                  <defs>
#                   <clippath id="clip0_2488_34246">
#                    <rect fill="white" height="18" transform="translate(3.00031 3)" width="18">
#                    </rect>
#                   </clippath>
#                  </defs>
#                 </svg>
#                 <span class="ml-sm">
#                  202.775.7317
#                 </span>
#                </a>
#               </li>
#               <li>
#                <a class="flex hocus-action hocus-underline mb-xs ts-fill-high-contrast" href="mailto:scestari@csis.org">
#                 <svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                  <path clip-rule="evenodd" d="M5.00854 7L11.9998 12.6659L18.9916 7H5.00854ZM5 8.49449L8.83542 11.6031L5 15.7867V8.49449ZM15.1646 11.6031L19 15.7867V8.49449L15.1646 11.6031ZM12 14.1674L14.2563 12.3387L18.9872 17.5H5.01282L9.74365 12.3387L12 14.1674Z" fill="#080808" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="ml-sm">
#                  scestari@csis.org
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="utility-block" data-block-plugin-id="utility-block" data_block_region="footer-col-two" id="block-utilityblock-3">
#           <div class="wysiwyg-wrapper mb-lg">
#            <p class="utility-sm">
#             See
#             <a href="/about/press-media">
#              Media Page
#             </a>
#             for more interview, contact, and citation details.
#            </p>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="md:col-start-9 md:col-span-3">
#         <div class="footer-subscribe-block" data-block-plugin-id="footer-subscribe-block" data_block_region="footer-col-three" id="block-footersubscribeblock">
#          <div class="footer-subscribe-block mt-lg md:mt-0">
#           <div class="mb-base text-high-contrast utility-sm">
#            Sign up to receive The Evening, a daily brief on the news, events, and people shaping the world of international affairs.
#           </div>
#           <a class="block btn-solid" href="/subscribe">
#            Subscribe to CSIS Newsletters
#           </a>
#          </div>
#         </div>
#         <nav aria-labelledby="block-footersocial-menu" class="footer-social-block" data-block-plugin-id="system-menu-block-footer-social" id="block-footersocial" role="navigation">
#          <h2 class="block__title visually-hidden" id="block-footersocial-menu">
#           Footer Social
#          </h2>
#          <div class="mt-2xl text-high-contrast utility-xs">
#           <h3 class="mb-sm uppercase">
#            Follow
#           </h3>
#           <ul data-block-region="footer-col-three">
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://www.facebook.com/CSIS.org">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M10.5 10.0681H9V12.1021H10.5V18.2043H13V12.1021H14.821L15 10.0681H13V9.2204C13 8.73477 13.096 8.54255 13.5575 8.54255H15V6H13.096C11.298 6 10.5 6.80497 10.5 8.34678V10.0681Z" fill="#282828">
#                </path>
#               </svg>
#              </span>
#              Facebook
#             </a>
#            </li>
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://twitter.com/csis">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M16.6489 5.22931H19.1014L13.7166 11.3604L20.0078 19.6773H15.0708L11.2054 14.6232L6.78022 19.6773H4.32771L10.0325 13.1198L4.00781 5.22931H9.06746L12.5596 9.84628L16.6489 5.22931ZM15.7906 18.2379H17.1501L8.35303 6.61547H6.89218L15.7906 18.2379Z" fill="black">
#                </path>
#               </svg>
#              </span>
#              X
#             </a>
#            </li>
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://www.linkedin.com/company/csis">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <svg class="icon-linkedin-svg" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <defs>
#                </defs>
#                <path class="b" d="M12.65,11c0-.35,0-.65,0-.94s0-.2-.19-.2H10.41c-.16,0-.2,0-.2.21V18c0,.16,0,.22.2.22h2.14c.16,0,.2,0,.2-.22V14a4.54,4.54,0,0,1,.07-.82,1.28,1.28,0,0,1,.92-1.17A2.12,2.12,0,0,1,14.3,12a1,1,0,0,1,1.09.88,4.54,4.54,0,0,1,.11,1c0,1.37,0,2.73,0,4.1,0,.16,0,.22.21.22h2.14c.15,0,.19,0,.19-.21v-4.4a8.17,8.17,0,0,0-.16-1.79A2.44,2.44,0,0,0,16.57,10a3.32,3.32,0,0,0-2.36-.21A2.63,2.63,0,0,0,12.65,11Zm-4,3v-4c0-.14,0-.19-.19-.19H6.33c-.14,0-.18,0-.18.19v8c0,.16,0,.2.19.19H8.48c.21,0,.21,0,.21-.21ZM7.42,8.78A1.51,1.51,0,1,0,6,7.28,1.48,1.48,0,0,0,7.42,8.78Z">
#                </path>
#                <path class="b" d="M12.65,11a2.63,2.63,0,0,1,1.56-1.24,3.32,3.32,0,0,1,2.36.21,2.44,2.44,0,0,1,1.31,1.84A8.17,8.17,0,0,1,18,13.63V18c0,.16,0,.21-.19.21H15.71c-.17,0-.21-.06-.21-.22,0-1.37,0-2.73,0-4.1a4.54,4.54,0,0,0-.11-1A1,1,0,0,0,14.3,12a2.12,2.12,0,0,0-.56.05,1.28,1.28,0,0,0-.92,1.17,4.54,4.54,0,0,0-.07.82v4c0,.17,0,.22-.2.22H10.41c-.16,0-.2-.06-.2-.22V10.1c0-.16,0-.21.2-.21h2.06c.15,0,.19,0,.19.2S12.65,10.68,12.65,11Z">
#                </path>
#                <path class="b" d="M8.69,14.05v4c0,.21,0,.21-.21.21H6.34c-.14,0-.19,0-.19-.19v-8c0-.15,0-.19.18-.19H8.5c.15,0,.19,0,.19.19Z">
#                </path>
#                <path class="b" d="M7.42,8.78a1.51,1.51,0,0,1,0-3,1.51,1.51,0,0,1,0,3Z">
#                </path>
#               </svg>
#              </span>
#              Linkedin
#             </a>
#            </li>
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://www.youtube.com/user/csisdc">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <?xml version="1.0" encoding="utf-8"?>
#               <!--Generator: Adobe Illustrator 26.3.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)-->
#               <svg enable-background="new 0 0 18 18" id="Layer_1" version="1.1" viewbox="0 0 18 18" x="0" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0">
#                <g>
#                 <defs>
#                  <rect height="18" id="SVGID_1_" width="18">
#                  </rect>
#                 </defs>
#                 <clippath id="SVGID_00000103960641233643479110000005230977282723455131_">
#                  <use overflow="visible" xlink:href="#SVGID_1_">
#                  </use>
#                 </clippath>
#                 <path clip-path="url(#SVGID_00000103960641233643479110000005230977282723455131_)" d="M17.6,4.7
# 		c-0.2-0.8-0.8-1.4-1.6-1.6c-1.4-0.4-7-0.4-7-0.4s-5.6,0-7,0.4C1.2,3.3,0.6,3.9,0.4,4.7C0,6.1,0,9,0,9s0,2.9,0.4,4.3
# 		c0.2,0.8,0.8,1.4,1.6,1.6c1.4,0.4,7,0.4,7,0.4s5.6,0,7-0.4c0.8-0.2,1.4-0.8,1.6-1.6C18,11.9,18,9,18,9S18,6.1,17.6,4.7z M7.2,11.7
# 		V6.3L11.9,9L7.2,11.7z" fill="#FFFFFF">
#                 </path>
#                </g>
#               </svg>
#              </span>
#              YouTube
#             </a>
#            </li>
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://www.instagram.com/csis/">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <svg fill="none" viewbox="0 0 22 22" xmlns="http://www.w3.org/2000/svg">
#                <path d="M15.9996 1H5.99988C3.25019 1 1 3.25019 1 5.99988V16.0001C1 18.7491 3.25019 21 5.99988 21H15.9996C18.7493 21 20.9995 18.7491 20.9995 16.0001V5.99988C20.9995 3.25019 18.7493 1 15.9996 1ZM19.3328 16.0001C19.3328 17.8376 17.8381 19.3333 15.9996 19.3333H5.99988C4.16218 19.3333 2.66671 17.8376 2.66671 16.0001V5.99988C2.66671 4.16193 4.16218 2.66671 5.99988 2.66671H15.9996C17.8381 2.66671 19.3328 4.16193 19.3328 5.99988V16.0001Z" fill="#FCFCFC">
#                </path>
#                <path d="M16.4179 6.83295C17.1083 6.83295 17.6679 6.27332 17.6679 5.58298C17.6679 4.89264 17.1083 4.33301 16.4179 4.33301C15.7276 4.33301 15.168 4.89264 15.168 5.58298C15.168 6.27332 15.7276 6.83295 16.4179 6.83295Z" fill="#0A2458">
#                </path>
#                <path d="M10.9999 6C8.23793 6 6 8.23818 6 10.9999C6 13.7606 8.23793 16.0002 10.9999 16.0002C13.761 16.0002 15.9998 13.7606 15.9998 10.9999C15.9998 8.23818 13.761 6 10.9999 6ZM10.9999 14.3335C9.15915 14.3335 7.66671 12.8411 7.66671 10.9999C7.66671 9.15866 9.15915 7.66671 10.9999 7.66671C12.8406 7.66671 14.333 9.15866 14.333 10.9999C14.333 12.8411 12.8406 14.3335 10.9999 14.3335Z" fill="#FCFCFC">
#                </path>
#               </svg>
#              </span>
#              Instagram
#             </a>
#            </li>
#            <li class="hocus-action-svg pb-base">
#             <a class="flex items-center" href="https://www.threads.net/@csis">
#              <span aria-hidden="true" class="inline-block mr-xs ts-fill-high-contrast">
#               <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M17.2129 11.1966C17.1181 11.1512 17.0219 11.1074 16.9244 11.0656C16.7545 7.93667 15.0448 6.14536 12.174 6.12703C12.161 6.12695 12.148 6.12695 12.135 6.12695C10.4179 6.12695 8.98976 6.85989 8.11076 8.19362L9.68964 9.27668C10.3463 8.28043 11.3768 8.06805 12.1358 8.06805C12.1445 8.06805 12.1533 8.06805 12.162 8.06813C13.1073 8.07416 13.8206 8.34899 14.2822 8.88494C14.6182 9.27513 14.8429 9.81432 14.9542 10.4948C14.1161 10.3524 13.2097 10.3086 12.2408 10.3641C9.51131 10.5213 7.75659 12.1132 7.87444 14.3251C7.93425 15.4471 8.49322 16.4124 9.44832 17.0429C10.2559 17.576 11.2959 17.8366 12.3768 17.7776C13.8043 17.6994 14.9241 17.1548 15.7054 16.1589C16.2987 15.4027 16.674 14.4226 16.8397 13.1878C17.52 13.5983 18.0242 14.1386 18.3026 14.788C18.7761 15.8921 18.8037 17.7062 17.3233 19.1853C16.0264 20.481 14.4673 21.0415 12.1111 21.0588C9.4975 21.0395 7.52085 20.2013 6.23569 18.5676C5.03225 17.0378 4.4103 14.8281 4.38709 12C4.4103 9.17183 5.03225 6.96218 6.23569 5.43239C7.52085 3.79869 9.49747 2.96052 12.1111 2.9411C14.7437 2.96067 16.7548 3.80287 18.0891 5.44446C18.7434 6.24948 19.2367 7.26184 19.5619 8.44222L21.4121 7.94859C21.0179 6.49567 20.3977 5.24367 19.5536 4.20535C17.843 2.10077 15.3411 1.02236 12.1175 1H12.1046C8.88761 1.02228 6.41376 2.10479 4.75183 4.21742C3.27294 6.0974 2.51009 8.71326 2.48446 11.9923L2.48438 12L2.48446 12.0077C2.51009 15.2867 3.27294 17.9026 4.75183 19.7826C6.41376 21.8952 8.88761 22.9778 12.1046 23H12.1175C14.9777 22.9802 16.9937 22.2314 18.6545 20.5721C20.8274 18.4013 20.7619 15.6803 20.0458 14.0099C19.532 12.8121 18.5524 11.8391 17.2129 11.1966ZM12.2746 15.8393C11.0784 15.9067 9.83556 15.3698 9.77427 14.2197C9.72885 13.367 10.3811 12.4155 12.3481 12.3021C12.5733 12.2891 12.7943 12.2828 13.0115 12.2828C13.7259 12.2828 14.3943 12.3522 15.002 12.485C14.7753 15.3155 13.4459 15.7751 12.2746 15.8393Z" fill="black">
#                </path>
#               </svg>
#              </span>
#              Threads
#             </a>
#            </li>
#           </ul>
#          </div>
#         </nav>
#        </div>
#       </div>
#       <div class="pt-sm md:pt-md md:flex md:justify-between md:items-center">
#        <div class="utility-block" data-block-plugin-id="utility-block" data_block_region="footer-bottom" id="block-utilityblock">
#         <div class="wysiwyg-wrapper mb-lg">
#          <p class="utility-sm">
#           ©2024 Center for Strategic &amp; International Studies. All Rights Reserved.
#          </p>
#         </div>
#        </div>
#        <nav aria-labelledby="block-footersecondarynavigation-menu" data-block-plugin-id="system-menu-block-footer-secondary-navigation" id="block-footersecondarynavigation" role="navigation">
#         <h2 class="block__title visually-hidden" id="block-footersecondarynavigation-menu">
#          Footer secondary navigation
#         </h2>
#         <ul class="footer-secondary-nav divide-blue-250/50 divide-x pt-md md:pt-0" data-block-region="footer-bottom">
#          <li class="h-md md:h-xl inline-block md:py-xs px-sm utility-xs-bold">
#           <a data-drupal-link-system-path="node/103277" href="/accessibility">
#            Accessibility
#           </a>
#          </li>
#          <li class="h-md md:h-xl inline-block md:py-xs px-sm utility-xs-bold">
#           <a data-drupal-link-system-path="node/103223" href="/privacy-policy">
#            Privacy Policy
#           </a>
#          </li>
#          <li class="h-md md:h-xl inline-block md:py-xs px-sm utility-xs-bold">
#           <a data-drupal-link-system-path="node/101213" href="/about/media/reprint-permissions">
#            Reprint Permissions
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script src="/core/assets/vendor/once/once.min.js?v=1.0.1">
#   </script>
#   <script src="/core/misc/drupal.js?v=10.2.6">
#   </script>
#   <script src="/core/misc/drupal.init.js?v=10.2.6">
#   </script>
#   <script src="/core/assets/vendor/tabbable/index.umd.min.js?v=6.2.0">
#   </script>
#   <script src="/modules/custom/c2pa/js/c2pa.js?ske1qr" type="module">
#   </script>
#   <script src="/core/misc/tabbingmanager.js?v=10.2.6">
#   </script>
#   <script src="/core/misc/debounce.js?v=10.2.6">
#   </script>
#   <script src="/core/misc/announce.js?v=10.2.6">
#   </script>
#   <script src="/themes/custom/ts_csis/dist/ts-csis.js?ske1qr">
#   </script>
#   <script src="/modules/custom/csis_event/js/csis-event-status.js?ske1qr">
#   </script>
#  </body>
# </html>
