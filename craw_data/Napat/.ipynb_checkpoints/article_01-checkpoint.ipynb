# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import spacy
from spacy import displacy

# %%
url = "https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url, headers=headers)

# %%
soup=BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.climatecouncil.org.au/xmlrpc.php" rel="pingback"/>
#   <link href="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/img/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css" rel="stylesheet" type="text/css">
#    <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#     <!-- Google Tag Manager for WordPress by gtm4wp.com -->
#     <script data-cfasync="false" data-pagespeed-no-defer="">
#      var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
#     </script>
#     <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
#     <!-- This site is optimized with the Yoast SEO plugin v21.8 - https://yoast.com/wordpress/plugins/seo/ -->
#     <title>
#      Australia has key role to play as clean energy reshapes Indo-Pacific relations: new report from Perth USAsia Centre | Climate Council
#     </title>
#     <meta content="A new report by the Perth USAsia Centre and the Climate Council, recommends five practical actions for Australia to secure its economic and strategic clean energy advantages in the Indo-Pacific:" name="description">
#      <link href="https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/" rel="canonical">
#       <meta content="en_GB" property="og:locale"/>
#       <meta content="article" property="og:type"/>
#       <meta content="Australia has key role to play as clean energy reshapes Indo-Pacific relations: new report from Perth USAsia Centre | Climate Council" property="og:title"/>
#       <meta content="A new report by the Perth USAsia Centre and the Climate Council, recommends five practical actions for Australia to secure its economic and strategic clean energy advantages in the Indo-Pacific:" property="og:description"/>
#       <meta content="https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/" property="og:url"/>
#       <meta content="Climate Council" property="og:site_name"/>
#       <meta content="2022-07-10T21:45:07+00:00" property="article:modified_time"/>
#       <meta content="https://www.climatecouncil.org.au/wp-content/uploads/2022/07/pexels-hasan-zahra-2118560-scaled.jpg" property="og:image"/>
#       <meta content="2560" property="og:image:width"/>
#       <meta content="1440" property="og:image:height"/>
#       <meta content="image/jpeg" property="og:image:type"/>
#       <meta content="summary_large_image" name="twitter:card"/>
#       <meta content="Estimated reading time" name="twitter:label1"/>
#       <meta content="3 minutes" name="twitter:data1"/>
#       <meta content="Written by" name="twitter:label2"/>
#       <meta content="Climate Council" name="twitter:data2"/>
#       <script class="yoast-schema-graph" type="application/ld+json">
#        {"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/","url":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/","name":"Australia has key role to play as clean energy reshapes Indo-Pacific relations: new report from Perth USAsia Centre | Climate Council","isPartOf":{"@id":"https://www.climatecouncil.org.au/#website"},"primaryImageOfPage":{"@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#primaryimage"},"image":{"@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#primaryimage"},"thumbnailUrl":"https://www.climatecouncil.org.au/wp-content/uploads/2022/07/pexels-hasan-zahra-2118560-scaled.jpg","datePublished":"2022-07-10T14:01:00+00:00","dateModified":"2022-07-10T21:45:07+00:00","description":"A new report by the Perth USAsia Centre and the Climate Council, recommends five practical actions for Australia to secure its economic and strategic clean energy advantages in the Indo-Pacific:","breadcrumb":{"@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#breadcrumb"},"inLanguage":"en-GB","potentialAction":{"@type":"ListenAction","target":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#podcast_player_162723","object":{"@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#/schema/podcast"}},"mainEntityOfPage":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#/schema/podcast"},{"@type":"ImageObject","inLanguage":"en-GB","@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#primaryimage","url":"https://www.climatecouncil.org.au/wp-content/uploads/2022/07/pexels-hasan-zahra-2118560-scaled.jpg","contentUrl":"https://www.climatecouncil.org.au/wp-content/uploads/2022/07/pexels-hasan-zahra-2118560-scaled.jpg","width":2560,"height":1440},{"@type":"BreadcrumbList","@id":"https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.climatecouncil.org.au/"},{"@type":"ListItem","position":2,"name":"Resources","item":"https://www.climatecouncil.org.au/resources/"},{"@type":"ListItem","position":3,"name":"Australia has key role to play as clean energy reshapes Indo-Pacific relations: new report from Perth USAsia Centre"}]},{"@type":"WebSite","@id":"https://www.climatecouncil.org.au/#website","url":"https://www.climatecouncil.org.au/","name":"Climate Council","description":"Australians deserve independent information about climate change, from the experts.","publisher":{"@id":"https://www.climatecouncil.org.au/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.climatecouncil.org.au/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-GB"},{"@type":"Organization","@id":"https://www.climatecouncil.org.au/#organization","name":"Climate Council","url":"https://www.climatecouncil.org.au/","logo":{"@type":"ImageObject","inLanguage":"en-GB","@id":"https://www.climatecouncil.org.au/#/schema/logo/image/","url":"https://www.climatecouncil.org.au/wp-content/uploads/2017/08/facebook-logo.gif","contentUrl":"https://www.climatecouncil.org.au/wp-content/uploads/2017/08/facebook-logo.gif","width":1200,"height":630,"caption":"Climate Council"},"image":{"@id":"https://www.climatecouncil.org.au/#/schema/logo/image/"}}]}
#       </script>
#       <!-- / Yoast SEO plugin. -->
#       <link href="//platform-api.sharethis.com" rel="dns-prefetch">
#        <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
#        <link href="//www.google.com" rel="dns-prefetch"/>
#        <link href="//use.fontawesome.com" rel="dns-prefetch"/>
#        <link href="//api.mapbox.com" rel="dns-prefetch"/>
#        <script type="text/javascript">
#         window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.climatecouncil.org.au\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.2.6"}};
# /*! This file is auto-generated */
# !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){p.clearRect(0,0,i.width,i.height),p.fillText(e,0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(t,0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(p&&p.fillText)switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s("\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!s("\ud83c\uddfa\ud83c\uddf3","\ud83c\uddfa\u200b\ud83c\uddf3")&&!s("\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!s("\ud83e\udef1\ud83c\udffb\u200d\ud83e\udef2\ud83c\udfff","\ud83e\udef1\ud83c\udffb\u200b\ud83e\udef2\ud83c\udfff")}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);
#        </script>
#        <style type="text/css">
#         img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 0.07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#        </style>
#        <link href="https://www.climatecouncil.org.au/wp-includes/css/dist/block-library/style.min.css?ver=6.2.6" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#        <style id="co-authors-plus-coauthors-style-inline-css" type="text/css">
#         .wp-block-co-authors-plus-coauthors.is-layout-flow [class*=wp-block-co-authors-plus]{display:inline}
#        </style>
#        <style id="co-authors-plus-avatar-style-inline-css" type="text/css">
#         .wp-block-co-authors-plus-avatar :where(img){height:auto;max-width:100%;vertical-align:bottom}.wp-block-co-authors-plus-coauthors.is-layout-flow .wp-block-co-authors-plus-avatar :where(img){vertical-align:middle}.wp-block-co-authors-plus-avatar:is(.alignleft,.alignright){display:table}.wp-block-co-authors-plus-avatar.aligncenter{display:table;margin-inline:auto}
#        </style>
#        <style id="co-authors-plus-image-style-inline-css" type="text/css">
#         .wp-block-co-authors-plus-image{margin-bottom:0}.wp-block-co-authors-plus-image :where(img){height:auto;max-width:100%;vertical-align:bottom}.wp-block-co-authors-plus-coauthors.is-layout-flow .wp-block-co-authors-plus-image :where(img){vertical-align:middle}.wp-block-co-authors-plus-image:is(.alignfull,.alignwide) :where(img){width:100%}.wp-block-co-authors-plus-image:is(.alignleft,.alignright){display:table}.wp-block-co-authors-plus-image.aligncenter{display:table;margin-inline:auto}
#        </style>
#        <link href="https://www.climatecouncil.org.au/wp-content/plugins/climatecouncil-blocks/dist/app.css?ver=1.0.9" id="cc-style-css-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="https://www.climatecouncil.org.au/wp-includes/css/classic-themes.min.css?ver=6.2.6" id="classic-theme-styles-css" media="all" rel="stylesheet" type="text/css"/>
#        <style id="global-styles-inline-css" type="text/css">
#         body{--wp--preset--color--black: #000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #FFF;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--red: #e81b61;--wp--preset--color--orange: #fbb042;--wp--preset--color--grey-light: #ececec;--wp--preset--color--grey: #bababa;--wp--preset--color--grey-dark: #453f3c;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 14px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 20px;--wp--preset--font-size--x-large: 42px;--wp--preset--font-size--regular: 16px;--wp--preset--font-size--huge: 36px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;} ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
#        </style>
#        <link href="https://www.climatecouncil.org.au/wp-content/plugins/sharethis-share-buttons/css/mu-style.css?ver=1718073318" id="share-this-share-buttons-sticky-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/css/site.min.css?ver=1722913498" id="main-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/css/print.min.css?ver=1678067270" id="print-css" media="print" rel="stylesheet" type="text/css"/>
#        <link href="https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-geocoder/v4.7.2/mapbox-gl-geocoder.css?ver=v4.7.2" id="mapbox_geocoding_styles-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="https://api.mapbox.com/mapbox-gl-js/v2.3.1/mapbox-gl.css?ver=v2.3.1" id="mapbox_styles-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="https://www.climatecouncil.org.au/wp-content/themes/climate-council/team/css/style.css?ver=1635810532" id="team-styles-css" media="" rel="stylesheet" type="text/css"/>
#        <link href="https://www.climatecouncil.org.au/wp-content/plugins/agency-payments/assets/payments.css?ver=1.0.11" id="payments-css" media="all" rel="stylesheet" type="text/css"/>
#        <script id="jquery-core-js" src="https://www.climatecouncil.org.au/wp-includes/js/jquery/jquery.min.js?ver=3.6.4" type="text/javascript">
#        </script>
#        <script id="jquery-migrate-js" src="https://www.climatecouncil.org.au/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.0" type="text/javascript">
#        </script>
#        <script id="share-this-share-buttons-mu-js" src="//platform-api.sharethis.com/js/sharethis.js?ver=2.3.2#property=5b63a813f3742d0012c88750&amp;product=inline-buttons&amp;source=sharethis-share-buttons-wordpress" type="text/javascript">
#        </script>
#        <script id="modernizr-js" src="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/js/modernizr-2.8.3.min.js?ver=1" type="text/javascript">
#        </script>
#        <script id="throttle-js" src="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/src/js/plugins/throttle-debounce.js?ver=1" type="text/javascript">
#        </script>
#        <script id="recaptcha-js" src="//www.google.com/recaptcha/api.js?render=6LfVFpEUAAAAAMyPKhRJcpAqdjv_QB1zzkkx9I03&amp;ver=1" type="text/javascript">
#        </script>
#        <link href="https://www.climatecouncil.org.au/wp-json/" rel="https://api.w.org/"/>
#        <link href="https://www.climatecouncil.org.au/wp-json/wp/v2/resource/162723" rel="alternate" type="application/json"/>
#        <link href="https://www.climatecouncil.org.au/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#        <link href="https://www.climatecouncil.org.au/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#        <link href="https://www.climatecouncil.org.au/?p=162723" rel="shortlink"/>
#        <link href="https://www.climatecouncil.org.au/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.climatecouncil.org.au%2Fresources%2Faustralia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations%2F" rel="alternate" type="application/json+oembed"/>
#        <link href="https://www.climatecouncil.org.au/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.climatecouncil.org.au%2Fresources%2Faustralia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#        <link href="https://www.climatecouncil.org.au/feed/podcast" rel="alternate" title="Podcast RSS feed" type="application/rss+xml"/>
#        <!-- Google Tag Manager for WordPress by gtm4wp.com -->
#        <!-- GTM Container placement set to automatic -->
#        <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">
#         var dataLayer_content = {"pagePostType":"resource","pagePostType2":"single-resource","pageCategory":["climate-politics","internation"],"pagePostAuthor":"Climate Council","pagePostDate":"July 11, 2022","pagePostDateYear":2022,"pagePostDateMonth":7,"pagePostDateDay":11,"pagePostDateDayName":"Monday","pagePostDateHour":0,"pagePostDateMinute":1,"pagePostDateIso":"2022-07-11T00:01:00+10:00","pagePostDateUnix":1657497660};
# 	dataLayer.push( dataLayer_content );
#        </script>
#        <script data-cfasync="false">
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N2GT9ML');
#        </script>
#        <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
#        <style id="wp-custom-css" type="text/css">
#         .update-payment-form iframe {
# 	width: 100%;
# }
#        </style>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body class="resource-template-default single single-resource postid-162723 resource-australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations">
#   <nav class="nav-primary">
#    <button class="ham js-toggle -plain" id="nav-open" name="button" type="button">
#     <span>
#     </span>
#     <span>
#     </span>
#     <span>
#     </span>
#    </button>
#    <a class="nav-logo" href="https://www.climatecouncil.org.au">
#     <img alt="Climate Council" src="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/img/logo-dark.png" srcset="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/img/logo-dark.png 1x, https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/img/logo-dark@2x.png 2x"/>
#    </a>
#    <div class="nav-action">
#     <button class="search -plain js-toggle" name="button" type="button">
#      <span>
#      </span>
#     </button>
#     <form action="https://www.climatecouncil.org.au/" class="search-form" method="get" role="search">
#      <div class="input-wrap">
#       <input autofocus="" class="field" name="s" placeholder="Enter to search" title="Search for:" type="search" value=""/>
#       <button class="search -plain" name="button" type="submit">
#        <span>
#        </span>
#       </button>
#      </div>
#     </form>
#     <a class="button-secondary" href="/join">
#      Join
#     </a>
#     <a class="button-primary" href="https://donate.climatecouncil.org.au/">
#      Donate
#     </a>
#    </div>
#    <ul class="menu-primary">
#     <li class="menu-item-news menu-item-has-children menu-item-news">
#      <a href="https://www.climatecouncil.org.au/news/">
#       News
#      </a>
#      <span class="js-toggle submenu-toggle">
#      </span>
#      <ul class="menu-sub">
#       <span>
#        <i class="icon-tags">
#        </i>
#        Popular Categories
#       </span>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/energy/renewable-energy/">
#         <span>
#          Renewable Energy
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/extreme-weather/">
#         <span>
#          Extreme Weather
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/solutions/">
#         <span>
#          Solutions
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/climate-impacts/">
#         <span>
#          Climate Impacts
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/international-action/">
#         <span>
#          International Action
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/climate-leaders/">
#         <span>
#          Leaders
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/climate-science/">
#         <span>
#          Science
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/climate-politics/">
#         <span>
#          Politics
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/health/">
#         <span>
#          Health
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/security/">
#         <span>
#          Security
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/the-facts/">
#         <span>
#          The Facts
#         </span>
#        </a>
#       </li>
#       <li class="menu-item">
#        <a class="" href="https://www.climatecouncil.org.au/category/cities-power-partnership/">
#         <span>
#          Cities Power
#          <br/>
#          Partnership
#         </span>
#        </a>
#       </li>
#       <li class="menu-item-all">
#        <a href="https://www.climatecouncil.org.au/news/">
#         All News
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li class="">
#      <a href="https://www.climatecouncil.org.au/resource/reports/">
#       Reports
#      </a>
#     </li>
#     <li class="menu-item-resources menu-item-has-children menu-item-resources">
#      <a href="/resources">
#       Resources
#      </a>
#      <span class="js-toggle submenu-toggle">
#      </span>
#      <ul class="menu-sub">
#       <li class="menu-item has-icon-report">
#        <a class="" href="https://www.climatecouncil.org.au/resource/reports/">
#         <i class="icon-report">
#         </i>
#         <span>
#          Reports
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-promoting">
#        <a class="" href="https://www.climatecouncil.org.au/resource/media-releases/">
#         <i class="icon-promoting">
#         </i>
#         <span>
#          Media Releases
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-video-alt">
#        <a class="" href="https://www.climatecouncil.org.au/resource/videos/">
#         <i class="icon-video-alt">
#         </i>
#         <span>
#          Videos
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-infographics">
#        <a class="" href="https://www.climatecouncil.org.au/resource/infographics/">
#         <i class="icon-infographics">
#         </i>
#         <span>
#          Infographics
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-torch">
#        <a class="" href="https://www.climatecouncil.org.au/resource/mythbusting/">
#         <i class="icon-torch">
#         </i>
#         <span>
#          Mythbusting
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-communication">
#        <a class="" href="https://www.climatecouncil.org.au/resource/communication-guides/">
#         <i class="icon-communication">
#         </i>
#         <span>
#          Communication Guides
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-book-alt">
#        <a class="" href="https://www.climatecouncil.org.au/resource/explainers/">
#         <i class="icon-book-alt">
#         </i>
#         <span>
#          Explainers
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-webinar">
#        <a class="" href="https://www.climatecouncil.org.au/resource/webinars/">
#         <i class="icon-webinar">
#         </i>
#         <span>
#          Webinars
#         </span>
#        </a>
#       </li>
#       <li class="menu-item-all">
#        <a href="https://www.climatecouncil.org.au/resources">
#         All Resources
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li class="menu-item-involved menu-item-has-children menu-item-involved">
#      <a href="https://www.climatecouncil.org.au/get-involved/">
#       Get Involved
#      </a>
#      <span class="js-toggle submenu-toggle">
#      </span>
#      <ul class="menu-sub">
#       <li class="menu-item menu-item-action">
#        <a class="" href="https://www.climatecouncil.org.au/get-involved/take-action/">
#         <i class="icon-write">
#         </i>
#         <span>
#          Take Action
#         </span>
#        </a>
#        <ul class="menu-sub">
#         <li>
#          <a href="https://www.climatecouncil.org.au/actions/open-letter-double-australias-rooftop-solar/">
#           Sign the open letter: Double Australia’s rooftop solar capacity by 2030!
#          </a>
#         </li>
#         <li>
#          <a href="https://www.climatecouncil.org.au/actions/help-us-ask-for-cleaner-cheaper-transport/">
#           Help us Ask for Cleaner, Cheaper Transport
#          </a>
#         </li>
#         <li>
#          <a href="https://www.climatecouncil.org.au/actions/pen-letter-zero-interest-loans/">
#           open letter to federal &amp; State Governments
#          </a>
#         </li>
#         <li>
#          <a href="https://www.climatecouncil.org.au/actions/gas-free-pledge/">
#           Pledge to go gas-free today!
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item has-icon-vote">
#        <a class="" href="https://www.climatecouncil.org.au/get-involved/fundraise-for-us/">
#         <i class="icon-vote">
#         </i>
#         <span>
#          Fundraise
#          <strong>
#           for Us
#          </strong>
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-hand-dollar">
#        <a class="" href="https://www.climatecouncil.org.au/get-involved/giving/">
#         <i class="icon-hand-dollar">
#         </i>
#         <span>
#          Giving
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-people">
#        <a class="" href="https://www.climatecouncil.org.au/get-involved/volunteer/">
#         <i class="icon-people">
#         </i>
#         <span>
#          Volunteer
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-job">
#        <a class="" href="https://www.climatecouncil.org.au/get-involved/jobs/">
#         <i class="icon-job">
#         </i>
#         <span>
#          Jobs
#         </span>
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li class="">
#      <a href="https://www.climatecouncil.org.au/resource/media-releases/">
#       Media
#      </a>
#     </li>
#     <li class="menu-item-has-children menu-item-about">
#      <a href="https://www.climatecouncil.org.au/about/">
#       About Us
#      </a>
#      <span class="js-toggle submenu-toggle">
#      </span>
#      <ul class="menu-sub">
#       <li class="menu-item has-icon-info-alt">
#        <a class="" href="https://www.climatecouncil.org.au/about/">
#         <i class="icon-info-alt">
#         </i>
#         <span>
#          About Us
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-team">
#        <a class="" href="https://www.climatecouncil.org.au/team/">
#         <i class="icon-team">
#         </i>
#         <span>
#          Team
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-faq">
#        <a class="" href="https://www.climatecouncil.org.au/faqs/">
#         <i class="icon-faq">
#         </i>
#         <span>
#          FAQs
#         </span>
#        </a>
#       </li>
#       <li class="menu-item has-icon-contact">
#        <a class="" href="https://www.climatecouncil.org.au/contact/">
#         <i class="icon-contact">
#         </i>
#         <span>
#          Contact Us
#         </span>
#        </a>
#       </li>
#      </ul>
#     </li>
#    </ul>
#    <ul class="menu-resources-sub">
#     <li class="menu-item has-icon-report">
#      <a class="" href="https://www.climatecouncil.org.au/resource/reports/">
#       <i class="icon-report">
#       </i>
#       <span>
#        Reports
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-promoting">
#      <a class="" href="https://www.climatecouncil.org.au/resource/media-releases/">
#       <i class="icon-promoting">
#       </i>
#       <span>
#        Media Releases
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-video-alt">
#      <a class="" href="https://www.climatecouncil.org.au/resource/videos/">
#       <i class="icon-video-alt">
#       </i>
#       <span>
#        Videos
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-infographics">
#      <a class="" href="https://www.climatecouncil.org.au/resource/infographics/">
#       <i class="icon-infographics">
#       </i>
#       <span>
#        Infographics
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-torch">
#      <a class="" href="https://www.climatecouncil.org.au/resource/mythbusting/">
#       <i class="icon-torch">
#       </i>
#       <span>
#        Mythbusting
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-communication">
#      <a class="" href="https://www.climatecouncil.org.au/resource/communication-guides/">
#       <i class="icon-communication">
#       </i>
#       <span>
#        Communication Guides
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-book-alt">
#      <a class="" href="https://www.climatecouncil.org.au/resource/explainers/">
#       <i class="icon-book-alt">
#       </i>
#       <span>
#        Explainers
#       </span>
#      </a>
#     </li>
#     <li class="menu-item has-icon-webinar">
#      <a class="" href="https://www.climatecouncil.org.au/resource/webinars/">
#       <i class="icon-webinar">
#       </i>
#       <span>
#        Webinars
#       </span>
#      </a>
#     </li>
#    </ul>
#   </nav>
#   <header class="header card -featured">
#    <!-- <div class="logo-label">
#
#
# 		</div> -->
#    <span class="image" style="background:url(https://www.climatecouncil.org.au/wp-content/uploads/2022/07/pexels-hasan-zahra-2118560-1600x900.jpg) no-repeat center center / cover">
#    </span>
#   </header>
#   <main class="post-content">
#    <div class="title">
#     <ul class="breadcrumbs">
#      <li>
#       <a href="/resources">
#        Resources
#       </a>
#      </li>
#      <li class="no-children">
#       <a href="https://www.climatecouncil.org.au/resource/media-releases/">
#        Media Releases
#       </a>
#      </li>
#     </ul>
#     <h2>
#      <a href="https://www.climatecouncil.org.au/resources/australia-key-role-to-play-clean-energy-reshapes-indo-pacific-relations/">
#       Australia has key role to play as clean energy reshapes Indo-Pacific relations: new report from Perth USAsia Centre
#      </a>
#     </h2>
#     <div class="social-share">
#      <div class="sharethis-inline-share-buttons">
#      </div>
#     </div>
#    </div>
#    <div class="meta">
#     <span class="date">
#      11.07.22
#     </span>
#     <span class="author">
#      By
#      <a class="author url fn" href="https://www.climatecouncil.org.au/author/climate-council/" rel="author" title="Posts by Climate Council">
#       Climate Council
#      </a>
#     </span>
#     <div class="social">
#     </div>
#    </div>
#    <article>
#     <div class="payment-form-alert has-small-font-size" style="margin-bottom: 1em">
#      <i class="icon-clock">
#      </i>
#      This content is more than
#      <strong>
#       2 years old
#      </strong>
#     </div>
#     <p>
#      With the incoming federal government declaring it will make Australia a “renewable superpower”, China dominating clean energy supply chains, and the Russian war in Ukraine disrupting the global energy market, now is a pivotal moment for Australia to shape the future of clean energy within the Indo-Pacific.
#     </p>
#     <p>
#      <strong>
#       A
#       <a href="https://www.climatecouncil.org.au/resources/re-energising-the-indo-pacific-australias-clean-energy-opportunity/" rel="noreferrer noopener" target="_blank">
#        new report by the Perth USAsia Centre, in collaboration with the Climate Council
#       </a>
#       , recommends five practical actions for Australia to secure its economic and strategic clean energy advantages in the Indo-Pacific
#      </strong>
#      :
#     </p>
#     <ol>
#      <li>
#       Promote the many economic, strategic, and energy security benefits of clean energy in the region.
#      </li>
#      <li>
#       Diversify clean energy supply chains and relationships so all countries in the region enjoy fairer access and greater energy resilience.
#      </li>
#      <li>
#       Develop a dedicated clean energy diplomacy program with the Department of Foreign Affairs and Trade that provides assistance to developing countries and leverages Australia’s key advantages.
#      </li>
#      <li>
#       Expand the focus of our clean energy outreach beyond economic and political capacity to increase inclusivity and better governance.
#      </li>
#      <li>
#       Work with all allies and partners, led by the Quad, to develop a truly multilateral Indo-Pacific clean energy program that promotes coordination and collaboration, and guards against risks.
#      </li>
#     </ol>
#     <p>
#      Published ahead of a major international forum on energy supply chains – the
#      <a href="https://www.sydneyenergyforum.gov.au/about" rel="noreferrer noopener" target="_blank">
#       Sydney Energy Forum
#      </a>
#      (12-13 July) – the report,
#      <a href="https://www.climatecouncil.org.au/resources/re-energising-the-indo-pacific-australias-clean-energy-opportunity/" rel="noreferrer noopener" target="_blank">
#       <em>
#        Reenergising Indo-Pacific Relations: Australia’s Clean Energy Opportunity
#       </em>
#       ,
#      </a>
#      explains that the Indo-Pacific sits at the heart of the global shift from fossil fuels to clean energy systems, the ramifications for Australia’s economic and strategic interests, and the leading role that our country could play.
#     </p>
#     <p>
#      Global warming is a significant security threat for all countries, but those within the Indo-Pacific region are among  the most vulnerable. More affordable and available renewables can improve energy security and erode troublesome interdependencies in the region. However, significant obstacles must be overcome, including China’s dominance in the global energy sector.
#     </p>
#     <p>
#      “The necessary transition from fossil fuel to clean energy systems is reordering Indo-Pacific relations. Australian government and industry should work to ensure emerging supply chains and interdependencies advance our national interest,”
#      <strong>
#       said report author James Bowen.
#      </strong>
#     </p>
#     <p>
#      China’s current dominance in global clean energy sectors has created vulnerabilities for both the energy transition, and broader system of Indo-Pacific relations. Diversifying supply chains and relationships is pivotal to the clean energy transition, and countries such as Australia have untapped potential to improve supply chain resilience and create a fairer and well-governed Indo-Pacific transition.
#     </p>
#     <p>
#      Australia’s role in the regional energy landscape is currently as a major supplier of coal and gas to economies in the Indo-Pacific. However, the shift toward net-zero emissions has profoundly changed Australia’s economic prospects. Economies such as Japan and Korea will continue to want Australian exports, but they now expect clean energy alternatives.
#     </p>
#     <p>
#      “Australia has emerging clean energy strengths in the critical minerals, technology, resources and industrial goods sectors. Enhancing cooperation with partners and allies could unlock the country’s vast economic and strategic potential in a decarbonising Indo-Pacific,”
#      <strong>
#       continued Bowen.
#      </strong>
#     </p>
#     <p>
#      <strong>
#       Climate Council Senior Researcher Dr Wesley Morgan added:
#      </strong>
#      “The growing economic advantages of renewable energy are driving an unprecedented global energy transition and the Indo-Pacific is at the heart of it. The upcoming Sydney Energy Forum presents a huge opportunity for Australia to shape the future of clean energy cooperation in the Indo-Pacific.
#     </p>
#     <p>
#      “There can be no doubt that Australia’s economic and strategic interests are now tied to leading a rapid clean energy transition.”
#     </p>
#     <p>
#      With both its natural resources and geopolitical alignments, Australia has the potential to become a clean energy superpower. The time is right for Australia to accelerate clean energy and associated climate action and secure its economic and strategic advantage in the Indo-Pacific’s clean energy future.
#     </p>
#     <p>
#     </p>
#     <p>
#      <strong>
#       For Media please contact:
#      </strong>
#     </p>
#     <p>
#      <strong>
#       Ryan Gibson
#      </strong>
#      :
#      <strong>
#       Media and Communications Coordinator
#      </strong>
#     </p>
#     <p>
#      <strong>
#       E:
#      </strong>
#      <a href="mailto:ryan.r.gibson@perthusasia.edu.au" rel="noreferrer noopener" target="_blank">
#       <strong>
#        ryan.r.gibson@perthusasia.edu.au
#       </strong>
#      </a>
#      <strong>
#      </strong>
#      <strong>
#       T: +61 8 6488 4328
#      </strong>
#     </p>
#     <p>
#     </p>
#     <p>
#      <strong>
#       Lydia Jupp
#      </strong>
#      :
#      <strong>
#       Media Officer (Climate Council)
#      </strong>
#     </p>
#     <p>
#      <strong>
#       E:
#      </strong>
#      <a href="mailto:lydia.jupp@climatecouncil.org.au" rel="noreferrer noopener" target="_blank">
#       <strong>
#        lydia.jupp@climatecouncil.org.au
#       </strong>
#      </a>
#      <strong>
#      </strong>
#     </p>
#     <p>
#      <strong>
#       T: 0428 980 839
#      </strong>
#     </p>
#     <p>
#      <meta charset="utf-8"/>
#      For further information, go to:
#      <a href="http://climatecouncil.org.au/?_ga=2.191338723.837444627.1613948161-1095504863.1605741024&amp;_gac=1.255761786.1611793567.Cj0KCQiA0fr_BRDaARIsAABw4EtyTV8HGE2VTxsHDa5AmtP93qPJv2r5ye3f4h2Vga_LYFPc4gBXDq8aAlKvEALw_wcB" rel="noreferrer noopener" target="_blank">
#       climatecouncil.org.au
#      </a>
#      Or follow us on social media:
#      <a href="https://facebook.com/climatecouncil" rel="noreferrer noopener" target="_blank">
#       facebook.com/climatecouncil
#      </a>
#      and
#      <a href="https://twitter.com/climatecouncil" rel="noreferrer noopener" target="_blank">
#       twitter.com/climatecouncil
#      </a>
#     </p>
#    </article>
#    <aside data-sticky="post-content" id="downloads">
#     <ul class="tab -further">
#      <li class="more">
#       <a class="more-arrow -main" href="https://www.climatecouncil.org.au/resource/media-releases/">
#        <span class="title">
#         More Media Releases
#        </span>
#        <div>
#         <span>
#         </span>
#        </div>
#       </a>
#      </li>
#     </ul>
#     <ul class="tab -related">
#      <li class="title">
#       <h6>
#        Related resources
#       </h6>
#      </li>
#      <li>
#       <a class="more-arrow" href="https://www.climatecouncil.org.au/resources/duttons-uncosted-nuclear-risks-energy-security/">
#        Peter Dutton’s weird obsession with uncosted nuclear risks energy security, the economy and our kids’ future
#        <div>
#         <span>
#         </span>
#        </div>
#       </a>
#      </li>
#      <li>
#       <a class="more-arrow" href="https://www.climatecouncil.org.au/resources/co-hosting-un-climate-talks-australias-economic-security-interests/">
#        Co-hosting UN climate talks in Australia’s economic and security interests
#        <div>
#         <span>
#         </span>
#        </div>
#       </a>
#      </li>
#      <li>
#       <a class="more-arrow" href="https://www.climatecouncil.org.au/resources/the-pacific-partnership-that-can-power-security-prosperity/">
#        Winning bid: The Pacific partnership that can power our security and prosperity.
#        <div>
#         <span>
#         </span>
#        </div>
#       </a>
#      </li>
#     </ul>
#    </aside>
#   </main>
#   <section class="row stream -mid">
#    <div class="sub-title">
#     Related resources
#    </div>
#    <div class="resources js-slick">
#     <article class="card -resource">
#      <a class="cat" href="https://www.climatecouncil.org.au/category/climate-politics/">
#       Climate Politics
#      </a>
#      <a class="title" href="https://www.climatecouncil.org.au/resources/duttons-uncosted-nuclear-risks-energy-security/">
#       Peter Dutton’s weird obsession with uncosted nuclear risks energy security, the economy and our kids’ future
#      </a>
#      <a class="image-wrap" href="https://www.climatecouncil.org.au/resources/duttons-uncosted-nuclear-risks-energy-security/">
#       <span class="image" style="background: url(https://www.climatecouncil.org.au/wp-content/uploads/2024/06/nuclear-waste-1024x576.png) no-repeat center center / cover">
#       </span>
#      </a>
#      <span class="underline">
#      </span>
#     </article>
#     <article class="card -resource">
#      <a class="cat" href="https://www.climatecouncil.org.au/category/climate-politics/australia/">
#       Australia
#      </a>
#      <a class="title" href="https://www.climatecouncil.org.au/resources/co-hosting-un-climate-talks-australias-economic-security-interests/">
#       Co-hosting UN climate talks in Australia’s economic and security interests
#      </a>
#      <a class="image-wrap" href="https://www.climatecouncil.org.au/resources/co-hosting-un-climate-talks-australias-economic-security-interests/">
#       <span class="image" style="background: url(https://www.climatecouncil.org.au/wp-content/uploads/2024/09/bowen-1024x512.png) no-repeat center center / cover">
#       </span>
#      </a>
#      <span class="underline">
#      </span>
#     </article>
#     <article class="card -resource">
#      <a class="cat" href="https://www.climatecouncil.org.au/category/climate-change/">
#       Climate Change
#      </a>
#      <a class="title" href="https://www.climatecouncil.org.au/resources/the-pacific-partnership-that-can-power-security-prosperity/">
#       Winning bid: The Pacific partnership that can power our security and prosperity.
#      </a>
#      <a class="image-wrap" href="https://www.climatecouncil.org.au/resources/the-pacific-partnership-that-can-power-security-prosperity/">
#       <span class="image" style="background: url(https://www.climatecouncil.org.au/wp-content/uploads/2024/09/albo-1024x512.png) no-repeat center center / cover">
#       </span>
#      </a>
#      <span class="underline">
#      </span>
#     </article>
#    </div>
#    <div class="more-arrow -sub">
#     <a href="/resources">
#      More resources
#      <div>
#       <span>
#       </span>
#      </div>
#     </a>
#    </div>
#    <div class="links">
#     <ul>
#      <li>
#       <a href="/news">
#        News
#       </a>
#      </li>
#      <li>
#       <a href="/resources">
#        Resources
#       </a>
#      </li>
#      <li>
#       <a href="/resource/reports">
#        Reports
#       </a>
#      </li>
#      <li>
#       <a href="/get-involved">
#        Get Involved
#       </a>
#      </li>
#     </ul>
#    </div>
#   </section>
#   <footer class="dynamic-footer">
#    <div class="footer-widgets widget_block" id="block-2">
#     <div class="wp-block-group alignfull has-white-color has-grey-dark-background-color has-text-color has-background is-layout-flow">
#      <div class="wp-block-group__inner-container">
#       <div aria-hidden="true" class="wp-block-spacer" style="height:33px">
#       </div>
#       <div class="wp-block-columns flex-reverse-mobile is-layout-flex wp-container-11">
#        <div class="wp-block-column has-none-background-color has-background is-layout-flow">
#         <div class="widget widget_nav_menu">
#          <div class="menu-secondary-navigation-container">
#           <ul class="menu" id="menu-secondary-navigation">
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-503" id="menu-item-503">
#             <a href="https://www.climatecouncil.org.au/contact/">
#              Contact
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-taxonomy menu-item-object-resource-type current-resource-ancestor current-menu-parent current-resource-parent menu-item-505" id="menu-item-505">
#             <a href="https://www.climatecouncil.org.au/resource/media-releases/">
#              Media
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-485" id="menu-item-485">
#             <a href="https://www.climatecouncil.org.au/faqs/">
#              FAQs
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <p>
#          <em>
#           The Climate Council acknowledges the Traditional Owners of the lands on which we live, meet and work. We wish to pay our respects to Elders past and present and recognise the continuous connection of Aboriginal and Torres Strait Islander people to land, water and Country.
#          </em>
#         </p>
#         <ul class="wp-block-social-links has-icon-color is-style-logos-only is-layout-flex">
#          <li class="wp-social-link wp-social-link-facebook wp-block-social-link" style="color: #bababa; ">
#           <a class="wp-block-social-link-anchor" href="http://facebook.com/climatecouncil" rel="noopener nofollow" target="_blank">
#            <svg aria-hidden="true" focusable="false" height="24" version="1.1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M12 2C6.5 2 2 6.5 2 12c0 5 3.7 9.1 8.4 9.9v-7H7.9V12h2.5V9.8c0-2.5 1.5-3.9 3.8-3.9 1.1 0 2.2.2 2.2.2v2.5h-1.3c-1.2 0-1.6.8-1.6 1.6V12h2.8l-.4 2.9h-2.3v7C18.3 21.1 22 17 22 12c0-5.5-4.5-10-10-10z">
#             </path>
#            </svg>
#            <span class="wp-block-social-link-label screen-reader-text">
#             Facebook
#            </span>
#           </a>
#          </li>
#          <li class="wp-social-link wp-social-link-twitter wp-block-social-link" style="color: #bababa; ">
#           <a class="wp-block-social-link-anchor" href="http://twitter.com/climatecouncil" rel="noopener nofollow" target="_blank">
#            <svg aria-hidden="true" focusable="false" height="24" version="1.1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M22.23,5.924c-0.736,0.326-1.527,0.547-2.357,0.646c0.847-0.508,1.498-1.312,1.804-2.27 c-0.793,0.47-1.671,0.812-2.606,0.996C18.324,4.498,17.257,4,16.077,4c-2.266,0-4.103,1.837-4.103,4.103 c0,0.322,0.036,0.635,0.106,0.935C8.67,8.867,5.647,7.234,3.623,4.751C3.27,5.357,3.067,6.062,3.067,6.814 c0,1.424,0.724,2.679,1.825,3.415c-0.673-0.021-1.305-0.206-1.859-0.513c0,0.017,0,0.034,0,0.052c0,1.988,1.414,3.647,3.292,4.023 c-0.344,0.094-0.707,0.144-1.081,0.144c-0.264,0-0.521-0.026-0.772-0.074c0.522,1.63,2.038,2.816,3.833,2.85 c-1.404,1.1-3.174,1.756-5.096,1.756c-0.331,0-0.658-0.019-0.979-0.057c1.816,1.164,3.973,1.843,6.29,1.843 c7.547,0,11.675-6.252,11.675-11.675c0-0.178-0.004-0.355-0.012-0.531C20.985,7.47,21.68,6.747,22.23,5.924z">
#             </path>
#            </svg>
#            <span class="wp-block-social-link-label screen-reader-text">
#             Twitter
#            </span>
#           </a>
#          </li>
#          <li class="wp-social-link wp-social-link-youtube wp-block-social-link" style="color: #bababa; ">
#           <a class="wp-block-social-link-anchor" href="http://youtube.com/user/ClimateCouncil" rel="noopener nofollow" target="_blank">
#            <svg aria-hidden="true" focusable="false" height="24" version="1.1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M21.8,8.001c0,0-0.195-1.378-0.795-1.985c-0.76-0.797-1.613-0.801-2.004-0.847c-2.799-0.202-6.997-0.202-6.997-0.202 h-0.009c0,0-4.198,0-6.997,0.202C4.608,5.216,3.756,5.22,2.995,6.016C2.395,6.623,2.2,8.001,2.2,8.001S2,9.62,2,11.238v1.517 c0,1.618,0.2,3.237,0.2,3.237s0.195,1.378,0.795,1.985c0.761,0.797,1.76,0.771,2.205,0.855c1.6,0.153,6.8,0.201,6.8,0.201 s4.203-0.006,7.001-0.209c0.391-0.047,1.243-0.051,2.004-0.847c0.6-0.607,0.795-1.985,0.795-1.985s0.2-1.618,0.2-3.237v-1.517 C22,9.62,21.8,8.001,21.8,8.001z M9.935,14.594l-0.001-5.62l5.404,2.82L9.935,14.594z">
#             </path>
#            </svg>
#            <span class="wp-block-social-link-label screen-reader-text">
#             YouTube
#            </span>
#           </a>
#          </li>
#          <li class="wp-social-link wp-social-link-instagram wp-block-social-link" style="color: #bababa; ">
#           <a class="wp-block-social-link-anchor" href="http://instagram.com/theclimatecouncil" rel="noopener nofollow" target="_blank">
#            <svg aria-hidden="true" focusable="false" height="24" version="1.1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M12,4.622c2.403,0,2.688,0.009,3.637,0.052c0.877,0.04,1.354,0.187,1.671,0.31c0.42,0.163,0.72,0.358,1.035,0.673 c0.315,0.315,0.51,0.615,0.673,1.035c0.123,0.317,0.27,0.794,0.31,1.671c0.043,0.949,0.052,1.234,0.052,3.637 s-0.009,2.688-0.052,3.637c-0.04,0.877-0.187,1.354-0.31,1.671c-0.163,0.42-0.358,0.72-0.673,1.035 c-0.315,0.315-0.615,0.51-1.035,0.673c-0.317,0.123-0.794,0.27-1.671,0.31c-0.949,0.043-1.233,0.052-3.637,0.052 s-2.688-0.009-3.637-0.052c-0.877-0.04-1.354-0.187-1.671-0.31c-0.42-0.163-0.72-0.358-1.035-0.673 c-0.315-0.315-0.51-0.615-0.673-1.035c-0.123-0.317-0.27-0.794-0.31-1.671C4.631,14.688,4.622,14.403,4.622,12 s0.009-2.688,0.052-3.637c0.04-0.877,0.187-1.354,0.31-1.671c0.163-0.42,0.358-0.72,0.673-1.035 c0.315-0.315,0.615-0.51,1.035-0.673c0.317-0.123,0.794-0.27,1.671-0.31C9.312,4.631,9.597,4.622,12,4.622 M12,3 C9.556,3,9.249,3.01,8.289,3.054C7.331,3.098,6.677,3.25,6.105,3.472C5.513,3.702,5.011,4.01,4.511,4.511 c-0.5,0.5-0.808,1.002-1.038,1.594C3.25,6.677,3.098,7.331,3.054,8.289C3.01,9.249,3,9.556,3,12c0,2.444,0.01,2.751,0.054,3.711 c0.044,0.958,0.196,1.612,0.418,2.185c0.23,0.592,0.538,1.094,1.038,1.594c0.5,0.5,1.002,0.808,1.594,1.038 c0.572,0.222,1.227,0.375,2.185,0.418C9.249,20.99,9.556,21,12,21s2.751-0.01,3.711-0.054c0.958-0.044,1.612-0.196,2.185-0.418 c0.592-0.23,1.094-0.538,1.594-1.038c0.5-0.5,0.808-1.002,1.038-1.594c0.222-0.572,0.375-1.227,0.418-2.185 C20.99,14.751,21,14.444,21,12s-0.01-2.751-0.054-3.711c-0.044-0.958-0.196-1.612-0.418-2.185c-0.23-0.592-0.538-1.094-1.038-1.594 c-0.5-0.5-1.002-0.808-1.594-1.038c-0.572-0.222-1.227-0.375-2.185-0.418C14.751,3.01,14.444,3,12,3L12,3z M12,7.378 c-2.552,0-4.622,2.069-4.622,4.622S9.448,16.622,12,16.622s4.622-2.069,4.622-4.622S14.552,7.378,12,7.378z M12,15 c-1.657,0-3-1.343-3-3s1.343-3,3-3s3,1.343,3,3S13.657,15,12,15z M16.804,6.116c-0.596,0-1.08,0.484-1.08,1.08 s0.484,1.08,1.08,1.08c0.596,0,1.08-0.484,1.08-1.08S17.401,6.116,16.804,6.116z">
#             </path>
#            </svg>
#            <span class="wp-block-social-link-label screen-reader-text">
#             Instagram
#            </span>
#           </a>
#          </li>
#         </ul>
#         <div class="subscribe wp-block-signup-form" id="wp-block-signup-form-block_8c1d6070812b460f0a18fded4b91235e">
#          <div class="subscribe-form full">
#           <h3 style="margin-bottom:0">
#            Subscribe to our newsletter for the latest climate &amp; energy news.
#           </h3>
#           <div class="subscribe wp-block-form-assembly" id="wp-block-form-assembly-block_167820">
#            <div>
#             <iframe class="fa-iframe" frameborder="0" height="150" loading="lazy" src="https://tfaforms.com/4966044?tfa_2510=701980000008yIFAAY" width="100%">
#             </iframe>
#             <script src="//tfaforms.com/js/iframe_resize_helper.js">
#             </script>
#            </div>
#           </div>
#           <p class="subscribe-text">
#            You can unsubscribe at any time. For more detail on how we collect, store and use your information, please read our
#            <a href="https://www.climatecouncil.org.au/privacy-policy/" target="_blank">
#             privacy policy
#            </a>
#            .
#           </p>
#          </div>
#         </div>
#         <div class="wp-block-columns is-layout-flex wp-container-8">
#          <div class="wp-block-column is-layout-flow" style="flex-basis:100%">
#           <div class="wp-block-columns is-layout-flex wp-container-6">
#            <div class="wp-block-column is-layout-flow" style="flex-basis:100%">
#             <div class="wp-block-columns are-vertically-aligned-center is-layout-flex wp-container-4">
#              <div class="wp-block-column is-vertically-aligned-center is-layout-flow" style="flex-basis:50%">
#               <div class="wp-block-image">
#                <figure class="alignleft size-medium is-resized">
#                 <a href="https://www.acnc.gov.au/charity/charities/1c4c9cff-39af-e811-a962-000d3ad24a0d/profile">
#                  <img alt="" class="wp-image-161819" decoding="async" height="100" loading="lazy" sizes="(max-width: 100px) 100vw, 100px" src="https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB-300x300.png" srcset="https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB-300x300.png 300w, https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB-150x150.png 150w, https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB-768x768.png 768w, https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB-900x900.png 900w, https://www.climatecouncil.org.au/wp-content/uploads/2022/02/ACNC-Registered-Charity-Logo_RGB.png 960w" width="100"/>
#                 </a>
#                </figure>
#               </div>
#              </div>
#              <div class="wp-block-column is-vertically-aligned-center is-layout-flow" style="flex-basis:50%">
#               <figure class="wp-block-image size-large is-resized">
#                <img alt="" class="wp-image-163473" decoding="async" height="87" loading="lazy" sizes="(max-width: 201px) 100vw, 201px" src="https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-1024x443.png" srcset="https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-1024x443.png 1024w, https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-300x130.png 300w, https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-768x332.png 768w, https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-1536x665.png 1536w, https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-2048x886.png 2048w, https://www.climatecouncil.org.au/wp-content/uploads/2022/10/fia-mb-organisationalcc-cmyk-white-background-added-1-1600x692.png 1600w" width="201"/>
#               </figure>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="widget widget_nav_menu">
#          <div class="menu-footer-navigation-container">
#           <ul class="menu" id="menu-footer-navigation">
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-482" id="menu-item-482">
#             <a href="https://www.climatecouncil.org.au/privacy-policy/">
#              Privacy Policy
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-481" id="menu-item-481">
#             <a href="https://www.climatecouncil.org.au/donation-policy/">
#              Donation Policy
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <p class="has-grey-color has-text-color" style="font-size:12px">
#          <meta charset="utf-8"/>
#          <em>
#           donations over $2 to the Climate Council may be tax deductible, and a receipt will be emailed to you
#          </em>
#          .
#          <strong>
#           The Climate Council is a registered charity with the Australian Charities and Not-for-profits Commission (ACNC).
#          </strong>
#          Registered Charity Number: ACN 165 914 303
#         </p>
#         <div aria-hidden="true" class="wp-block-spacer" style="height:20px">
#         </div>
#        </div>
#        <div class="wp-block-column has-none-background-color has-background is-layout-flow" style="flex-basis:140px">
#         <figure class="wp-block-image size-full is-resized">
#          <img alt="Climate Council logo" class="wp-image-13611" decoding="async" height="72" loading="lazy" sizes="(max-width: 182px) 100vw, 182px" src="http://climatecouncil-wp.localhost/wp-content/uploads/2019/04/cc-logo-524px.png" srcset="https://www.climatecouncil.org.au/wp-content/uploads/2019/04/cc-logo-524px.png 554w, https://www.climatecouncil.org.au/wp-content/uploads/2019/04/cc-logo-524px-300x120.png 300w" width="182"/>
#         </figure>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- .footer-widget -->
#   </footer>
#   <style id="core-block-supports-inline-css" type="text/css">
#    .wp-container-4.wp-container-4,.wp-container-6.wp-container-6,.wp-container-8.wp-container-8,.wp-container-11.wp-container-11{flex-wrap:nowrap;}
#   </style>
#   <script id="accounts-js" src="https://www.climatecouncil.org.au/wp-content/plugins/agency-accounts//assets/accounts.js?ver=1.0" type="text/javascript">
#   </script>
#   <script id="campaignactions-theme-js" src="https://www.climatecouncil.org.au/wp-content/plugins/agency-actions-kepla/assets/theme.js?ver=2.1" type="text/javascript">
#   </script>
#   <script id="gtm4wp-form-move-tracker-js" src="https://www.climatecouncil.org.au/wp-content/plugins/duracelltomi-google-tag-manager/dist/js/gtm4wp-form-move-tracker.js?ver=1.20.2" type="text/javascript">
#   </script>
#   <script id="validate-js" src="//cdnjs.cloudflare.com/ajax/libs/jquery-validate/1.15.0/jquery.validate.min.js?ver=1.15.0" type="text/javascript">
#   </script>
#   <script id="placeholders-js" src="//cdnjs.cloudflare.com/ajax/libs/jquery-placeholder/2.1.3/jquery.placeholder.min.js?ver=2.1.3" type="text/javascript">
#   </script>
#   <script id="modals-js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-modal/0.9.1/jquery.modal.min.js?ver=0.9.1" type="text/javascript">
#   </script>
#   <script id="site-js" src="https://www.climatecouncil.org.au/wp-content/themes/climate-council/assets/dist/js/site.js?ver=1725403188" type="text/javascript">
#   </script>
#   <script id="team-script-js" src="https://www.climatecouncil.org.au/wp-content/themes/climate-council/team/js/app.js?ver=1635810532" type="text/javascript">
#   </script>
#   <script id="fa-script-js" src="https://use.fontawesome.com/36bffc945f.js?ver=1.0.0" type="text/javascript">
#   </script>
#   <script id="jquery.validate-js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-validate/1.14.0/jquery.validate.min.js?ver=1.14.0" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
main_content = soup.find('article')
for element in main_content(['header', 'footer', 'aside', 'script']):
    element.decompose()

# %%
text_list = []
stop_text = "The time is right for Australia to accelerate clean energy and associated climate action and secure its economic and strategic advantage in the Indo-Pacific’s clean energy future."
for paragraph in main_content.find_all('p'):
    paragraph_text = paragraph.get_text(separator=' ', strip=False)

    if stop_text in paragraph_text:
        text_list.append(paragraph_text)
        break
    text_list.append(paragraph_text)

# %%
df = pd.DataFrame(text_list, columns=["Paragraph Text"])
df.to_csv('01_paragraphs.csv', index=False)

# %%
df
# Out:
#                                        Paragraph Text
# 0   With the incoming federal government declaring...
# 1   A  new report by the Perth USAsia Centre, in c...
# 2   Published ahead of a major international forum...
# 3   Global warming is a significant security threa...
# 4   “The necessary transition from fossil fuel to ...
# 5   China’s current dominance in global clean ener...
# 6   Australia’s role in the regional energy landsc...
# 7   “Australia has emerging clean energy strengths...
# 8   Climate Council Senior Researcher Dr Wesley Mo...
# 9   “There can be no doubt that Australia’s econom...
# 10  With both its natural resources and geopolitic...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('01_paragraphs.csv')

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/loogyee/anaconda3/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 4.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
relationship_keywords = {'collaboration', 'cooperation', 'partner', 'engage', 
                         'support', 'fund', 'finance', 'invest', 'develop', 
                         'supply', 'promote', 'transition', 'export', 'agreement', 
                         'interest', 'share', 'enhance', 'effort', 'import'}

# %%
def extract_entities_and_relationships(text):
    doc = nlp(text)  # Process text with spaCy
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['ORG', 'GPE']]

    # Find relationships based on keywords
    relationships = []
    for token in doc:
        if token.lemma_ in relationship_keywords:  # Use lemma_ to check relationship keywords
            subject = [w for w in token.children if w.dep_ == "nsubj"]  # Find subject
            object_ = [w for w in token.children if w.dep_ == "dobj"]  # Find object
            if subject and object_:
                relationships.append((subject[0].text, token.text, object_[0].text))  # (subject, relationship, object)

    return entities, relationships

# %%
df['Entities'], df['Relationships'] = zip(*df['Paragraph Text'].apply(extract_entities_and_relationships))

# %%
df[['Paragraph Text', 'Entities', 'Relationships']]
# Out:
#                                        Paragraph Text  \
# 0   With the incoming federal government declaring...
# 1   A  new report by the Perth USAsia Centre, in c...
# 2   Published ahead of a major international forum...
# 3   Global warming is a significant security threa...
# 4   “The necessary transition from fossil fuel to ...
# 5   China’s current dominance in global clean ener...
# 6   Australia’s role in the regional energy landsc...
# 7   “Australia has emerging clean energy strengths...
# 8   Climate Council Senior Researcher Dr Wesley Mo...
# 9   “There can be no doubt that Australia’s econom...
# 10  With both its natural resources and geopolitic...
#
#                                              Entities Relationships
# 0   [(Australia, GPE), (China, GPE), (Ukraine, GPE...            []
# 1   [(the Perth USAsia Centre, ORG), (the Climate ...            []
# 2   [(Sydney Energy Forum, ORG), (Reenergising Ind...            []
# 3             [(the Indo-Pacific, ORG), (China, GPE)]            []
# 4                               [(Indo-Pacific, ORG)]            []
# 5   [(China, GPE), (Indo-Pacific, ORG), (Australia...            []
# 6   [(Australia, GPE), (the Indo-Pacific, ORG), (A...            []
# 7             [(Australia, GPE), (Indo-Pacific, ORG)]            []
# 8   [(Climate Council Senior Researcher, ORG), (th...            []
# 9                                  [(Australia, GPE)]            []
# 10  [(Australia, GPE), (Australia, GPE), (the Indo...            []

# %%
for index, row in df.iterrows():
    print(f"\nParagraph {index + 1}:")
    print(row['Paragraph Text'])

    # Display dependency parsing
    doc = nlp(row['Paragraph Text'])
    sentence_spans = list(doc.sents)
    displacy.render(sentence_spans, style='dep', jupyter=True, options={'compact': True})
    
    # Display named entities
    displacy.render(sentence_spans, style="ent", jupyter=True)
    
    # Print extracted entities and relationships
    print("Entities:", row['Entities'])
    print("Relationships:", row['Relationships'])
# Out:
# Paragraph 1:
# With the incoming federal government declaring it will make Australia a “renewable superpower”, China dominating clean energy supply chains, and the Russian war in Ukraine disrupting the global energy market, now is a pivotal moment for Australia to shape the future of clean energy within the Indo-Pacific.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4b35e758661b4c79a777771def139034-0" class="displacy" width="7250" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">incoming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">federal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">government</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">declaring</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">a “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">renewable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">superpower”,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">China</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">dominating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">supply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">chains,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Russian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">war</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Ukraine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">disrupting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">market,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">now</tspan>
#     <tspan class="displacy-t
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">With the incoming federal government declaring it will make
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a “renewable superpower”,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dominating clean energy supply chains, and the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  war in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  disrupting the global energy market, now is a pivotal moment for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to shape the future of clean energy within
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indo-Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# Entities: [('Australia', 'GPE'), ('China', 'GPE'), ('Ukraine', 'GPE'), ('Australia', 'GPE'), ('the Indo-Pacific', 'ORG')]
# Relationships: []
#
# Paragraph 2:
# A  new report by the Perth USAsia Centre, in collaboration with the Climate Council , recommends five practical actions for Australia to secure its economic and strategic clean energy advantages in the Indo-Pacific :
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="29a5534603514af88e6a0d2b255581ac-0" class="displacy" width="5150" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">report</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Perth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">USAsia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Centre,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">collaboration</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Climate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Council ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">recommends</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">five</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">practical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">actions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">secure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">economic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">strategic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">advantages</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">in</tspan>
#     <tspan class="displacy-tag" dy="2
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A  new report by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Perth USAsia Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , in collaboration with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Climate Council
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , recommends
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  practical actions for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to secure its economic and strategic clean energy advantages in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indo-Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  :</div></span>
# Entities: [('the Perth USAsia Centre', 'ORG'), ('the Climate Council', 'ORG'), ('Australia', 'GPE'), ('the Indo-Pacific', 'ORG')]
# Relationships: []
#
# Paragraph 3:
# Published ahead of a major international forum on energy supply chains – the  Sydney Energy Forum  (12-13 July) – the report,  Reenergising Indo-Pacific Relations: Australia’s Clean Energy Opportunity ,  explains that the Indo-Pacific sits at the heart of the global shift from fossil fuels to clean energy systems, the ramifications for Australia’s economic and strategic interests, and the leading role that our country could play.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="36470972408644b9a977a91c42dc3d5b-0" class="displacy" width="10700" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">ahead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">major</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">international</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">forum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">supply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">chains –</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Sydney</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Forum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450"> (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">12-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">13</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">July) –</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">report,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">Reenergising</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Indo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">Pacific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">Relations:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">Clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">Energy</tspan>
#     <tspan class="displacy-tag" dy
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Published ahead of a major international forum on energy supply chains – the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sydney Energy Forum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12-13 July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) – the report,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reenergising Indo-Pacific Relations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clean Energy Opportunity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ,  explains that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indo-Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sits at the heart of the global shift from fossil fuels to clean energy systems, the ramifications for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s economic and strategic interests, and the leading role that our country could play.</div></span>
# Entities: [('Sydney Energy Forum', 'ORG'), ('Reenergising Indo-Pacific Relations', 'ORG'), ('Australia', 'GPE'), ('Clean Energy Opportunity', 'ORG'), ('the Indo-Pacific', 'ORG'), ('Australia', 'GPE')]
# Relationships: []
#
# Paragraph 4:
# Global warming is a significant security threat for all countries, but those within the Indo-Pacific region are among  the most vulnerable. More affordable and available renewables can improve energy security and erode troublesome interdependencies in the region. However, significant obstacles must be overcome, including China’s dominance in the global energy sector.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="913a72f2091a49d59a416bb2b2d37328-0" class="displacy" width="3500" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">warming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">security</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">threat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">countries,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">those</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Indo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Pacific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">region</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">vulnerable.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-913a72f2091a49d59a416bb2b2d37328-0-0" stroke-width="2px" d="M62,452.0 62,427.0 185.0,427.0 185.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-913a72f2091a49d59a416bb2b2d37328-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-913a72f2091a49d59a416bb2b2d37328-0-1" stroke-width="2px" d="M212,452.0 212,427.0 335.0,427.0 335.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-913a72f2091a49d59a416bb2b2d37328-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,454.0 L208,446.0 216,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-913a72f2091a49d59a416bb2b2d37328-0-2" stroke-width="2px" d="M512,452.0 512,377.0 941.0,377.0 941.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-913a72f2091a49d59a416bb2b2d37328-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,454.0 L508,446.0 516,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-913a72f2091a49d59a416bb2b2d37328-0-3" stroke-width="2px" d="M662,452.0 662,402.0 938.0,402.0 938.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1
# /Users/loogyee/anaconda3/lib/python3.11/site-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Global warming is a significant security threat for all countries, but those within
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indo-Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  region are among  the most vulnerable. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">More affordable and available renewables can improve energy security and erode troublesome interdependencies in the region. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">However, significant obstacles must be overcome, including
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s dominance in the global energy sector.    </div></span>
# Entities: [('the Indo-Pacific', 'ORG'), ('China', 'GPE')]
# Relationships: []
#
# Paragraph 5:
# “The necessary transition from fossil fuel to clean energy systems is reordering Indo-Pacific relations. Australian government and industry should work to ensure emerging supply chains and interdependencies advance our national interest,”  said report author James Bowen.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cb861f6e91a54232a32f54219fe53325-0" class="displacy" width="2450" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">“</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">necessary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">transition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">fossil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">fuel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">reordering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Indo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Pacific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">relations.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb861f6e91a54232a32f54219fe53325-0-0" stroke-width="2px" d="M62,377.0 62,252.0 1850.0,252.0 1850.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb861f6e91a54232a32f54219fe53325-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb861f6e91a54232a32f54219fe53325-0-1" stroke-width="2px" d="M212,377.0 212,327.0 491.0,327.0 491.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb861f6e91a54232a32f54219fe53325-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# ...
#     <tspan class="displacy-word" fill="currentColor" x="1250">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">economic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">strategic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">interests</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">tied</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">leading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">rapid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">transition.”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-baf3deea3cf54e3787ece509aa757677-0-0" stroke-width="2px" d="M62,452.0 62,377.0 491.0,377.0 491.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-baf3deea3cf54e3787ece509aa757677-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-baf3deea3cf54e3787ece509aa757677-0-1" stroke-width="2px" d="M212,452.0 212,402.0 488.0,402.0 488.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-baf3deea3cf54e3787ece509aa757677-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">expl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,454.0 L208,446.0 216,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-baf3deea3cf54e3787ece509aa757677-0-2" stroke-width="2px" d="M362,452.0 362,427.0 485.0,427.0 485.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-baf3deea3cf54e3787ece509aa757677-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,454.0 L358,446.0 366,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-baf3deea3cf54e3787ece509aa757677-0-3" stroke-width="2px" d="M662,452.0 662,427.0 785.0,427.0 785.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" s
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“There can be no doubt that
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s economic and strategic interests are now tied to leading a rapid clean energy transition.”</div></span>
# Entities: [('Australia', 'GPE')]
# Relationships: []
#
# Paragraph 11:
# With both its natural resources and geopolitical alignments, Australia has the potential to become a clean energy superpower. The time is right for Australia to accelerate clean energy and associated climate action and secure its economic and strategic advantage in the Indo-Pacific’s clean energy future.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d77008d435634121a09f37d550e390db-0" class="displacy" width="2750" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">resources</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">geopolitical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">alignments,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">potential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">become</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">clean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">superpower.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-0" stroke-width="2px" d="M62,377.0 62,252.0 1400.0,252.0 1400.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d77008d435634121a09f37d550e390db-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-1" stroke-width="2px" d="M212,377.0 212,302.0 644.0,302.0 644.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d77008d435634121a09f37d550e390db-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">preconj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-2" stroke-width="2px" d="M362,377.0 362,327.0 641.0,327.0 641.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d77008d435634121a09f37d550e390db-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-3" stroke-width="2px" d="M512,377.0 512,352.0 638.0,352.0 638.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d77008d435634121a09f37d550e390db-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,379.0 L508,371.0 516,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-4" stroke-width="2px" d="M62,377.0 62,277.0 647.0,277.0 647.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d77008d435634121a09f37d550e390db-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M647.0,379.0 L651.0,371.0 643.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d77008d435634121a09f37d550e390db-0-5" stroke-width="2px" d="M662,377.0 662,352.0 788.0,352.0 788.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <t
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">With both its natural resources and geopolitical alignments,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has the potential to become a clean energy superpower. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The time is right for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to accelerate clean energy and associated climate action and secure its economic and strategic advantage in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indo-Pacific’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  clean energy future.</div></span>
# Entities: [('Australia', 'GPE'), ('Australia', 'GPE'), ('the Indo-Pacific’s', 'ORG')]
# Relationships: []

# %%
entity1_list = []
relationship_list = []
entity2_list = []
date_list = []
money_list = []

# %%
# Iterate through each paragraph
for index, row in df.iterrows():
    doc = nlp(row['Paragraph Text'])  # Process the paragraph with spaCy

    for sent in doc.sents:
        # Extract named entities (countries, organizations)
        entities = []
        money_in_sentence = []

        for ent in sent.ents:
            if 'Inititative' in ent.text.lower(): 
                ent = ent._replace(label_='POL')
                entities.append(ent)
            elif ent.label_ in ['GPE', 'ORG', 'POL', 'MONEY']:
                entities.append(ent)

            # Collect monetary amounts
            if ent.label_ == "MONEY":
                money_in_sentence.append(ent.text)
        
        # Look for verbs or specific relationship nouns in the sentence
        verbs = [token for token in sent if token.pos_ == "VERB"]
        keywords_in_sentence = [token.text for token in sent if token.lemma_ in relationship_keywords]
        
        # Extract dates
        dates = [ent.text for ent in sent.ents if ent.label_ == "DATE"]

        # If we find two entities and a relationship keyword, we assume a relationship
        if len(entities) >= 2 and keywords_in_sentence:
            entity1_list.append(entities[0].text)

            # Concatenate the relationship noun and verb (if available) into one string
            relationship_info = keywords_in_sentence[0]
            if verbs:
                relationship_info += " (verb: " + verbs[0].lemma_ + ")"

            relationship_list.append(relationship_info)  # Store concatenated info
            entity2_list.append(entities[1].text)
            date_list.append(dates[0] if dates else "n/a")
            money_list.append(money_in_sentence[0] if money_in_sentence else "n/a")

# %%
# DataFrame
relationships_df = pd.DataFrame({
    "Entity1": entity1_list,
    "Relationship": relationship_list,
    "Entity2": entity2_list,
    "Date": date_list,
    "Money": money_list
})

# %%
relationships_df
# Out:
#                              Entity1                     Relationship  \
# 0                          Australia           supply (verb: declare)
# 1            the Perth USAsia Centre  collaboration (verb: recommend)
# 2                Sydney Energy Forum           supply (verb: publish)
# 3                              China        transition (verb: create)
# 4                          Australia         supply (verb: diversify)
# 5                              Japan         exports (verb: continue)
# 6  Climate Council Senior Researcher           transition (verb: add)
# 7                Sydney Energy Forum      cooperation (verb: present)
#
#                                Entity2        Date Money
# 0                                China         n/a   n/a
# 1                  the Climate Council         n/a   n/a
# 2  Reenergising Indo-Pacific Relations  12-13 July   n/a
# 3                         Indo-Pacific         n/a   n/a
# 4                         Indo-Pacific         n/a   n/a
# 5                                Korea         n/a   n/a
# 6                     the Indo-Pacific         n/a   n/a
# 7                            Australia         n/a   n/a

# %%
# Export to csv
relationships_df.to_csv('01_relationships.csv', index=False)
