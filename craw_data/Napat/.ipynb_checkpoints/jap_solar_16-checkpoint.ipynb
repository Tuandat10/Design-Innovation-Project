# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/loogyee/anaconda3/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0.tar.gz (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/loogyee/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import spacy
from spacy import displacy

# %%
url = "https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/"
response = requests.get(url)

# %%
soup=BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-Us">
#  <head>
#   <meta charset="utf-8"/>
#   <base href="https://www.societegenerale.asia/"/>
#   <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1, width=device-width" name="viewport">
#    <meta content="summary" name="twitter:card"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <title>
#     A novel financing solution for Japan’s solar energy ambitions
#    </title>
#    <meta content="A novel financing solution for Japan’s solar energy ambitions" name="title"/>
#    <!-- HrefLang&Canonic -->
#    <link href="https://www.societegenerale.asia/jp/newsroom/%E3%82%B5%E3%82%AF%E3%82%BB%E3%82%B9%E3%82%B9%E3%83%88%E3%83%BC%E3%83%AA%E3%83%BC%E3%83%93%E3%83%A5%E3%83%BC%E3%83%9D%E3%82%A4%E3%83%B3%E3%83%88/translate-japan-success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" hreflang="jp" rel="alternate"/>
#    <link href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" hreflang="en" rel="alternate"/>
#    <link href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" rel="canonical"/>
#    <!-- SocialsMetas -->
#    <meta content="A novel financing solution for Japan’s solar energy ambitions" property="og:title"/>
#    <meta content="Société Générale" property="og:site_name"/>
#    <meta content="https://www.societegenerale.asia//uploads/tx_bisgnews/japan-solar-success-story-twitter.webp" property="og:image"/>
#    <meta content="summary_large_image" property="twitter:card"/>
#    <meta content="A novel financing solution for Japan’s solar energy ambitions" property="twitter:title"/>
#    <meta content="https://www.societegenerale.asia//uploads/tx_bisgnews/japan-solar-success-story-twitter.webp" property="twitter:image"/>
#    <meta content="An innovative financing package for Japan’s Azuma Kofuji solar facility could provide a template for renewables projects that meet the country’s uniqu" property="og:description"/>
#    <meta content="An innovative financing package for Japan’s Azuma Kofuji solar facility could provide a template for renewables projects that meet the country’s uniqu" property="twitter:description"/>
#    <meta content="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" property="og:url"/>
#    <meta content="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" property="twitter:url"/>
#    <meta content="An innovative financing package for Japan’s Azuma Kofuji solar facility could provide a template for renewables projects that meet the country’s uniqu" name="description"/>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <meta content="none" name="msapplication-config"/>
#    <link href="https://plus.google.com/108633454649832462728" rel="author"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon.png" rel="icon" type="image/png"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon-64.png" rel="icon" sizes="64x64" type="image/png"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon-96.png" rel="icon" sizes="96x96" type="image/png"/>
#    <link href="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon-196.png" rel="icon" sizes="196x196" type="image/png"/>
#    <meta content="/typo3conf/ext/bi_template/themes/default/res/favicon/favicon-144.png" name="msapplication-TileImage"/>
#    <meta content="#FFFFFF" name="msapplication-TileColor"/>
#    <script data-move="0">
#     var GBIS = JSON.parse('{"movingLineColor":"#e60028","tracking":{"pageType":false},"lang":"en","frontend_editing":false}');
#    </script>
#    <script data-move="0" type="application/ld+json">
#     {
#         "@context": "https://schema.org",
#         "@type": "NewsArticle",
#         "mainEntityOfPage": {
#             "@type": "WebPage",
#             "@id": "https://www.societegenerale.asia//en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/"
#         },
#         "headline": "A novel financing solution for Japan’s solar energy ambitions",
#
#         "datePublished": "2021-12-21T02:47:22+01:00",
#         "dateModified": "2024-03-04T16:37:29+01:00"
#
#     }
#    </script>
#    <link as="style" href="/typo3conf/ext/bi_template/themes/default/res/css/fonts.css" rel="preload stylesheet">
#     <style type="text/css">
#      span.video-miniSingle-desc {
# display: none;
# }
#
# div#c94300 {
#     display: none;
# }
#
# .design2015 .ttcContent.colored {
#     margin-left: 0px !important;
#     margin-right: 0px !important;
#     margin-top: 25px !important;
#     margin-bottom: 25px !important;
# }
#
#
#
# .dce-blockquotev2 .dce-blockquotev2-content {
#     font-size: 2.3rem;
# }
#     </style>
#     <style type="text/css">
#      .logo, .design2018.transparentHeader.transparentHeader--scrolled .logo{background-image:url("/fileadmin/user_upload/logos/160_Group-Futur-en.svg");} .logoWhite .logo{background-image:url("/fileadmin/user_upload/logos/160_Group-Futur-en-blanc.svg");}
#     </style>
#     <link href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" hreflang="en-Us" rel="alternate">
#      <link href="https://www.societegenerale.asia/jp/newsroom/%E3%82%B5%E3%82%AF%E3%82%BB%E3%82%B9%E3%82%B9%E3%83%88%E3%83%BC%E3%83%AA%E3%83%BC%E3%83%93%E3%83%A5%E3%83%BC%E3%83%9D%E3%82%A4%E3%83%B3%E3%83%88/translate-japan-success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" hreflang="ja-JP" rel="alternate">
#       <link href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" hreflang="x-default" rel="alternate">
#        <link href="/typo3conf/ext/bi_template/themes/default/res/css/styles.css?1728402401" media="all" rel="stylesheet"/>
#        <link href="/fileadmin/extra_css/5813.css?1713442996" media="all" rel="stylesheet"/>
#        <link href="/typo3conf/ext/ps_quantumsearch/Resources/Public/css/styles.css?1706549468" media="all" rel="stylesheet"/>
#        <link href="/typo3temp/themecolorcss/5813-inline241009.css" media="all" rel="stylesheet" type="text/css"/>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="fullwidth headerOneLine transparentHeader designPb2019 design2018 logoWhite page8641">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M7VV6PR" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- _headerOneLine.tmpl (pb2019) -->
#   <div id="menu_accessible">
#    <ul>
#     <li>
#      <a href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/#main" id="menu_accessible--main">
#       Go to content
#      </a>
#     </li>
#     <li>
#      <a href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/#menu-header" id="menu_accessible--menu">
#       Go to menu
#      </a>
#     </li>
#     <li>
#      <a href="https://www.societegenerale.asia/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/#form-search" id="menu_accessible--search">
#       Go to search
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="navmobile" id="navmobile">
#    <div class="navmobileSearch">
#    </div>
#    <div class="navmobileMenu">
#    </div>
#    <div class="navmobileLang" data-label="OTHER LANGUAGES">
#    </div>
#   </div>
#   <div class="mainContainer">
#    <header class="mainHeader mainHeader__oneline" role="banner">
#     <div class="topHeader">
#      <div class="container">
#       <div class="row">
#        <div class="col-sm-12">
#         <div class="mainLogo" itemscope="" itemtype="http://schema.org/Organization">
#          <a aria-label="The future is You, Societe Generale, go to home page" class="my-svg-container" href="/en/" itemprop="url">
#           <span class="logo">
#           </span>
#           <div class="mainLogoBaseline">
#           </div>
#          </a>
#         </div>
#         <nav aria-label="navigation principale" class="mainHeader--menu">
#          <ul class="mainMenuOneLine">
#           <li class="lvl1 theme" id="itemMenu29329">
#            <a href="/en/our-offering-1/">
#             <span>
#              Our offering
#             </span>
#            </a>
#           </li>
#           <li class="lvl1 theme" id="itemMenu29323">
#            <a href="/en/positive-impact-finance/">
#             <span>
#              Sustainable and Positive Impact Finance
#             </span>
#            </a>
#           </li>
#           <li class="lvl1 theme0" id="itemMenu6130">
#            <a aria-current="true" href="/en/newsroom/">
#             <span>
#              News and insights
#             </span>
#            </a>
#           </li>
#           <li class="lvl1 theme0" id="itemMenu5827">
#            <a href="/en/about-asia-pacific/committed-our-communities/">
#             <span>
#              About us
#             </span>
#            </a>
#            <ul class="mainMenuOneLine__sub">
#             <li class="lvl1 theme" id="itemMenu26429">
#              <a href="/en/about-asia-pacific/committed-our-communities/">
#               <span>
#                Supporting communities
#               </span>
#              </a>
#             </li>
#             <li class="lvl1 theme" id="itemMenu29092">
#              <a href="/en/about-asia-pacific/locations/">
#               <span>
#                Asia Pacific offices
#               </span>
#              </a>
#             </li>
#             <li class="lvl1 theme" id="itemMenu30178">
#              <a href="/en/contact/">
#               <span>
#                Contact us
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="lvl1 theme" id="itemMenu26407">
#            <a href="/en/careers/">
#             <span>
#              Careers
#             </span>
#            </a>
#            <ul class="mainMenuOneLine__sub">
#             <li class="lvl1 theme" id="itemMenu29560">
#              <a href="/en/careers/building-your-career-with/">
#               <span>
#                Building your career with us
#               </span>
#              </a>
#             </li>
#             <li class="lvl1 theme" id="itemMenu29563">
#              <a href="/en/careers/diversity-equity-inclusion-dei/">
#               <span>
#                Diversity, Equity &amp; Inclusion (DE&amp;I)
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </nav>
#         <div class="actionsMenu">
#          <div class="search actionsMenuItem" id="form-search" role="search">
#           <!-- case 3 : Quantum -->
#           <div class="sb-search sb-search--qwant" id="sb-search">
#            <form action="/en/search-results/" id="tx_indexedsearch" method="post" name="tx_indexedsearch" novalidate="novalidate">
#             <div>
#              <input name="__referrer[@extension]" type="hidden" value=""/>
#              <input name="__referrer[@controller]" type="hidden" value="Standard"/>
#              <input name="__referrer[@action]" type="hidden" value="index"/>
#              <input name="__referrer[arguments]" type="hidden" value="YTowOnt95083deeaa07fb94583ffa6f7aa23164d00fb3b8c"/>
#              <input name="__referrer[@request]" type="hidden" value='{"@extension":null,"@controller":"Standard","@action":"index"}ef8b5fc64d9fdda8a1d0550ee104a5524d540020'/>
#              <input name="__trustedProperties" type="hidden" value="[]d6efcaabff6d02336bfb6827f7240a6c0667e1eb"/>
#             </div>
#             <label for="searchForm">
#              Search
#             </label>
#             <input class="formCheck" name="tx_psquantumsearch_pi1[check]" tabindex="-1" type="text"/>
#             <input aria-label="Search with Quantum" class="sb-search-input" id="searchForm" name="tx_psquantumsearch_pi1[q]" placeholder="Search with Quantum" title="Search with Quantum" type="search"/>
#             <input class="sb-search-submit" type="submit" value="Search"/>
#             <button aria-controls="searchForm" class="sb-icon-search" role="link">
#              <span class="accessi">
#               Search
#              </span>
#              <span class="fa fa-search">
#              </span>
#             </button>
#            </form>
#           </div>
#          </div>
#          <div aria-haspopup="true" class="langList actionsMenuItem">
#           <div id="langueSwitcherForm">
#            <ul>
#             <li>
#              <a aria-current="page" aria-label="See website in English" class="anim__underline act" data-idlang="0" href="/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" lang="en" title="English">
#               EN
#              </a>
#             </li>
#             <li>
#              <a aria-label="See website in Japan" class="anim__underline" data-idlang="6" href="/jp/newsroom/%E3%82%B5%E3%82%AF%E3%82%BB%E3%82%B9%E3%82%B9%E3%83%88%E3%83%BC%E3%83%AA%E3%83%BC%E3%83%93%E3%83%A5%E3%83%BC%E3%83%9D%E3%82%A4%E3%83%B3%E3%83%88/translate-japan-success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/" lang="jp" title="Japan">
#               JP
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="menuButton">
#          <button aria-controls="navmobile" aria-expanded="false" class="bt-menu-trigger">
#           <strong class="accessi">
#            menu
#           </strong>
#           <span>
#           </span>
#          </button>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <!-- common2018.tmpl -->
#    <main id="main" role="main">
#     <div class="contentHeader">
#      <div class="headerImage" data-ratio="4.11" data-stellar-background-ratio="0.5">
#       <img alt="" height="467" sizes="100vw" src="/typo3temp/assets/_processed_/5/b/csm_japan-solar-success-story-hero_dfdd0e4e06.webp" srcset="/typo3temp/assets/_processed_/5/b/csm_japan-solar-success-story-hero_7e8fdbf7ad.webp 810w, /typo3temp/assets/_processed_/5/b/csm_japan-solar-success-story-hero_dfdd0e4e06.webp 1920w" width="1920"/>
#      </div>
#     </div>
#     <div class="zonetitre">
#      <div class="container maincontainer">
#       <div class="row zonetitre__rootline">
#        <div class="col-md-12">
#         <nav aria-label="Breadcrumb">
#          <ol class="rootline-menu breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#           <li class="first" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#            <a href="/en/" itemprop="item" itemscope="" itemtype="https://schema.org/WebPage">
#             <span itemprop="name">
#              Societe Generale Asia Pacific
#             </span>
#            </a>
#            <meta content="1" itemprop="position"/>
#           </li>
#           <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#            <a href="/en/newsroom/" itemprop="item" itemscope="" itemtype="https://schema.org/WebPage">
#             <span itemprop="name">
#              News and insights
#             </span>
#            </a>
#            <meta content="2" itemprop="position"/>
#           </li>
#           <li aria-current="page" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#            <span itemprop="name">
#             A novel financing solution for Japan’s solar energy ambitions
#            </span>
#            <meta content="3" itemprop="position"/>
#           </li>
#          </ol>
#         </nav>
#        </div>
#       </div>
#       <div class="row zonetitre__socials">
#        <div class="col-md-12">
#        </div>
#       </div>
#       <div class="row zonetitre__title">
#        <div class="col-md-12" role="main">
#         <h1 class="mainTitle">
#          A novel financing solution for Japan’s solar energy ambitions
#         </h1>
#        </div>
#       </div>
#      </div>
#      <!-- fin de maincontainer -->
#     </div>
#     <!-- fin de zontitre -->
#     <div class="container content">
#      <div class="row">
#       <div class="col-md-9 mainCol mainCol--noheader" role="main">
#        <div class="containerContent">
#         <div class="ttcContent default" data-anchor="#c37341">
#          <div class="frame frame-default frame-type-list frame-layout-0" id="c37341">
#           <!--
#
# 		BEGIN: Content of extension "bi_sg_news", plugin "tx_bisgnews_pi1"
#
# 	-->
#           <div class="tx-bisgnews-pi1">
#            <div class="sgnews_single">
#             <div class="row">
#              <div class="col-md-3 pull-right sgnews_single__socials">
#              </div>
#              <div class="col-md-9 sgnews_single__datefile">
#               <div class="sgnews_single_date">
#                05/01/2022
#               </div>
#              </div>
#             </div>
#             <div class="sgnewsTitle">
#              <div class="intro">
#               <p>
#                An innovative financing package for Japan’s Azuma Kofuji solar facility could provide a template for renewables projects that meet the country’s unique requirements.
#               </p>
#              </div>
#             </div>
#             <div class="sgnews_single_content">
#              <p class="bodytext">
#               Canadian Solar has sealed a JPY 24.5 billion (EUR 185 million) financing for the 100 megawatt Azuma Kofuji Solar power project, which counts among the largest solar projects in the country, and is Canadian Solar’s flagship project in Japan. The deal harnesses an inventive financing approach to advance Japan’s clean energy ambitions and help revitalising the Fukushima prefecture, reinvigorating the local economy in a region devastated by the 2011 Tohoku earthquake.
#              </p>
#              <p class="bodytext">
#               Societe Generale recently acted as Mandated Lead Arranger (MLA) in the financing of Canadian Solar’s Azuma Kofuji Solar photovoltaic project.
#              </p>
#              <p class="bodytext">
#               In Japan’s updated energy plan announced in April 2021, its government committed to a 2030 target of cutting greenhouse gas (GHG) emissions by at least 46% from 2013 levels. Renewables will make up between 36% and 38% of overall generation by then.
#               <sup>
#                1
#               </sup>
#               Of this target, of solar’s share is set to be 15% while wind (predominantly offshore wind) will account for 6%.
#              </p>
#              <p class="bodytext">
#               Japan’s solar ambitions, however, are a challenge in a country where land use is at a premium and geography restricts available options for solar installations. In addition, solar sites are relatively complex, often requiring capital-intensive civil works. Japan’s feed-in tariff (FiT), introduced in 2012, has helped to meet these challenges by guaranteeing a fixed purchase price for renewable power. It boosted non-hydro renewables’ growth rate from 9% CAGR between 2009-12 to 29% between 2012 and 2015.
#               <sup>
#                2
#               </sup>
#               A new Feed-in-Premium (FiP) is due to be introduced in 2022 which will further incentivise renewables generators to sell their power to the grid.
#              </p>
#              <p class="bodytext">
#               <strong>
#                Putting finance in place
#               </strong>
#              </p>
#              <p class="bodytext">
#               While the FiT and FiP mechanisms provide a strong ‘pull’ factor for installing solar generation, suitable financial solutions are needed to support construction and commissioning.
#              </p>
#              <p class="bodytext">
#               Unusually for a long-term power asset, this deal is structured as a hard mini perm, a short-term facility with a maturity one year after construction is complete. This solution allows for the debt to be taken out by capital markets funding once the plant is up and running: after the solar farm is completed in 2023, it is expected to be acquired by the Canadian Solar Infrastructure Fund, which will subsequently receive the revenues from its operations at a predictable rate guaranteed by the FiT.
#              </p>
#              <p class="bodytext">
#               “This funding model has real potential to help accelerate Japan’s energy transition, providing additional financing options to address the country’s specific challenges and enabling the project sponsors to benefit from a wider range of funding schemes. It’s a great example of how international and local institutions, as well as commercial debt and institutional funding, can make a difference through innovative financing,” said Cedric Chatel, Managing Director - Energy Finance &amp; Advisory, Societe Generale.
#              </p>
#              <p class="bodytext">
#               Canadian Solar is one of the biggest solar power developers in Japan, having successfully bid for projects at every auction since the FiT programme was launched in 2017. It is also the sponsor of the Tokyo-listed Canadian Solar Infrastructure Fund, which offers access to efficient capital markets funding for long-term infrastructure assets.
#              </p>
#              <p class="bodytext">
#               “Canadian Solar is committed to working with all stakeholders in furthering Japan’s renewable energy journey. Obtaining financing that suits the country’s specific circumstances is key to enabling the construction phase of solar projects by tapping into the government’s strategic incentive programmes,” said Dr. Shawn Qu, Chairman and Chief Executive Officer of Canadian Solar Inc.
#              </p>
#              <p class="bodytext">
#               The reduced tenor and capital markets-friendly structure of the Azuma Kofuji financing is unusual in Japan but is a regular feature in the US, applying Canadian Solar’s and Societe Generale’s global experience to the local market.
#              </p>
#              <p class="bodytext">
#               This is Societe Generale’s first financing for a domestic Japanese solar project, having entered the Japanese renewables market in 2020 with financing for the Marubeni Corporation’s 140 MW Akita offshore wind project.
#               <sup>
#                3
#               </sup>
#               The Azuma Kofuji facility will be one of the largest solar projects in the country to date, critical to the meeting the country’s energy transition commitments, as well as playing a substantial role in the reconstruction of the Fukushima prefecture.
#              </p>
#              <p class="bodytext">
#              </p>
#              <p class="bodytext">
#               <span class="bodytext text--minor">
#                1
#                <a href="https://asia.nikkei.com/Business/Energy/Japan-aims-for-nearly-40-renewable-energy-by-fiscal-2030" rel="noreferrer" target="_blank">
#                 https://asia.nikkei.com/Business/Energy/Japan-aims-for-nearly-40-renewable-energy-by-fiscal-2030
#                </a>
#                <br/>
#                2
#                <a href="https://shulman-advisory.com/2020/06/19/fit-fip-and-the-future-of-renewables-in-japan/" rel="noreferrer" target="_blank">
#                 https://shulman-advisory.com/2020/06/19/fit-fip-and-the-future-of-renewables-in-japan/
#                </a>
#                <br/>
#                3
#                <a href="https://wholesale.banking.societegenerale.com/en/insights/clients-successes/clients-successes-details/news/how-marubeni-using-sun-and-wind-power-asiaes-energy-transition/" target="_blank">
#                 https://wholesale.banking.societegenerale.com/en/insights/clients-successes/clients-successes-details/news/how-marubeni-using-sun-and-wind-power-asiaes-energy-transition/
#                </a>
#               </span>
#              </p>
#             </div>
#             <div class="sgnews_single_video">
#             </div>
#             <div class="row sgnews_single__bottom">
#              <div class="col-md-3 pull-right">
#              </div>
#              <div class="col-md-9">
#              </div>
#             </div>
#            </div>
#           </div>
#           <!-- END: Content of extension "bi_sg_news", plugin "tx_bisgnews_pi1" -->
#          </div>
#         </div>
#        </div>
#        <!--
#
# 		BEGIN: Content of extension "bi_sg_bio", plugin "tx_bisgbio_pi1"
#
# 	-->
#        <div class="tx-bisgbio-pi1">
#        </div>
#        <!-- END: Content of extension "bi_sg_bio", plugin "tx_bisgbio_pi1" -->
#       </div>
#       <div class="col-md-3 sideCol">
#        <aside class="aside">
#        </aside>
#       </div>
#      </div>
#     </div>
#     <!-- partials/contentFooter.tmpl -->
#     <div class="container contentFooter">
#      <div class="row">
#       <div class="col-md-12">
#        <!--
#
# 		BEGIN: Content of extension "bi_sgpriv_tags", plugin "tx_bisgprivtags_pi1"
#
# 	-->
#        <div class="tx-bisgprivtags-pi1">
#         <div class="tx-bisgprivtags-pi1-TagList">
#          <h2 class="tagTitle">
#           Find out more:
#          </h2>
#          <div class="tagList">
#           <a class="label label-default" href="/en/tags/tag/japan/" rel="tag">
#            Japan
#           </a>
#           <a class="label label-default" href="/en/tags/tag/clients-successes/" rel="tag">
#            Clients' successes
#           </a>
#           <a class="label label-default" href="/en/tags/tag/sustainable-positive-impact-finance/" rel="tag">
#            Sustainable &amp; Positive Impact Finance
#           </a>
#           <a class="label label-default" href="/en/tags/tag/energy/" rel="tag">
#            Energy
#           </a>
#           <a class="label label-default" href="/en/tags/tag/poweringenergytransition/" rel="tag">
#            Powering Energy Transition
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- END: Content of extension "bi_sgpriv_tags", plugin "tx_bisgprivtags_pi1" -->
#       </div>
#      </div>
#      <div class="row">
#       <div class="col-md-12">
#        <!--
#
# 		BEGIN: Content of extension "bi_links_block", plugin "tx_bilinksblock_pi1"
#
# 	-->
#        <div class="tx-bilinksblock-pi1">
#         <!--
#
# 		BEGIN: Content of extension "bi_sg_summary", plugin "tx_bisgsummary_pi2"
#
# 	-->
#         <div class="tx-bisgsummary-pi2">
#          <div class="wallCard nbPerLine4" id="wallCard0">
#           <div class="summaryWallAjax">
#            <div class="resultsContainer">
#             <div class="wallCardItems">
#              <div class="wallCardRow wallCardRow_card">
#               <div aria-label="The new narrative of ESG investing" class="card cardType2" data-dimratio="1-1" data-dimratiomobile="1-1" data-href="/en/newsroom/press-releases/press-releases-details/news/the-new-narrative-of-esg-investing/" data-ref="2-25517" data-type="2" id="card2-25517" tabindex="0">
#                <div class="cardContent haveDate haveVisuel haveDesc">
#                 <div class="cardContentSub">
#                  <div class="date">
#                   <div class="dateDay">
#                    25
#                   </div>
#                   <div class="dateCouple">
#                    <div class="dateMonth">
#                     Sep
#                    </div>
#                    <div class="dateYear">
#                     2024
#                    </div>
#                   </div>
#                  </div>
#                  <div class="visuel">
#                   <img alt="" height="275" src="/typo3temp/assets/_processed_/7/e/csm_The_New_Narrative_of_ESG_Investing_550_1727228923_ecf7aa874e.webp" srcset="/typo3temp/assets/_processed_/7/e/csm_The_New_Narrative_of_ESG_Investing_550_1727228923_66423e8a3d.webp 1x, /typo3temp/assets/_processed_/7/e/csm_The_New_Narrative_of_ESG_Investing_550_1727228923_ecf7aa874e.webp 2x" width="550"/>
#                  </div>
#                  <div class="mask">
#                  </div>
#                  <div class="cardContentTxt">
#                   <span class="title">
#                    The new narrative of ESG investing
#                   </span>
#                   <br>
#                    <span class="desc">
#                     Since the boom in 2020, global Exchange Traded Fund (ETF) investments that embed ESG criteria have gone through some...
#                    </span>
#                   </br>
#                  </div>
#                  <div class="taxoWrap">
#                   <div class="taxoLabel">
#                    Expert views
#                   </div>
#                   <div class="desc">
#                    Since the boom in 2020, global Exchange Traded Fund (ETF) investments that embed ESG criteria have gone through some bumpy years – particularly in 2023. Macroeconomic events such as the energy price shock in Europe, interest rate hikes, and even political elections, have had a profound impact on ESG investing.
#                   </div>
#                   <a class="googleLink" href="/en/newsroom/press-releases/press-releases-details/news/the-new-narrative-of-esg-investing/" tabindex="-1">
#                    The new narrative of ESG investing
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="wallCardRow wallCardRow_card">
#               <div aria-label="Supporting Australian real estate sustainability goals" class="card cardType2" data-dimratio="1-1" data-dimratiomobile="1-1" data-href="/en/newsroom/success-stories/success-stories-details/news/supporting-australian-real-estate-sustainability-goals/" data-ref="2-25426" data-type="2" id="card2-25426" tabindex="0">
#                <div class="cardContent haveDate haveVisuel haveDesc">
#                 <div class="cardContentSub">
#                  <div class="date">
#                   <div class="dateDay">
#                    16
#                   </div>
#                   <div class="dateCouple">
#                    <div class="dateMonth">
#                     Sep
#                    </div>
#                    <div class="dateYear">
#                     2024
#                    </div>
#                   </div>
#                  </div>
#                  <div class="visuel">
#                   <img alt="" height="275" src="/typo3temp/assets/_processed_/d/5/csm_Cromwell_550_1726471687_329dfae512.webp" srcset="/typo3temp/assets/_processed_/d/5/csm_Cromwell_550_1726471687_92e089b26f.webp 1x, /typo3temp/assets/_processed_/d/5/csm_Cromwell_550_1726471687_329dfae512.webp 2x" width="550"/>
#                  </div>
#                  <div class="mask">
#                  </div>
#                  <div class="cardContentTxt">
#                   <span class="title">
#                    Supporting Australian real estate sustainability goals
#                   </span>
#                   <br>
#                    <span class="desc">
#                     How an innovative green loan in Australia is helping a major real estate investor and fund manager meet ambitious...
#                    </span>
#                   </br>
#                  </div>
#                  <div class="taxoWrap">
#                   <div class="taxoLabel">
#                    Clients' successes
#                   </div>
#                   <div class="desc">
#                    How an innovative green loan in Australia is helping a major real estate investor and fund manager meet ambitious sustainability targets.
#                   </div>
#                   <a class="googleLink" href="/en/newsroom/success-stories/success-stories-details/news/supporting-australian-real-estate-sustainability-goals/" tabindex="-1">
#                    Supporting Australian real estate sustainability goals
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="wallCardRow wallCardRow_card">
#               <div aria-label="Something new under the sun: How a landmark New Zealand solar securitisation shows the way to unlock Asia’s potential" class="card cardType2" data-dimratio="1-1" data-dimratiomobile="1-1" data-href="/en/newsroom/press-releases/press-releases-details/news/something-new-under-the-sun-how-a-landmark-new-zealand-solar-securitisation-shows-the-way-to-unlock-asias-potential/" data-ref="2-25336" data-type="2" id="card2-25336" tabindex="0">
#                <div class="cardContent haveDate haveVisuel haveDesc">
#                 <div class="cardContentSub">
#                  <div class="date">
#                   <div class="dateDay">
#                    30
#                   </div>
#                   <div class="dateCouple">
#                    <div class="dateMonth">
#                     Aug
#                    </div>
#                    <div class="dateYear">
#                     2024
#                    </div>
#                   </div>
#                  </div>
#                  <div class="visuel">
#                   <img alt="" height="275" src="/typo3temp/assets/_processed_/7/f/csm_solar_securitisation_550_1724982706_b16664a94f.webp" srcset="/typo3temp/assets/_processed_/7/f/csm_solar_securitisation_550_1724982706_cdb5684416.webp 1x, /typo3temp/assets/_processed_/7/f/csm_solar_securitisation_550_1724982706_b16664a94f.webp 2x" width="550"/>
#                  </div>
#                  <div class="mask">
#                  </div>
#                  <div class="cardContentTxt">
#                   <span class="title">
#                    Something new under the sun: How a landmark New Zealand solar securitisation shows the way to unlock Asia’s potential
#                   </span>
#                   <br/>
#                   <span class="desc">
#                    Capital markets solutions offer another way to provide the scale of financing needed for the energy transition in Asia...
#                   </span>
#                  </div>
#                  <div class="taxoWrap">
#                   <div class="taxoLabel">
#                    Expert views
#                   </div>
#                   <div class="desc">
#                    Capital markets solutions offer another way to provide the scale of financing needed for the energy transition in Asia Pacific. A new Societe Generale-backed solar securitisation in New Zealand could serve as a template for other jurisdictions.
#                   </div>
#                   <a class="googleLink" href="/en/newsroom/press-releases/press-releases-details/news/something-new-under-the-sun-how-a-landmark-new-zealand-solar-securitisation-shows-the-way-to-unlock-asias-potential/" tabindex="-1">
#                    Something new under the sun: How a landmark New Zealand solar securitisation shows the way to unlock Asia’s potential
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="wallCardRow wallCardRow_card">
#               <div aria-label="Asia’s energy transition: a changing outlook for commodities" class="card cardType2" data-dimratio="1-1" data-dimratiomobile="1-1" data-href="/en/newsroom/press-releases/press-releases-details/news/asias-energy-transition-a-changing-outlook-for-commodities/" data-ref="2-25063" data-type="2" id="card2-25063" tabindex="0">
#                <div class="cardContent haveDate haveVisuel haveDesc">
#                 <div class="cardContentSub">
#                  <div class="date">
#                   <div class="dateDay">
#                    15
#                   </div>
#                   <div class="dateCouple">
#                    <div class="dateMonth">
#                     Jul
#                    </div>
#                    <div class="dateYear">
#                     2024
#                    </div>
#                   </div>
#                  </div>
#                  <div class="visuel">
#                   <img alt="" height="275" src="/typo3temp/assets/_processed_/c/8/csm_Greenflation_550_1721030812_c234227b38.webp" srcset="/typo3temp/assets/_processed_/c/8/csm_Greenflation_550_1721030812_cbbf55a62b.webp 1x, /typo3temp/assets/_processed_/c/8/csm_Greenflation_550_1721030812_c234227b38.webp 2x" width="550"/>
#                  </div>
#                  <div class="mask">
#                  </div>
#                  <div class="cardContentTxt">
#                   <span class="title">
#                    Asia’s energy transition: a changing outlook for commodities
#                   </span>
#                   <br/>
#                   <span class="desc">
#                    In the energy transition, the commodities sector is where the pedal really hits the metal. Rising prices are just a...
#                   </span>
#                  </div>
#                  <div class="taxoWrap">
#                   <div class="taxoLabel">
#                    Expert views
#                   </div>
#                   <div class="desc">
#                    In the energy transition, the commodities sector is where the pedal really hits the metal. Rising prices are just a taste of things to come.
#                   </div>
#                   <a class="googleLink" href="/en/newsroom/press-releases/press-releases-details/news/asias-energy-transition-a-changing-outlook-for-commodities/" tabindex="-1">
#                    Asia’s energy transition: a changing outlook for commodities
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="wallCardRow wallCardRow_card">
#               <div aria-label="Turning vision into reality for a sustainable EV solutions pioneer  " class="card cardType2" data-dimratio="1-1" data-dimratiomobile="1-1" data-href="/en/newsroom/press-releases/press-releases-details/news/turning-vision-into-reality-for-a-sustainable-ev-solutions-pioneer/" data-ref="2-24703" data-type="2" id="card2-24703" tabindex="0">
#                <div class="cardContent haveDate haveVisuel haveDesc">
#                 <div class="cardContentSub">
#                  <div class="date">
#                   <div class="dateDay">
#                    03
#                   </div>
#                   <div class="dateCouple">
#                    <div class="dateMonth">
#                     Jun
#                    </div>
#                    <div class="dateYear">
#                     2024
#                    </div>
#                   </div>
#                  </div>
#                  <div class="visuel">
#                   <img alt="" height="275" src="/typo3temp/assets/_processed_/5/e/csm_EV_solutions_pioneer_550_1717396414_73eb8bc2f4.webp" srcset="/typo3temp/assets/_processed_/5/e/csm_EV_solutions_pioneer_550_1717396414_3f8d8f8d79.webp 1x, /typo3temp/assets/_processed_/5/e/csm_EV_solutions_pioneer_550_1717396414_73eb8bc2f4.webp 2x" width="550"/>
#                  </div>
#                  <div class="mask">
#                  </div>
#                  <div class="cardContentTxt">
#                   <span class="title">
#                    Turning vision into reality for a sustainable EV solutions pioneer
#                   </span>
#                   <br/>
#                   <span class="desc">
#                    From gigafactories to green ammonia, bankable new business models are key to accelerating the energy transition.
#                   </span>
#                  </div>
#                  <div class="taxoWrap">
#                   <div class="taxoLabel">
#                    Expert views
#                   </div>
#                   <div class="desc">
#                    From gigafactories to green ammonia, bankable new business models are key to accelerating the energy transition.
#                   </div>
#                   <a class="googleLink" href="/en/newsroom/press-releases/press-releases-details/news/turning-vision-into-reality-for-a-sustainable-ev-solutions-pioneer/" tabindex="-1">
#                    Turning vision into reality for a sustainable EV solutions pioneer
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div aria-live="polite" class="wallCard__status sr-only" role="status">
#           </div>
#          </div>
#         </div>
#         <!-- END: Content of extension "bi_sg_summary", plugin "tx_bisgsummary_pi2" -->
#        </div>
#        <!-- END: Content of extension "bi_links_block", plugin "tx_bilinksblock_pi1" -->
#       </div>
#      </div>
#     </div>
#    </main>
#    <footer role="contentinfo">
#     <div class="topFooter">
#      <div class="container">
#       <div class="ttcContent default" data-anchor="#c44098">
#        <div class="frame frame-default frame-type-container-4cols-25-25-25-25 frame-layout-0" id="c44098">
#         <div class="row">
#          <div class="col-sm-3 gridCol thinCol">
#           <div class="ttcContent default" data-anchor="#c44094">
#            <div class="frame frame-default frame-type-text frame-layout-0" id="c44094">
#             <h2 class="">
#              Direct access
#             </h2>
#             <ul>
#              <li>
#               <a href="https://www.societegenerale.com/en/" rel="noreferrer noopener" target="_blank">
#                Societe Generale Group
#               </a>
#              </li>
#              <li>
#               <a href="https://wholesale.banking.societegenerale.com/en/" target="_blank">
#                Wholesale Banking
#               </a>
#              </li>
#              <li>
#               <a href="https://www.securities-services.societegenerale.com/en/" rel="noreferrer noopener" target="_blank">
#                Securities Services
#               </a>
#              </li>
#              <li>
#               <a href="https://www.societegenerale.asia/en/our-offering/global-transaction-banking/" target="_blank">
#                Global Transaction Banking
#               </a>
#              </li>
#              <li>
#               <a href="https://www.ayvens.com/fr-fr/" rel="noreferrer" target="_blank">
#                Ayvens
#               </a>
#              </li>
#              <li>
#               <a href="https://www.equipmentfinance.societegenerale.com/" rel="noreferrer noopener" target="_blank" title="Equipment Finance website">
#                Equipment Finance
#               </a>
#              </li>
#              <li>
#               <a href="https://insight-public.sgmarkets.com/" rel="noreferrer noopener" target="_blank">
#                SG Markets Research &amp; Insight
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-3 gridCol thinCol">
#          </div>
#          <div class="col-sm-3 gridCol thinCol">
#          </div>
#          <div class="col-sm-3 gridCol thinCol">
#           <div class="ttcContent default" data-anchor="#c44097">
#            <div class="frame frame-default frame-type-text frame-layout-0" id="c44097">
#             <h2 class="">
#              Stay connected
#             </h2>
#             <p class="bodytext">
#              &gt;
#              <a href="https://www.linkedin.com/company/societegenerale-corporate-and-investment-banking" rel="noreferrer" target="_blank">
#               LinkedIn
#              </a>
#              <br/>
#              &gt;
#              <a href="https://twitter.com/SocieteGenerale" rel="noreferrer" target="_blank">
#               X
#              </a>
#              <br/>
#              &gt;
#              <a href="https://www.youtube.com/user/societegenerale" rel="noreferrer" target="_blank">
#               Youtube
#              </a>
#             </p>
#            </div>
#           </div>
#           <div class="ttcContent default" data-anchor="#c106131">
#            <div class="frame frame-default frame-type-html frame-layout-0 frame-space-before-extra-large" id="c106131">
#             <h2>
#              <a aria-haspopup="true" href="javascript:Didomi.preferences.show()" role="button">
#               Consent configurator
#              </a>
#             </h2>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="ttcContent default" data-anchor="#c106130">
#        <div class="frame frame-default frame-type-html frame-layout-0" id="c106130">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="subFooter">
#      <div class="container">
#       <div class="row">
#        <div class="col-sm-8 col-xs-6">
#         <div class="footerLogo">
#          <img alt="Logo Société Générale" onerror="this.src='/typo3conf/ext/bi_template/themes/default/res/img/logoFooter.svg';this.onerror=null;" src="/typo3conf/ext/bi_template/themes/default/res/img/logoFooter.svg"/>
#         </div>
#        </div>
#        <div class="col-sm-4 col-xs-6">
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-md-12">
#         <ul class="footerMenu">
#          <li class="first">
#           <a href="/en/contact/">
#            Contact us
#           </a>
#          </li>
#          <li>
#           <a href="/en/sitemap/">
#            Sitemap
#           </a>
#          </li>
#          <li>
#           <a href="/en/general-conditions/">
#            General conditions
#           </a>
#          </li>
#          <li>
#           <a href="/en/disclosure-information/">
#            Disclosure Information
#           </a>
#          </li>
#          <li>
#           <a href="/en/cookies-policy/">
#            Cookies policy
#           </a>
#          </li>
#          <li>
#           <a href="/en/data-policy/">
#            Data policy
#           </a>
#          </li>
#          <li>
#           <a href="/en/accessibility-not-compliant/">
#            Accessibility: not compliant
#           </a>
#          </li>
#          <li>
#           <a href="/en/information-security/">
#            Information security
#           </a>
#          </li>
#          <li class="last">
#           <a href="https://report.whistleb.com/en/portal/socgengroup" target="_blank">
#            Report Improper Conduct
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <button aria-label="Back to top" class="topLink" tabindex="0">
#      <i aria-hidden="true" class="fa fa-arrow-circle-up">
#      </i>
#     </button>
#    </footer>
#   </div>
#   <script src="/typo3conf/ext/bi_template/themes/default/res/js/vendors.min.js?1706549468">
#   </script>
#   <script src="/typo3conf/ext/bi_template/themes/default/res/js/gbis.min.js?1706549468">
#   </script>
#   <script src="/typo3conf/ext/bi_template/themes/default/res/js/commons.js?1728402408">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-M7VV6PR');
#   </script>
#   <script type="text/javascript">
#    $('document').ready(function(){
#    $('#langueSwitcherForm a').on('click', function(){
#        gaTrackEvent({
#         hitType: 'event',
#         eventCategory: 'Langage',
#         eventAction: 'click',
#         eventLabel: $(this).attr('lang')
#        });
#        $.cookie("lang", $(this).data('idlang'), { expires: 365, path: "/" });
#    })
# });
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function(){
# 	$('#wallCard0').cardWallFilters({
# 		currentPageLink: '/en/newsroom/success-stories/success-stories-details/news/novel-financing-solution-for-japanes-solar-energy-ambitions/',
# 		nbTotalResults: 5,
# 		idContent: 0,
# 		forceConf: 'a:3:{s:8:"mainConf";a:8:{s:13:"displayModule";s:12:"CONNEXE_WALL";s:8:"itemType";s:11:"2,3,4,7,8,9";s:4:"tags";s:24:"1341,2118,3584,3620,1439";s:15:"manualSelection";N;s:28:"hideAllReadyDisplayedResults";i:1;s:22:"hideTagPageFromResults";i:1;s:26:"hideCurrentPageFromResults";i:1;s:6:"maxAge";s:3:"700";}s:11:"displayConf";a:11:{s:10:"blockRatio";s:3:"1-1";s:9:"nbPerLine";i:4;s:13:"searchFilters";i:4;s:7:"sorting";i:3;s:5:"limit";i:5;s:9:"nbPerPage";i:5;s:10:"thumbWidth";s:4:"600c";s:11:"thumbHeight";s:4:"300c";s:9:"cardRatio";s:3:"1/1";s:14:"relatedContent";s:4:"true";s:23:"hideSingleViewInSummary";s:4:"true";}s:12:"siteOptions.";a:152:{s:13:"resCommonsDir";s:44:"/typo3conf/ext/bi_template/themes/default/res";s:6:"isSGSS";s:1:"0";s:10:"isMomentum";s:1:"0";s:6:"isSgbt";s:1:"1";s:7:"piwikId";s:1:"0";s:5:"GTMid";s:11:"GTM-M7VV6PR";s:8:"hrefLang";s:0:"";s:11:"hrefCountry";s:0:"";s:10:"listLangId";s:3:"0,6";s:11:"homepagePid";s:4:"5813";s:10:"rootPageId";s:4:"5813";s:11:"diffusionId";s:2:"69";s:9:"rssPageId";s:4:"5821";s:13:"contactPageId";s:4:"6138";s:11:"pickListPid";s:1:"0";s:17:"pickListFooterPid";s:1:"0";s:17:"pickListHeaderPid";s:1:"0";s:15:"clientAccessPid";s:1:"0";s:18:"clientAccessIframe";s:1:"0";s:8:"toolsPid";s:4:"5814";s:11:"SuperHeader";s:1:"0";s:14:"addLangueClass";s:1:"0";s:21:"redirectLangueDefault";s:1:"0";s:11:"langDefault";s:1:"0";s:16:"autoLangRedirect";s:1:"0";s:12:"rememberLang";s:1:"0";s:12:"check404Lang";s:1:"1";s:32:"strategieInvestissementSummaryId";s:4:"7329";s:25:"strategieInvestissementId";s:4:"4726";s:17:"momentumSummaryId";s:4:"9111";s:10:"momentumId";s:4:"9112";s:17:"lalettreSummaryId";s:4:"9883";s:10:"lalettreId";s:4:"9884";s:10:"tagPagePid";s:4:"5825";s:16:"newsSinglePageId";s:4:"6132";s:21:"newsActusSinglePageId";s:4:"6132";s:21:"newsSinglePageIdType9";s:4:"2140";s:22:"newsSinglePageIdType10";s:4:"2139";s:22:"newsSinglePageIdType11";s:4:"2141";s:22:"newsSinglePageIdType36";s:4:"4228";s:22:"newsSinglePageIdType42";s:4:"4360";s:22:"newsSinglePageIdType43";s:4:"4363";s:22:"newsSinglePageIdType44";s:4:"6132";s:22:"newsSinglePageIdType65";s:4:"6435";s:22:"newsSinglePageIdType71";s:4:"6971";s:21:"newsSinglePageIdType3";s:4:"8043";s:22:"newsSinglePageIdType77";s:4:"6132";s:22:"newsSinglePageIdType78";s:4:"6132";s:22:"newsSinglePageIdType75";s:4:"7672";s:22:"newsSinglePageIdType84";s:4:"8003";s:22:"newsSinglePageIdType76";s:4:"6132";s:22:"newsSinglePageIdType73";s:4:"6132";s:22:"newsSinglePageIdType88";s:4:"8010";s:22:"newsSinglePageIdType89";s:4:"8014";s:22:"newsSinglePageIdType85";s:0:"";s:22:"newsSinglePageIdType86";s:0:"";s:22:"newsSinglePageIdType87";s:0:"";s:22:"newsSinglePageIdType90";s:0:"";s:22:"newsSinglePageIdType91";s:4:"8074";s:22:"newsSinglePageIdType94";s:4:"6132";s:22:"newsSinglePageIdType97";s:4:"9264";s:22:"newsSinglePageIdType98";s:4:"9265";s:22:"newsSinglePageIdType99";s:4:"9266";s:23:"newsSinglePageIdType100";s:4:"9267";s:23:"newsSinglePageIdType105";s:0:"";s:23:"newsSinglePageIdType106";s:0:"";s:23:"newsSinglePageIdType107";s:0:"";s:23:"newsSinglePageIdType108";s:0:"";s:23:"newsSinglePageIdType109";s:0:"";s:23:"newsSinglePageIdType115";s:5:"10180";s:23:"newsSinglePageIdType152";s:0:"";s:23:"newsSinglePageIdType153";s:0:"";s:23:"newsSinglePageIdType154";s:0:"";s:23:"newsSinglePageIdType155";s:0:"";s:23:"newsSinglePageIdType156";s:4:"6750";s:23:"newsSinglePageIdType157";s:0:"";s:23:"newsSinglePageIdType158";s:4:"8641";s:23:"newsSinglePageIdType159";s:0:"";s:23:"newsSinglePageIdType160";s:0:"";s:23:"newsSinglePageIdType161";s:0:"";s:23:"newsSinglePageIdType162";s:0:"";s:23:"newsSinglePageIdType163";s:0:"";s:23:"newsSinglePageIdType164";s:4:"6132";s:23:"newsSinglePageIdType165";s:4:"8641";s:23:"newsSinglePageIdType166";s:0:"";s:23:"newsSinglePageIdType167";s:0:"";s:23:"newsSinglePageIdType168";s:0:"";s:23:"newsSinglePageIdType169";s:0:"";s:23:"newsSinglePageIdType170";s:0:"";s:23:"newsSinglePageIdType174";s:0:"";s:23:"newsSinglePageIdType199";s:5:"22887";s:23:"newsSinglePage ...
# 	});
# });
#   </script>
#   <script type="text/javascript">
#    window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
# else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
# var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
# if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#   var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})("415bfedc-6dd5-40a1-accb-c5d40e32a005")})();
#   </script>
#   <script>
#   </script>
#   <script defer="defer" src="/typo3conf/ext/powermail/Resources/Public/JavaScript/Powermail/Form.min.js?1728402340">
#   </script>
#   <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=1&amp;cb=1101857980" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# Extract main content
main_content = soup.find('div', {'class': 'sgnews_single_content'})
for element in main_content(['a', 'em', 'span']):
    element.decompose()

# %%
text_list = []
for paragraph in main_content.find_all('p'):
    paragraph_text = paragraph.get_text(separator=' ', strip=True)
    text_list.append(paragraph_text)

# %%
df = pd.DataFrame({"Paragraph Text": text_list})
df.to_csv('15_paragraphs.csv', index=False) # Save as csv file

# %%
df
# Out:
#                                        Paragraph Text
# 0   Canadian Solar has sealed a JPY 24.5 billion (...
# 1   Societe Generale recently acted as Mandated Le...
# 2   In Japan’s updated energy plan announced in Ap...
# 3   Japan’s solar ambitions, however, are a challe...
# 4                            Putting finance in place
# 5   While the FiT and FiP mechanisms provide a str...
# 6   Unusually for a long-term power asset, this de...
# 7   “This funding model has real potential to help...
# 8   Canadian Solar is one of the biggest solar pow...
# 9   “Canadian Solar is committed to working with a...
# 10  The reduced tenor and capital markets-friendly...
# 11  This is Societe Generale’s first financing for...
# 12
# 13

# %%
nlp = spacy.load("en_core_web_sm")

# %%
relationship_keywords = {'collaboration', 'cooperation', 'partner', 'engage', 
                         'support', 'fund', 'finance', 'invest', 'develop', 
                         'supply', 'promote', 'transition', 'export', 'agreement', 
                         'interest', 'share', 'enhance', 'effort', 'import'}

# %%
def extract_entities_and_relationships(text):
    doc = nlp(text)  # Process text with spaCy
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['ORG', 'GPE', 'FAC']]

    # Find relationships based on keywords
    relationships = []
    for token in doc:
        if token.lemma_ in relationship_keywords:  # Use lemma_ to check relationship keywords
            subject = [w for w in token.children if w.dep_ == "nsubj"]  # Find subject
            object_ = [w for w in token.children if w.dep_ == "dobj"]  # Find object
            if subject and object_:
                relationships.append((subject[0].text, token.text, object_[0].text))  # (subject, relationship, object)

    return entities, relationships

# %%
df['Entities'], df['Relationships'] = zip(*df['Paragraph Text'].apply(extract_entities_and_relationships))

# %%
df[['Paragraph Text', 'Entities', 'Relationships']]
# Out:
#                                        Paragraph Text  \
# 0   Canadian Solar has sealed a JPY 24.5 billion (...
# 1   Societe Generale recently acted as Mandated Le...
# 2   In Japan’s updated energy plan announced in Ap...
# 3   Japan’s solar ambitions, however, are a challe...
# 4                            Putting finance in place
# 5   While the FiT and FiP mechanisms provide a str...
# 6   Unusually for a long-term power asset, this de...
# 7   “This funding model has real potential to help...
# 8   Canadian Solar is one of the biggest solar pow...
# 9   “Canadian Solar is committed to working with a...
# 10  The reduced tenor and capital markets-friendly...
# 11  This is Societe Generale’s first financing for...
# 12
# 13
#
#                                              Entities Relationships
# 0         [(Japan, GPE), (Japan, GPE), (Tohoku, GPE)]            []
# 1                           [(Societe Generale, ORG)]            []
# 2       [(Japan, GPE), (GHG, ORG), (Renewables, ORG)]            []
# 3            [(Japan, GPE), (Japan, GPE), (FiP, ORG)]            []
# 4                                                  []            []
# 5                            [(FiT, ORG), (FiP, ORG)]            []
# 6     [(the Canadian Solar Infrastructure Fund, ORG)]            []
# 7   [(Japan, GPE), (Director - Energy Finance & Ad...            []
# 8   [(Japan, GPE), (FiT, ORG), (Tokyo, GPE), (Cana...            []
# 9          [(Japan, GPE), (Canadian Solar Inc., ORG)]            []
# 10  [(Japan, GPE), (US, GPE), (Societe Generale’s,...            []
# 11  [(Societe Generale’s, ORG), (the Marubeni Corp...            []
# 12                                                 []            []
# 13                                                 []            []

# %%
for index, row in df.iterrows():
    print(f"\nParagraph {index + 1}:")
    print(row['Paragraph Text'])

    # Display dependency parsing
    doc = nlp(row['Paragraph Text'])
    sentence_spans = list(doc.sents)
    displacy.render(sentence_spans, style='dep', jupyter=True, options={'compact': True})
    
    # Display named entities
    displacy.render(sentence_spans, style="ent", jupyter=True)
    
    # Print extracted entities and relationships
    print("Entities:", row['Entities'])
    print("Relationships:", row['Relationships'])
# Out:
# Paragraph 1:
# Canadian Solar has sealed a JPY 24.5 billion (EUR 185 million) financing for the 100 megawatt Azuma Kofuji Solar power project, which counts among the largest solar projects in the country, and is Canadian Solar’s flagship project in Japan. The deal harnesses an inventive financing approach to advance Japan’s clean energy ambitions and help revitalising the Fukushima prefecture, reinvigorating the local economy in a region devastated by the 2011 Tohoku earthquake.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="696121e0fa1344ecbe3b1f1f6a545dc6-0" class="displacy" width="6050" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Canadian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">sealed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">JPY</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">24.5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">billion (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">EUR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">185</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">million)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">financing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">megawatt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Azuma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">Kofuji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">project,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">counts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">largest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">projects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">country,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cur
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Solar has sealed a JPY
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (EUR
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     185 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) financing for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100 megawatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  Azuma Kofuji Solar power project, which counts among the largest solar projects in the country, and is
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Solar’s flagship project in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The deal harnesses an inventive financing approach to advance
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s clean energy ambitions and help revitalising the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fukushima
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  prefecture, reinvigorating the local economy in a region devastated by the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tohoku
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  earthquake.</div></span>
# Entities: [('Japan', 'GPE'), ('Japan', 'GPE'), ('Tohoku', 'GPE')]
# Relationships: []
#
# Paragraph 2:
# Societe Generale recently acted as Mandated Lead Arranger (MLA) in the financing of Canadian Solar’s Azuma Kofuji Solar photovoltaic project.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a59e280bd51f42a2bdc5a47cdc9dd64c-0" class="displacy" width="3200" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Societe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Generale</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">recently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">acted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Mandated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Lead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Arranger (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">MLA)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">financing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Canadian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Azuma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">Kofuji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">photovoltaic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">project.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-1" stroke-width="2px" d="M212,302.0 212,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-3" stroke-width="2px" d="M512,302.0 512,277.0 641.0,277.0 641.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M641.0,304.0 L645.0,296.0 637.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a59e280bd51f42a2bdc5a47cdc9dd64c-0-4"
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Societe Generale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  recently acted as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mandated Lead Arranger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (MLA) in the financing of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Solar’s Azuma Kofuji Solar photovoltaic project.</div></span>
# Entities: [('Societe Generale', 'ORG')]
# Relationships: []
#
# Paragraph 3:
# In Japan’s updated energy plan announced in April 2021, its government committed to a 2030 target of cutting greenhouse gas (GHG) emissions by at least 46% from 2013 levels. Renewables will make up between 36% and 38% of overall generation by then. 1 Of this target, of solar’s share is set to be 15% while wind (predominantly offshore wind) will account for 6%.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="575aac774c2947859fd4c9271f0a39b9-0" class="displacy" width="4550" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Japan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">updated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">announced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">April</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">2021,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">government</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">committed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">2030</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">target</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">cutting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">greenhouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">gas (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">GHG)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">emissions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">least</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">46%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">2013</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">levels.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-575aac774c2947859fd4c9271f0a39b9-0-0" stroke-width="2px" d="M62,377.0 62,252.0 1850.0,252.0 1850.0,377.0" fill="none" stroke="currentColor"/>
#     <te
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s updated energy plan announced in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , its government committed to a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2030
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  target of cutting greenhouse gas (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GHG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) emissions by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 46%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  levels. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Renewables
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will make up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 36% and 38%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of overall generation by then. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Of this target, of solar’s share is set to be
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  while wind (predominantly offshore wind) will account for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# .</div></span>
# Entities: [('Japan', 'GPE'), ('GHG', 'ORG'), ('Renewables', 'ORG')]
# Relationships: []
#
# Paragraph 4:
# Japan’s solar ambitions, however, are a challenge in a country where land use is at a premium and geography restricts available options for solar installations. In addition, solar sites are relatively complex, often requiring capital-intensive civil works. Japan’s feed-in tariff (FiT), introduced in 2012, has helped to meet these challenges by guaranteeing a fixed purchase price for renewable power. It boosted non-hydro renewables’ growth rate from 9% CAGR between 2009-12 to 29% between 2012 and 2015. 2 A new Feed-in-Premium (FiP) is due to be introduced in 2022 which will further incentivise renewables generators to sell their power to the grid.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d6a750bc675f48f48dd04f08122b9921-0" class="displacy" width="3950" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Japan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">ambitions,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">however,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">challenge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">land</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">premium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">geography</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">restricts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">available</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">options</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">installations.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6a750bc675f48f48dd04f08122b9921-0-0" stroke-width="2px" d="M62,302.0 62,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6a750bc675f48f48dd04f08122b9921-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6a750bc675f48f48dd04f08122b9921-0-1" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6a750bc675f48f48dd04f08122b9921-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M191.0,304.0 L195.0,296.0 187.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displa
# /Users/loogyee/anaconda3/lib/python3.11/site-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s solar ambitions, however, are a challenge in a country where land use is at a premium and geography restricts available options for solar installations. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In addition, solar sites are relatively complex, often requiring capital-intensive civil works. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s feed-in tariff (FiT), introduced in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , has helped to meet these challenges by guaranteeing a fixed purchase price for renewable power. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">It boosted non-hydro renewables’ growth rate from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  CAGR
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 2009-12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 2012 and 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A new Feed-in-Premium (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FiP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is due to be introduced in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  which will further incentivise renewables generators to sell their power to the grid.</div></span>
# Entities: [('Japan', 'GPE'), ('Japan', 'GPE'), ('FiP', 'ORG')]
# Relationships: []
#
# Paragraph 5:
# Putting finance in place
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8670dc103a164c3bb527b569681b0dd2-0" class="displacy" width="650" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Putting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">finance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# ...
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">applying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">Canadian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">Solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">Societe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="current
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The reduced tenor and capital markets-friendly structure of the Azuma Kofuji financing is unusual in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  but is a regular feature in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , applying
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Solar’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Societe Generale’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  global experience to the local market.</div></span>
# Entities: [('Japan', 'GPE'), ('US', 'GPE'), ('Societe Generale’s', 'ORG')]
# Relationships: []
#
# Paragraph 12:
# This is Societe Generale’s first financing for a domestic Japanese solar project, having entered the Japanese renewables market in 2020 with financing for the Marubeni Corporation’s 140 MW Akita offshore wind project. 3 The Azuma Kofuji facility will be one of the largest solar projects in the country to date, critical to the meeting the country’s energy transition commitments, as well as playing a substantial role in the reconstruction of the Fukushima prefecture.
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f5d6dd0f09744128ff3aa2df78e8829-0" class="displacy" width="5150" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Societe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Generale</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">financing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">domestic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Japanese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">solar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">project,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">having</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">entered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Japanese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">renewables</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">2020</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">financing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">Marubeni</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">Corporation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">140</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">MW</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">Akita</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Societe Generale’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  financing for a domestic
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japanese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  solar project, having entered the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japanese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  renewables market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with financing for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Marubeni Corporation’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     140
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MW Akita
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  offshore wind project. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The Azuma Kofuji facility will be one of the largest solar projects in the country to date, critical to the meeting the country’s energy transition commitments, as well as playing a substantial role in the reconstruction of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fukushima
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  prefecture.</div></span>
# Entities: [('Societe Generale’s', 'ORG'), ('the Marubeni Corporation’s', 'ORG'), ('MW Akita', 'ORG')]
# Relationships: []
#
# Paragraph 13:
# <span class="tex2jax_ignore"></span>
# <span class="tex2jax_ignore"></span>
# Entities: []
# Relationships: []
#
# Paragraph 14:
# <span class="tex2jax_ignore"></span>
# <span class="tex2jax_ignore"></span>
# Entities: []
# Relationships: []

# %%
entity1_list = []
relationship_list = []
entity2_list = []
date_list = []
money_list = []

# %%
# Iterate through each paragraph
for index, row in df.iterrows():
    doc = nlp(row['Paragraph Text'])  # Process the paragraph with spaCy

    for sent in doc.sents:
        # Extract named entities (countries, organizations)
        entities = []
        money_in_sentence = []

        for ent in sent.ents:
            if 'Inititative' in ent.text.lower(): 
                ent = ent._replace(label_='POL')
                entities.append(ent)
            elif ent.label_ in ['GPE', 'ORG', 'POL', 'MONEY']:
                entities.append(ent)

            # Collect monetary amounts
            if ent.label_ == "MONEY":
                money_in_sentence.append(ent.text)
        
        # Look for verbs or specific relationship nouns in the sentence
        verbs = [token for token in sent if token.pos_ == "VERB"]
        keywords_in_sentence = [token.text for token in sent if token.lemma_ in relationship_keywords]
        
        # Extract dates
        dates = [ent.text for ent in sent.ents if ent.label_ == "DATE"]

        # If we find two entities and a relationship keyword, we assume a relationship
        if len(entities) >= 2 and keywords_in_sentence:
            entity1_list.append(entities[0].text)

            # Concatenate the relationship noun and verb (if available) into one string
            relationship_info = keywords_in_sentence[0]
            if verbs:
                relationship_info += " (verb: " + verbs[0].lemma_ + ")"

            relationship_list.append(relationship_info)  # Store concatenated info
            entity2_list.append(entities[1].text)
            date_list.append(dates[0] if dates else "n/a")
            money_list.append(money_in_sentence[0] if money_in_sentence else "n/a")

# %%
# DataFrame
relationships_df = pd.DataFrame({
    "Entity1": entity1_list,
    "Relationship": relationship_list,
    "Entity2": entity2_list,
    "Date": date_list,
    "Money": money_list
})

# %%
relationships_df
# Out:
#   Entity1             Relationship                             Entity2 Date  \
# 0     FiT  support (verb: provide)                                 FiP  n/a
# 1   Tokyo     funding (verb: list)  Canadian Solar Infrastructure Fund  n/a
#
#   Money
# 0   n/a
# 1   n/a

# %%
# Export to csv
relationships_df.to_csv('15_relationships.csv', index=False)
